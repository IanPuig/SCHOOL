# %% [markdown]
# ![Nuclio logo](https://nuclio.school/wp-content/uploads/2018/12/nucleoDS-newBlack.png)

# %% [markdown]
# ## 1. Librerias
#
# Para empezar carguemos esas librerias que nos hacen falta

# %%
import numpy as np
import time
import datetime
import random
import pandas as pd
import os

from matplotlib import pyplot as plt
from tensorflow import keras as ks
from tensorflow.keras.preprocessing.image import ImageDataGenerator, load_img
from keras.utils import to_categorical
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.regularizers import l2
from tensorflow.keras.optimizers import Adam

# %% [markdown]
# ## 2. Arquitectura de red del modelo

# %%
model = ks.Sequential()

model.add(ks.layers.Conv2D(32, (3, 3), strides=1, activation='relu', padding='same', input_shape=(32,32,3)))
model.add(ks.layers.Conv2D(32, (3, 3), strides=1, activation='relu', padding='same'))
model.add(ks.layers.MaxPooling2D((2, 2)))
model.add(ks.layers.Dropout(0.6))  

model.add(ks.layers.Conv2D(64, (3, 3), strides=1, activation='relu', padding='same', input_shape=(32,32,3)))
model.add(ks.layers.Conv2D(64, (3, 3), strides=1, activation='relu', padding='same'))
model.add(ks.layers.MaxPooling2D((2, 2)))
model.add(ks.layers.Dropout(0.5))  

model.add(ks.layers.Flatten())
model.add(ks.layers.Dense(128, activation='relu'))
model.add(ks.layers.Dropout(0.4))  

model.add(ks.layers.Dense(10, activation='softmax'))
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_4 (Conv2D)            (None, 32, 32, 32)        896
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 32, 32, 32)        9248
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 16, 16, 32)        0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 16, 16, 32)        0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 16, 16, 64)        18496
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 16, 16, 64)        36928
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 8, 8, 64)          0
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 8, 8, 64)          0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 4096)              0
# _________________________________________________________________
# dense_2 (Dense)              (None, 128)               524416
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 10)                1290
# =================================================================
# Total params: 591,274
# Trainable params: 591,274
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# Para revisar un modelo, nos basta con llamar al método **.summary()** del modelo

# %% [markdown]
# ## 3. Optimizador, función error

# %%
model.compile(optimizer='Adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# %% [markdown]
# # 3.1 Definimos la tecnica de Early stopping mediante callbacks

# %%
callback_val_loss = EarlyStopping(monitor="val_loss", patience=20)
callback_val_accy = EarlyStopping(monitor="val_accuracy", patience=20)

# %% [markdown]
# ## 4. Preparamos los datos
#
# Cargamos los datos de CIFAR10 de los datasets directamente de las librerias de Keras. Estos ya estan dispuestos en train and test
#
# **Detalle importante:**
# > La red neuronal requiere que los inputs sean números reales, y lo haremos forzando la division de los valores de dentro de las matrices 28x28 (que tienen valoress del 0 al 255) por 255.0 (un real)

# %%
cifar10 = ks.datasets.cifar10

(x_train, y_train), (x_test, y_test) = cifar10.load_data()
# x_train, x_test = x_train / 255.0, x_test / 255.0            # ya cambiamos el escalado a de 0 a 1

# %%
print(y_train)
print(y_test)
# Out:
# [[6]
#  [9]
#  [9]
#  ...
#  [9]
#  [1]
#  [1]]
# [[3]
#  [8]
#  [8]
#  ...
#  [5]
#  [1]
#  [7]]

# %% [markdown]
# Obtenemos un array con todas las labels de CIFAR10

# %%
cifar10_labels = ['airplane','automobile','bird','cat','deer','dog','frog','horse','ship','truck']
print('labels: %s' % (cifar10_labels))
# Out:
# labels: ['airplane', 'automobile', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']

# %% [markdown]
# Pintemos una muestra de las imagenes del dataset CIFAR10, a ver si se parece en algo a lo que esperamos.
# Primero, vemos que tipos de datos tengo, después mapeamos esas matrices en una escala de grises utilizando el método **.get_cmap()** de PlotLy con los nueve primeros números del dataset.

# %%
# Pintemos una muestra de las las imagenes del dataset 

print('Train: X=%s, y=%s' % (x_train.shape, y_train.shape))
print('Test: X=%s, y=%s' % (x_test.shape, y_test.shape))

for i in range(9):

    plt.subplot(330 + 1 + i)
    plt.imshow(x_train[i], cmap=plt.get_cmap('gray'))
    plt.title(cifar10_labels[y_train[i,0]])

plt.subplots_adjust(hspace = 1)
plt.show()
# Out:
# Train: X=(50000, 32, 32, 3), y=(50000, 1)
# Test: X=(10000, 32, 32, 3), y=(10000, 1)

# %% [markdown]
# Como vamos a querer ir haciendo validación a la vez que entrenamos (muy practico)

# %%
x_val = x_train[-10000:]
y_val = y_train[-10000:]

x_train = x_train[:-10000]
y_train = y_train[:-10000]

# %% [markdown]
# Cuando añadimos convoluciones, necesitamos "pre-tratar los datos", porque **la convolución es pera una matriz de 4 campos** (más parecido a "imagenes"), no un array de 3 como son actualmente los data sets de train, test y validación. Así que toca darle al **.reshape()**
#
# Por eso, al salir de la Convolution, hay que hacer un Flatten, porque las capas FullDense esperan arrays, no matrices!!
#
# Luego lo imprimimos para ver que todo está correcto

# %%
# Validamos el resultado
print('Train: X=%s, y=%s' % (x_train.shape, y_train.shape))
print('Test: X=%s, y=%s' % (x_test.shape, y_test.shape))
# Out:
# Train: X=(40000, 32, 32, 3), y=(40000, 1)
# Test: X=(10000, 32, 32, 3), y=(10000, 1)

# %% [markdown]
# ## Transformador de imagenes a datos consumibles por la red neuronal

# %%
train_datagen = ImageDataGenerator( 
    rescale=1./255,
    # rotation_range = 20,
    # shear_range = 0.05,
    # zoom_range= 0.05,
    horizontal_flip=True,
    # width_shift_range=-0.01,
    # height_shift_range=-0.01,
    # brightness_range=(0.8,1.2),
    # fill_mode='nearest'
    )

# debemos coger las imagenes originales, le doy la x, le doy la y 
# y el batch size = cuantas imagenes voy a generar por cada paquete, data generation (no podemos pasarnos, misma cantidad que le pasamos en eel data set)

train_generator = train_datagen.flow( 
    x_train, 
    y_train, 
    batch_size=256          # hago esto para cada 30 imagenes
    )

# %% [markdown]
# ## vamos a pintarnos un ejemplo de lo que hace el train data generator

# %%
sample = random.choice(range(0,1450))
example_generator = train_datagen.flow(
    x_train[sample:sample+1],
    y_train[sample:sample+1],
    batch_size=20
    )

plt.imshow(x_train[sample])

# %%
plt.figure(figsize=(12,12))
for i in range(0,15):
    plt.subplot(5,3,i+1)
    for X, Y in example_generator:
        image = X[0]
        plt.imshow(image)
        break

plt.tight_layout()
plt.show()

# %% [markdown]
# **De validacion y de testeo**
#
# Fijaos que aquí la única modificación es un re-escalado, nada de modificaciones

# %%
validation_datagen = ImageDataGenerator(
    rescale=1./255
    )
validation_generator = validation_datagen.flow(
    x_val, 
    y_val, 
    batch_size=32
    )

test_datagen = ImageDataGenerator(
    rescale=1./255
    )
test_generator = test_datagen.flow(
    x_test, 
    y_test,
    batch_size=32
    )

# %% [markdown]
# ## 5. Entrenamiento
#
# Ya podemos ponernos a entrenar el modelo!! Ojo, que hemos de entrenar contra los datos convertidos al formato que espera la Convolution.
#
# Empezaremos con 30 epocs, es decir, 30 pasadas completas del dataset (que a su vez sera con mini-batches internamente), fijando un batch de 64
#
# El metodo .fit() nos permite, definir además si disponemos de varias CPUs, GPUs, y si queremos ir validando datos a cada fin de epoch.

# %%
t = time.perf_counter()

# %%
history = model.fit(train_generator,epochs=100,steps_per_epoch= 128,callbacks=[callback_val_loss,callback_val_accy],validation_data=validation_generator,validation_steps=32)

# history = model.fit(x_traain, y_train, epochs=200, callbacks=[callback_val_loss,callback_val_accy], batch_size= 512, validation_data=(x_val, y_val))
# Out:
# Epoch 1/100
# 128/128 [==============================] - 2s 19ms/step - loss: 1.3245 - accuracy: 0.0957 - val_loss: 1.2620 - val_accuracy: 0.0918
# Epoch 2/100
# 128/128 [==============================] - 2s 18ms/step - loss: 1.2748 - accuracy: 0.0970 - val_loss: 1.1299 - val_accuracy: 0.0684
# Epoch 3/100
# 128/128 [==============================] - 2s 18ms/step - loss: 1.2238 - accuracy: 0.0962 - val_loss: 1.0617 - val_accuracy: 0.0889
# Epoch 4/100
# 128/128 [==============================] - 2s 18ms/step - loss: 1.1791 - accuracy: 0.0960 - val_loss: 1.0452 - val_accuracy: 0.0850
# Epoch 5/100
# 128/128 [==============================] - 2s 18ms/step - loss: 1.1482 - accuracy: 0.0979 - val_loss: 0.9745 - val_accuracy: 0.0752
# Epoch 6/100
# 128/128 [==============================] - 2s 18ms/step - loss: 1.1057 - accuracy: 0.0969 - val_loss: 0.9564 - val_accuracy: 0.0693
# Epoch 7/100
# 128/128 [==============================] - 2s 18ms/step - loss: 1.0891 - accuracy: 0.0970 - val_loss: 0.9359 - val_accuracy: 0.0820
# Epoch 8/100
# 128/128 [==============================] - 2s 18ms/step - loss: 1.0644 - accuracy: 0.0976 - val_loss: 0.9566 - val_accuracy: 0.1025
# Epoch 9/100
# 128/128 [==============================] - 2s 18ms/step - loss: 1.0494 - accuracy: 0.0990 - val_loss: 0.9108 - val_accuracy: 0.0879
# Epoch 10/100
# 128/128 [==============================] - 2s 18ms/step - loss: 1.0185 - accuracy: 0.0970 - val_loss: 0.9378 - val_accuracy: 0.0762
# Epoch 11/100
# 128/128 [==============================] - 2s 18ms/step - loss: 1.0005 - accuracy: 0.0981 - val_loss: 0.8639 - val_accuracy: 0.0967
# Epoch 12/100
# 128/128 [==============================] - 2s 18ms/step - loss: 0.9898 - accuracy: 0.0984 - val_loss: 0.9002 - val_accuracy: 0.0654
# Epoch 13/100
# 128/128 [==============================] - 2s 18ms/step - loss: 0.9724 - accuracy: 0.0991 - val_loss: 0.8507 - val_accuracy: 0.0850
# Epoch 14/100
# 128/128 [==============================] - 2s 18ms/step - loss: 0.9585 - accuracy: 0.0997 - val_loss: 0.8636 - val_accuracy: 0.1006
# Epoch 15/100
# 128/128 [==============================] - 2s 18ms/step - loss: 0.9354 - accuracy: 0.0996 - val_loss: 0.8909 - val_accuracy: 0.0635
# Epoch 16/100
# 128/128 [==============================] - 2s 18ms/step - loss: 0.9259 - accuracy: 0.0992 - val_loss: 0.8498 - val_accuracy: 0.0771
# Epoch 17/100
# 128/128 [==============================] - 2s 18ms/step - loss: 0.9179 - accuracy: 0.0980 - val_loss: 0.8189 - val_accuracy: 0.0928
# Epoch 18/100
# 128/128 [==============================] - 2s 18ms/step - loss: 0.9069 - accuracy: 0.0988 - val_loss: 0.8027 - val_accuracy: 0.1035
# Epoch 19/100
# 128/128 [==============================] - 2s 18ms/step - loss: 0.8946 - accuracy: 0.0987 - val_loss: 0.7887 - val_accuracy: 0.0762
# Epoch 20/100
# 128/128 [==============================] - 2s 18ms/step - loss: 0.8983 - accuracy: 0.0978 - val_loss: 0.7747 - val_accuracy: 0.0820
# Epoch 21/100
# 128/128 [==============================] - 2s 18ms/step - loss: 0.8762 - accuracy: 0.0990 - val_loss: 0.7628 - val_accuracy: 0.0850
# Epoch 22/100
# 128/128 [==============================] - 2s 18ms/step - loss: 0.8607 - accuracy: 0.0997 - val_loss: 0.7516 - val_accuracy: 0.0908
# Epoch 23/100
# 128/128 [==============================] - 2s 18ms/step - loss: 0.8644 - accuracy: 0.1029 - val_loss: 0.7716 - val_accuracy: 0.0908
# Epoch 24/100
# 128/128 [==============================] - 2s 18ms/step - loss: 0.8550 - accuracy: 0.1004 - val_loss: 0.7936 - val_accuracy: 0.0967
# Epoch 25/100
# 128/128 [==============================] - 2s 18ms/step - loss: 0.8436 - accuracy: 0.1008 - val_loss: 0.8654 - val_accuracy: 0.0928
# Epoch 26/100
# 128/128 [==============================] - 2s 19ms/step - loss: 0.8457 - accuracy: 0.1014 - val_loss: 0.7893 - val_accuracy: 0.0938
# Epoch 27/100
# 128/128 [==============================] - 2s 18ms/step - loss: 0.8368 - accuracy: 0.1006 - val_loss: 0.7266 - val_accuracy: 0.0898
# Epoch 28/100
# 128/128 [==============================] - 2s 18ms/step - loss: 0.8227 - accuracy: 0.1024 - val_loss: 0.6923 - val_accuracy: 0.0957
# Epoch 29/100
# 128/128 [==============================] - 2s 19ms/step - loss: 0.8144 - accuracy: 0.1005 - val_loss: 0.6849 - val_accuracy: 0.0928
# Epoch 30/100
# 128/128 [==============================] - 2s 18ms/step - loss: 0.8066 - accuracy: 0.1024 - val_loss: 0.6878 - val_accuracy: 0.0850
# Epoch 31/100
# 128/128 [==============================] - 2s 18ms/step - loss: 0.7961 - accuracy: 0.1012 - val_loss: 0.7446 - val_accuracy: 0.0781
# Epoch 32/100
# 128/128 [==============================] - 2s 18ms/step - loss: 0.7891 - accuracy: 0.1011 - val_loss: 0.6601 - val_accuracy: 0.1055
# Epoch 33/100
# 128/128 [==============================] - 2s 18ms/step - loss: 0.7873 - accuracy: 0.1004 - val_loss: 0.6540 - val_accuracy: 0.0879
# Epoch 34/100
# 128/128 [==============================] - 2s 18ms/step - loss: 0.8017 - accuracy: 0.1010 - val_loss: 0.6627 - val_accuracy: 0.1084
# Epoch 35/100
# 128/128 [==============================] - 2s 19ms/step - loss: 0.7830 - accuracy: 0.1015 - val_loss: 0.7051 - val_accuracy: 0.0801
# Epoch 36/100
# 128/128 [==============================] - 2s 19ms/step - loss: 0.7870 - accuracy: 0.1013 - val_loss: 0.6515 - val_accuracy: 0.0771
# Epoch 37/100
# 128/128 [==============================] - 2s 18ms/step - loss: 0.7691 - accuracy: 0.1007 - val_loss: 0.7584 - val_accuracy: 0.0859
# Epoch 38/100
# 128/128 [==============================] - 2s 19ms/step - loss: 0.7695 - accuracy: 0.1036 - val_loss: 0.6610 - val_accuracy: 0.0801
# Epoch 39/100
# 128/128 [==============================] - 2s 19ms/step - loss: 0.7655 - accuracy: 0.1023 - val_loss: 0.6843 - val_accuracy: 0.0879
# Epoch 40/100
# 128/128 [==============================] - 2s 19ms/step - loss: 0.7618 - accuracy: 0.1001 - val_loss: 0.7759 - val_accuracy: 0.0996
# Epoch 41/100
# 128/128 [==============================] - 2s 19ms/step - loss: 0.7568 - accuracy: 0.1014 - val_loss: 0.6123 - val_accuracy: 0.0967
# Epoch 42/100
# 128/128 [==============================] - 2s 19ms/step - loss: 0.7505 - accuracy: 0.1019 - val_loss: 0.6853 - val_accuracy: 0.0859
# Epoch 43/100
# 128/128 [==============================] - 2s 19ms/step - loss: 0.7472 - accuracy: 0.1023 - val_loss: 0.6417 - val_accuracy: 0.0918
# Epoch 44/100
# 128/128 [==============================] - 2s 18ms/step - loss: 0.7522 - accuracy: 0.1007 - val_loss: 0.7174 - val_accuracy: 0.0811
# Epoch 45/100
# 128/128 [==============================] - 2s 19ms/step - loss: 0.7481 - accuracy: 0.1020 - val_loss: 0.7126 - val_accuracy: 0.0859
# Epoch 46/100
# 128/128 [==============================] - 2s 19ms/step - loss: 0.7375 - accuracy: 0.1001 - val_loss: 0.5764 - val_accuracy: 0.0830
# Epoch 47/100
# 128/128 [==============================] - 2s 19ms/step - loss: 0.7426 - accuracy: 0.1022 - val_loss: 0.7523 - val_accuracy: 0.0771
# Epoch 48/100
# 128/128 [==============================] - 2s 19ms/step - loss: 0.7332 - accuracy: 0.1004 - val_loss: 0.6865 - val_accuracy: 0.0859
# Epoch 49/100
# 128/128 [==============================] - 2s 19ms/step - loss: 0.7346 - accuracy: 0.1004 - val_loss: 0.6692 - val_accuracy: 0.0947
# Epoch 50/100
# 128/128 [==============================] - 2s 18ms/step - loss: 0.7294 - accuracy: 0.1021 - val_loss: 0.5976 - val_accuracy: 0.0928
# Epoch 51/100
# 128/128 [==============================] - 2s 19ms/step - loss: 0.7154 - accuracy: 0.1005 - val_loss: 0.6533 - val_accuracy: 0.1016
# Epoch 52/100
# 128/128 [==============================] - 2s 19ms/step - loss: 0.7152 - accuracy: 0.1021 - val_loss: 0.6376 - val_accuracy: 0.0957
# Epoch 53/100
# 128/128 [==============================] - 3s 20ms/step - loss: 0.7136 - accuracy: 0.1031 - val_loss: 0.6820 - val_accuracy: 0.0898
# Epoch 54/100
# 128/128 [==============================] - 2s 19ms/step - loss: 0.7183 - accuracy: 0.1032 - val_loss: 0.7096 - val_accuracy: 0.0791

# %%
elapsed_time = datetime.timedelta(seconds=(time.perf_counter() - t))

print('Tiempo de entrenamiento:', elapsed_time)
# Out:
# Tiempo de entrenamiento: 0:01:53.123163

# %% [markdown]
# ## 6. Evaluamos los resultados

# %%
_, acc = model.evaluate(test_generator, verbose=0)
print('Accuracy:',' %.3f' % (acc))
# Out:
# Accuracy:  0.085

# %%
plt.title('Cross Entropy Loss')
plt.plot(history.history['loss'], color='blue', label='train')
plt.plot(history.history['val_loss'], color='orange', label='test')
plt.show()

plt.title('Classification Accuracy')
plt.plot(history.history['accuracy'], color='blue', label='train')
plt.plot(history.history['val_accuracy'], color='orange', label='test')
plt.show()

# %% [markdown]
# El coste podemos ver que es estable y es en el epoch 15 que se fija en un valor. Además la accuracy baila alrededor de 0.10. No se puede decir que sea un modelo muy bueno.
#
# Veamos que tipo de predicciones estoy obteniendo sobre el conjunto de test (vamos a pintar las imagenes y sus clasificaciones)

# %%
predictions = model.predict(x_test)

# %% [markdown]
# Una de las ventajas de Python es que hay montones de funciones y código realizado por terceras personas. Aquí me he fusilado unas bonitas funciones (que he adaptado un poco a mis necesidades) para poder pintar las imagenes, su label (ground truth) y las clasificaciones que hemos realizado.

# %%
def plot_image(i, predictions_array, true_label, img):
  predictions_array, true_label, img = predictions_array, true_label[i], img[i]
  plt.grid(False)
  plt.xticks([])
  plt.yticks([])

  plt.imshow(img, cmap=plt.cm.binary)

  predicted_label = np.argmax(predictions_array)
  if predicted_label == true_label:
    color = 'blue'
  else:
    color = 'red'

  plt.xlabel("{} {:2.0f}% ({})".format(predicted_label,
                                100*np.max(predictions_array),
                                true_label[0]),
                                color=color)

def plot_value_array(i, predictions_array, true_label):
  predictions_array, true_label = predictions_array, true_label[i]
  plt.grid(False)
  plt.xticks(range(10))
  plt.yticks([])
  thisplot = plt.bar(range(10), predictions_array, color="#777777")
  plt.ylim([0, 1])
  predicted_label = np.argmax(predictions_array)

  thisplot[predicted_label].set_color('red')
  thisplot[true_label[0]].set_color('blue')

# %% [markdown]
# Dibujamos las primeras imagenes, con las predicciones y sus valores reales (un total de 20 imagenes, para no abusar de vuestros laptops)
#
# Coloreamos las prediciones correctas en azul y los fallos en rojo. Aunque primero he impreso las etiquetas para que tengamos una referencia al grafico.

# %%
i = 0
for l in cifar10_labels:
    print(i, l)
    i += 1

num_rows = 5
num_cols = 4
start = 650
num_images = num_rows*num_cols
plt.figure(figsize=(2*2*num_cols, 2*num_rows))
for i in range(num_images):
  plt.subplot(num_rows, 2*num_cols, 2*i+1)
  plot_image(i+start, predictions[i+start], y_test, x_test)
  plt.subplot(num_rows, 2*num_cols, 2*i+2)
  plot_value_array(i+start, predictions[i+start], y_test)
plt.tight_layout()
plt.show()
# Out:
# 0 airplane
# 1 automobile
# 2 bird
# 3 cat
# 4 deer
# 5 dog
# 6 frog
# 7 horse
# 8 ship
# 9 truck
