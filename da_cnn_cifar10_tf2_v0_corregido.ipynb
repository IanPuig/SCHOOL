# %% [markdown]
# <a href="https://colab.research.google.com/github/IanPuig/SCHOOL/blob/main/da_cnn_cifar10_tf2_v0_corregido.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![Nuclio logo](https://nuclio.school/wp-content/uploads/2018/12/nucleoDS-newBlack.png)

# %% [markdown]
# ## 1. Librerias
#
# Para empezar carguemos esas librerias que nos hacen falta

# %%
import numpy as np
import time
import datetime
import random
import pandas as pd
import os

from matplotlib import pyplot as plt
from tensorflow import keras as ks
from tensorflow.keras.preprocessing.image import ImageDataGenerator, load_img
from keras.utils import to_categorical
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.regularizers import l2
from tensorflow.keras.optimizers import Adam

# %% [markdown]
# ## 2. Arquitectura de red del modelo

# %%
model = ks.Sequential()

model.add(ks.layers.Conv2D(32, (3, 3), strides=1, activation='relu', padding='same', kernel_regularizer=l2(0.001), kernel_initializer='he_uniform', input_shape=(32,32,3)))
model.add(ks.layers.Conv2D(32, (3, 3), strides=1, activation='relu', padding='same', kernel_regularizer=l2(0.001), kernel_initializer='he_uniform'))
model.add(ks.layers.MaxPooling2D((2, 2)))
model.add(ks.layers.Dropout(0.4)) 

model.add(ks.layers.Conv2D(64, (3, 3), strides=1, activation='relu', padding='same', kernel_regularizer=l2(0.001), kernel_initializer='he_uniform'))
model.add(ks.layers.Conv2D(64, (3, 3), strides=1, activation='relu', padding='same', kernel_regularizer=l2(0.001), kernel_initializer='he_uniform'))
model.add(ks.layers.MaxPooling2D((2, 2)))
model.add(ks.layers.Dropout(0.4)) 

model.add(ks.layers.Conv2D(128, (3, 3), strides=1, activation='relu', padding='same', kernel_regularizer=l2(0.001), kernel_initializer='he_uniform'))
model.add(ks.layers.Conv2D(128, (3, 3), strides=1, activation='relu', padding='same', kernel_regularizer=l2(0.001), kernel_initializer='he_uniform'))
model.add(ks.layers.MaxPooling2D((2, 2)))
model.add(ks.layers.Dropout(0.4))  

model.add(ks.layers.Conv2D(256, (3, 3), strides=1, activation='relu', padding='same', kernel_regularizer=l2(0.001), kernel_initializer='he_uniform'))
model.add(ks.layers.Conv2D(256, (3, 3), strides=1, activation='relu', padding='same', kernel_regularizer=l2(0.001), kernel_initializer='he_uniform'))
model.add(ks.layers.MaxPooling2D((2, 2)))
model.add(ks.layers.Dropout(0.4))  

model.add(ks.layers.Flatten())
model.add(ks.layers.Dense(256, activation='relu', kernel_regularizer=l2(0.001), kernel_initializer='he_uniform'))
model.add(ks.layers.BatchNormalization())
model.add(ks.layers.Dropout(0.4))  

model.add(ks.layers.Dense(256, activation='relu', kernel_regularizer=l2(0.001), kernel_initializer='he_uniform'))
model.add(ks.layers.BatchNormalization())
model.add(ks.layers.Dropout(0.4))  

model.add(ks.layers.Dense(10, activation='softmax'))
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 32, 32, 32)        896
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 32, 32, 32)        9248
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 16, 16, 32)        0
# _________________________________________________________________
# dropout (Dropout)            (None, 16, 16, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 16, 16, 64)        18496
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 16, 16, 64)        36928
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 8, 8, 64)          0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 8, 8, 64)          0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 8, 8, 128)         73856
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 8, 8, 128)         147584
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 4, 4, 128)         0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 4, 4, 128)         0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 4, 4, 256)         295168
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 4, 4, 256)         590080
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 2, 2, 256)         0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 2, 2, 256)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 1024)              0
# _________________________________________________________________
# dense (Dense)                (None, 256)               262400
# _________________________________________________________________
# batch_normalization (BatchNo (None, 256)               1024
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 256)               65792
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 256)               1024
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                2570
# =================================================================
# Total params: 1,505,066
# Trainable params: 1,504,042
# Non-trainable params: 1,024
# _________________________________________________________________

# %% [markdown]
# Para revisar un modelo, nos basta con llamar al método **.summary()** del modelo

# %% [markdown]
# ## 3. Optimizador, función error

# %%
model.compile(optimizer='Adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# %% [markdown]
# # 3.1 Definimos la tecnica de Early stopping mediante callbacks

# %%
callback_val_loss = EarlyStopping(monitor="val_loss", patience=20)
callback_val_accy = EarlyStopping(monitor="val_accuracy", patience=20)

# %% [markdown]
# ## 4. Preparamos los datos
#
# Cargamos los datos de CIFAR10 de los datasets directamente de las librerias de Keras. Estos ya estan dispuestos en train and test
#
# **Detalle importante:**
# > La red neuronal requiere que los inputs sean números reales, y lo haremos forzando la division de los valores de dentro de las matrices 28x28 (que tienen valoress del 0 al 255) por 255.0 (un real)

# %%
cifar10 = ks.datasets.cifar10

(x_train, y_train), (x_test, y_test) = cifar10.load_data()
x_train_scaled, x_test_scaled = x_train / 255.0, x_test / 255.0            # Descomentado por Isidre

# %%
print(y_train)
print(y_test)
# Out:
# [[6]
#  [9]
#  [9]
#  ...
#  [9]
#  [1]
#  [1]]
# [[3]
#  [8]
#  [8]
#  ...
#  [5]
#  [1]
#  [7]]

# %% [markdown]
# Obtenemos un array con todas las labels de CIFAR10

# %%
cifar10_labels = ['airplane','automobile','bird','cat','deer','dog','frog','horse','ship','truck']
print('labels: %s' % (cifar10_labels))
# Out:
# labels: ['airplane', 'automobile', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']

# %% [markdown]
# Pintemos una muestra de las imagenes del dataset CIFAR10, a ver si se parece en algo a lo que esperamos.
# Primero, vemos que tipos de datos tengo, después mapeamos esas matrices en una escala de grises utilizando el método **.get_cmap()** de PlotLy con los nueve primeros números del dataset.

# %%
# Pintemos una muestra de las las imagenes del dataset 

print('Train: X=%s, y=%s' % (x_train.shape, y_train.shape))
print('Test: X=%s, y=%s' % (x_test.shape, y_test.shape))

for i in range(9):

    plt.subplot(330 + 1 + i)
    plt.imshow(x_train[i], cmap=plt.get_cmap('gray'))
    plt.title(cifar10_labels[y_train[i,0]])

plt.subplots_adjust(hspace = 1)
plt.show()
# Out:
# Train: X=(50000, 32, 32, 3), y=(50000, 1)
# Test: X=(10000, 32, 32, 3), y=(10000, 1)

# %% [markdown]
# Como vamos a querer ir haciendo validación a la vez que entrenamos (muy practico)

# %%
x_val = x_train[-10000:]
y_val = y_train[-10000:]

x_train = x_train[:-10000]
y_train = y_train[:-10000]

# %% [markdown]
# # [Añadido por ISIDRE]

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()
le.fit(y_train)

y_train_encoded = le.transform(y_train)
y_val_encoded = le.transform(y_val)
y_test_encoded = le.transform(y_test)
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/preprocessing/_label.py:235: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.6/dist-packages/sklearn/preprocessing/_label.py:268: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
y_train_encoded
# Out:
# array([6, 9, 9, ..., 6, 2, 8])

# %% [markdown]
# # [Fin añadido por Isidre]

# %%
y_train
# Out:
# array([[6],
#        [9],
#        [9],
#        ...,
#        [6],
#        [2],
#        [8]], dtype=uint8)

# %% [markdown]
# Cuando añadimos convoluciones, necesitamos "pre-tratar los datos", porque **la convolución es pera una matriz de 4 campos** (más parecido a "imagenes"), no un array de 3 como son actualmente los data sets de train, test y validación. Así que toca darle al **.reshape()**
#
# Por eso, al salir de la Convolution, hay que hacer un Flatten, porque las capas FullDense esperan arrays, no matrices!!
#
# Luego lo imprimimos para ver que todo está correcto

# %%
# Validamos el resultado
print('Train: X=%s, y=%s' % (x_train.shape, y_train.shape))
print('Test: X=%s, y=%s' % (x_test.shape, y_test.shape))
# Out:
# Train: X=(40000, 32, 32, 3), y=(40000, 1)
# Test: X=(10000, 32, 32, 3), y=(10000, 1)

# %% [markdown]
# ## Transformador de imagenes a datos consumibles por la red neuronal

# %%
train_datagen = ImageDataGenerator( 
    rescale=1./255,
    # rotation_range = 20,
    # shear_range = 0.05,
    # zoom_range= 0.05,
    horizontal_flip=True,
    # width_shift_range=-0.01,
    # height_shift_range=-0.01,
    # brightness_range=(0.8,1.2),
    # fill_mode='nearest'
    )

train_generator = train_datagen.flow( 
    x_train, 
    y_train_encoded, 
    batch_size=512          
    )

# %% [markdown]
# ## vamos a pintarnos un ejemplo de lo que hace el train data generator

# %%
sample = random.choice(range(0,1450))
example_generator = train_datagen.flow(
    x_train[sample:sample+1],
    y_train[sample:sample+1],
    batch_size=512
    )

plt.imshow(x_train[sample])

# %%
plt.figure(figsize=(12,12))
for i in range(0,15):
    plt.subplot(5,3,i+1)
    for X, Y in example_generator:
        image = X[0]
        plt.imshow(image)
        break

plt.tight_layout()
plt.show()

# %% [markdown]
# **De validacion y de testeo**
#
# Fijaos que aquí la única modificación es un re-escalado, nada de modificaciones

# %%
validation_datagen = ImageDataGenerator(
    rescale=1./255
    )
validation_generator = validation_datagen.flow(
    x_val, 
    y_val_encoded, 
    batch_size=512
    )

test_datagen = ImageDataGenerator(
    rescale=1./255
    )
test_generator = test_datagen.flow(
    x_test, 
    y_test_encoded,
    batch_size=512
    )

# %% [markdown]
# ## 5. Entrenamiento
#
# Ya podemos ponernos a entrenar el modelo!! Ojo, que hemos de entrenar contra los datos convertidos al formato que espera la Convolution.
#
# Empezaremos con 30 epocs, es decir, 30 pasadas completas del dataset (que a su vez sera con mini-batches internamente), fijando un batch de 64
#
# El metodo .fit() nos permite, definir además si disponemos de varias CPUs, GPUs, y si queremos ir validando datos a cada fin de epoch.

# %%
t = time.perf_counter()

# %%
history = model.fit(train_generator,epochs=200,steps_per_epoch= 78,callbacks=[callback_val_loss,callback_val_accy],validation_data=validation_generator,validation_steps=20)

# history = model.fit(x_traain, y_train, epochs=200, callbacks=[callback_val_loss,callback_val_accy], batch_size= 512, validation_data=(x_val, y_val))
# Out:
# Epoch 1/200
# 78/78 [==============================] - 14s 124ms/step - loss: 5.6910 - accuracy: 0.1454 - val_loss: 4.4819 - val_accuracy: 0.1851
# Epoch 2/200
# 78/78 [==============================] - 8s 107ms/step - loss: 4.3866 - accuracy: 0.2022 - val_loss: 4.1175 - val_accuracy: 0.1382
# Epoch 3/200
# 78/78 [==============================] - 8s 107ms/step - loss: 3.6811 - accuracy: 0.2375 - val_loss: 4.1599 - val_accuracy: 0.1109
# Epoch 4/200
# 78/78 [==============================] - 9s 109ms/step - loss: 3.1735 - accuracy: 0.2903 - val_loss: 3.4151 - val_accuracy: 0.1076
# Epoch 5/200
# 78/78 [==============================] - 9s 112ms/step - loss: 2.7641 - accuracy: 0.3714 - val_loss: 3.0729 - val_accuracy: 0.2130
# Epoch 6/200
# 78/78 [==============================] - 8s 107ms/step - loss: 2.4157 - accuracy: 0.4368 - val_loss: 2.9010 - val_accuracy: 0.2919
200
# 78/78 [==============================] - 8s 108ms/step - loss: 0.8892 - accuracy: 0.7862 - val_loss: 0.9122 - val_accuracy: 0.7831
# Epoch 47/200
# 78/78 [==============================] - 8s 108ms/step - loss: 0.9139 - accuracy: 0.7803 - val_loss: 0.8220 - val_accuracy: 0.8068
# Epoch 48/200
# 78/78 [==============================] - 8s 108ms/step - loss: 0.8840 - accuracy: 0.7896 - val_loss: 0.7978 - val_accuracy: 0.8176
# Epoch 49/200
# 78/78 [==============================] - 9s 111ms/step - loss: 0.9042 - accuracy: 0.7820 - val_loss: 0.8601 - val_accuracy: 0.7988
# Epoch 50/200
# 78/78 [==============================] - 9s 112ms/step - loss: 0.8777 - accuracy: 0.7903 - val_loss: 0.8377 - val_accuracy: 0.8061
# Epoch 51/200
# 78/78 [==============================] - 8s 108ms/step - loss: 0.8893 - accuracy: 0.7864 - val_loss: 0.8202 - val_accuracy: 0.8126
# Epoch 52/200
# 78/78 [==============================] - 8s 108ms/step - loss: 0.8823 - accuracy: 0.7889 - val_loss: 0.8072 - val_accuracy: 0.8134
# Epoch 53/200
# 78/78 [==============================] - 8s 108ms/step - loss: 0.8819 - accuracy: 0.7915 - val_loss: 0.8061 - val_accuracy: 0.8144
# Epoch 54/200
# 78/78 [==============================] - 9s 111ms/step - loss: 0.8641 - accuracy: 0.7946 - val_loss: 0.8325 - val_accuracy: 0.8039
# Epoch 55/200
# 78/78 [==============================] - 9s 109ms/step - loss: 0.8706 - accuracy: 0.7907 - val_loss: 0.8246 - val_accuracy: 0.8078
# Epoch 56/200
# 78/78 [==============================] - 8s 108ms/step - loss: 0.8605 - accuracy: 0.7963 - val_loss: 0.8508 - val_accuracy: 0.8051
# Epoch 57/200
# 78/78 [==============================] - 8s 108ms/step - loss: 0.8754 - accuracy: 0.7943 - val_loss: 0.8275 - val_accuracy: 0.8069
# Epoch 58/200
# 78/78 [==============================] - 8s 108ms/step - loss: 0.8559 - accuracy: 0.7976 - val_loss: 0.7715 - val_accuracy: 0.8294
# Epoch 59/200
# 78/78 [==============================] - 9s 109ms/step - loss: 0.8668 - accuracy: 0.7951 - val_loss: 0.8511 - val_accuracy: 0.7997
# Epoch 60/200
# 78/78 [==============================] - 9s 112ms/step - loss: 0.8687 - accuracy: 0.7954 - val_loss: 0.7843 - val_accuracy: 0.8202
# Epoch 61/200
# 78/78 [==============================] - 8s 108ms/step - loss: 0.8635 - accuracy: 0.7966 - val_loss: 0.8649 - val_accuracy: 0.7984
# Epoch 62/200
# 78/78 [==============================] - 8s 108ms/step - loss: 0.8615 - accuracy: 0.7977 - val_loss: 0.7941 - val_accuracy: 0.8224
# Epoch 63/200
# 78/78 [==============================] - 9s 109ms/step - loss: 0.8574 - accuracy: 0.8016 - val_loss: 0.7680 - val_accuracy: 0.8291
# Epoch 64/200
# 78/78 [==============================] - 8s 108ms/step - loss: 0.8415 - accuracy: 0.8030 - val_loss: 0.7845 - val_accuracy: 0.8220
# Epoch 65/200
# 78/78 [==============================] - 9s 111ms/step - loss: 0.8807 - accuracy: 0.7920 - val_loss: 0.7590 - val_accuracy: 0.8271
# Epoch 66/200
# 78/78 [==============================] - 9s 109ms/step - loss: 0.8529 - accuracy: 0.7969 - val_loss: 0.7814 - val_accuracy: 0.8269
# Epoch 67/200
# 78/78 [==============================] - 8s 107ms/step - loss: 0.8435 - accuracy: 0.8037 - val_loss: 0.7946 - val_accuracy: 0.8234
# Epoch 68/200
# 78/78 [==============================] - 8s 108ms/step - loss: 0.8368 - accuracy: 0.8047 - val_loss: 0.7289 - val_accuracy: 0.8400
# Epoch 69/200
# 78/78 [==============================] - 8s 108ms/step - loss: 0.8399 - accuracy: 0.8033 - val_loss: 0.8288 - val_accuracy: 0.8022
# Epoch 70/200
# 78/78 [==============================] - 9s 111ms/step - loss: 0.8743 - accuracy: 0.7909 - val_loss: 0.8588 - val_accuracy: 0.8015
# Epoch 71/200
# 78/78 [==============================] - 9s 111ms/step - loss: 0.8477 - accuracy: 0.8013 - val_loss: 0.7652 - val_accuracy: 0.8288
# Epoch 72/200
# 78/78 [==============================] - 8s 108ms/step - loss: 0.8311 - accuracy: 0.8043 - val_loss: 0.7842 - val_accuracy: 0.8269
# Epoch 73/200
# 78/78 [==============================] - 8s 108ms/step - loss: 0.8464 - accuracy: 0.8019 - val_loss: 0.7764 - val_accuracy: 0.8231
# Epoch 74/200
# 78/78 [==============================] - 8s 108ms/step - loss: 0.8431 - accuracy: 0.8006 - val_loss: 0.7447 - val_accuracy: 0.8398
# Epoch 75/200
# 78/78 [==============================] - 9s 111ms/step - loss: 0.8290 - accuracy: 0.8061 - val_loss: 0.7850 - val_accuracy: 0.8244
# Epoch 76/200
# 78/78 [==============================] - 9s 112ms/step - loss: 0.8363 - accuracy: 0.8040 - val_loss: 0.8359 - val_accuracy: 0.8099
# Epoch 77/200
# 78/78 [==============================] - 8s 109ms/step - loss: 0.8382 - accuracy: 0.8028 - val_loss: 0.7434 - val_accuracy: 0.8389
# Epoch 78/200
# 78/78 [==============================] - 8s 108ms/step - loss: 0.8153 - accuracy: 0.8125 - val_loss: 0.8469 - val_accuracy: 0.8028
# Epoch 79/200
# 78/78 [==============================] - 8s 109ms/step - loss: 0.8382 - accuracy: 0.8049 - val_loss: 0.7782 - val_accuracy: 0.8224
# Epoch 80/200
# 78/78 [==============================] - 8s 109ms/step - loss: 0.8179 - accuracy: 0.8104 - val_loss: 0.7868 - val_accuracy: 0.8189
# Epoch 81/200
# 78/78 [==============================] - 9s 113ms/step - loss: 0.8386 - accuracy: 0.8012 - val_loss: 0.8002 - val_accuracy: 0.8181
# Epoch 82/200
# 78/78 [==============================] - 9s 109ms/step - loss: 0.8085 - accuracy: 0.8155 - val_loss: 0.7631 - val_accuracy: 0.8246
# Epoch 83/200
# 78/78 [==============================] - 8s 108ms/step - loss: 0.8154 - accuracy: 0.8078 - val_loss: 0.8387 - val_accuracy: 0.8031
# Epoch 84/200
# 78/78 [==============================] - 9s 110ms/step - loss: 0.8300 - accuracy: 0.8053 - val_loss: 0.8230 - val_accuracy: 0.8156
# Epoch 85/200
# 78/78 [==============================] - 9s 109ms/step - loss: 0.8331 - accuracy: 0.8057 - val_loss: 0.7550 - val_accuracy: 0.8367
# Epoch 86/200
# 78/78 [==============================] - 9s 113ms/step - loss: 0.8200 - accuracy: 0.8103 - val_loss: 0.7421 - val_accuracy: 0.8351
# Epoch 87/200
# 78/78 [==============================] - 9s 110ms/step - loss: 0.8167 - accuracy: 0.8095 - val_loss: 0.7734 - val_accuracy: 0.8270
# Epoch 88/200
# 78/78 [==============================] - 8s 108ms/step - loss: 0.8215 - accuracy: 0.8099 - val_loss: 0.7911 - val_accuracy: 0.8231

# %%
elapsed_time = datetime.timedelta(seconds=(time.perf_counter() - t))

print('Tiempo de entrenamiento:', elapsed_time)
# Out:
# Tiempo de entrenamiento: 0:12:36.525096

# %% [markdown]
# ## 6. Evaluamos los resultados

# %%
_, acc = model.evaluate(x_test_scaled, y_test_encoded, verbose=0)
print('Accuracy:',' %.3f' % (acc))
# Out:
# Accuracy:  0.821

# %%
plt.title('Cross Entropy Loss')
plt.plot(history.history['loss'], color='blue', label='train')
plt.plot(history.history['val_loss'], color='orange', label='test')
plt.show()

plt.title('Classification Accuracy')
plt.plot(history.history['accuracy'], color='blue', label='train')
plt.plot(history.history['val_accuracy'], color='orange', label='test')
plt.show()

# %% [markdown]
# El coste podemos ver que es estable y es en el epoch 15 que se fija en un valor. Además la accuracy baila alrededor de 0.10. No se puede decir que sea un modelo muy bueno.
#
# Veamos que tipo de predicciones estoy obteniendo sobre el conjunto de test (vamos a pintar las imagenes y sus clasificaciones)

# %%
predictions = model.predict(x_test_scaled)

# %% [markdown]
# Una de las ventajas de Python es que hay montones de funciones y código realizado por terceras personas. Aquí me he fusilado unas bonitas funciones (que he adaptado un poco a mis necesidades) para poder pintar las imagenes, su label (ground truth) y las clasificaciones que hemos realizado.

# %%
def plot_image(i, predictions_array, true_label, img):
  predictions_array, true_label, img = predictions_array, true_label[i], img[i]
  plt.grid(False)
  plt.xticks([])
  plt.yticks([])

  plt.imshow(img, cmap=plt.cm.binary)

  predicted_label = np.argmax(predictions_array)
  if predicted_label == true_label:
    color = 'blue'
  else:
    color = 'red'

  plt.xlabel("{} {:2.0f}% ({})".format(predicted_label,
                                100*np.max(predictions_array),
                                true_label[0]),
                                color=color)

def plot_value_array(i, predictions_array, true_label):
  predictions_array, true_label = predictions_array, true_label[i]
  plt.grid(False)
  plt.xticks(range(10))
  plt.yticks([])
  thisplot = plt.bar(range(10), predictions_array, color="#777777")
  plt.ylim([0, 1])
  predicted_label = np.argmax(predictions_array)

  thisplot[predicted_label].set_color('red')
  thisplot[true_label[0]].set_color('blue')

# %% [markdown]
# Dibujamos las primeras imagenes, con las predicciones y sus valores reales (un total de 20 imagenes, para no abusar de vuestros laptops)
#
# Coloreamos las prediciones correctas en azul y los fallos en rojo. Aunque primero he impreso las etiquetas para que tengamos una referencia al grafico.

# %%
i = 0
for l in cifar10_labels:
    print(i, l)
    i += 1

num_rows = 5
num_cols = 4
start = 1000
num_images = num_rows*num_cols
plt.figure(figsize=(2*2*num_cols, 2*num_rows))
for i in range(num_images):
  plt.subplot(num_rows, 2*num_cols, 2*i+1)
  plot_image(i+start, predictions[i+start], y_test, x_test_scaled)
  plt.subplot(num_rows, 2*num_cols, 2*i+2)
  plot_value_array(i+start, predictions[i+start], y_test)
plt.tight_layout()
plt.show()
# Out:
# 0 airplane
# 1 automobile
# 2 bird
# 3 cat
# 4 deer
# 5 dog
# 6 frog
# 7 horse
# 8 ship
# 9 truck
