# %% [markdown]
# <a href="https://colab.research.google.com/github/IanPuig/SCHOOL/blob/main/da_cnn_cifar10_tf2_v0_corregido.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![Nuclio logo](https://nuclio.school/wp-content/uploads/2018/12/nucleoDS-newBlack.png)

# %% [markdown]
# ## 1. Librerias
#
# Para empezar carguemos esas librerias que nos hacen falta

# %%
import numpy as np
import time
import datetime
import random
import pandas as pd
import os

from matplotlib import pyplot as plt
from tensorflow import keras as ks
from tensorflow.keras.preprocessing.image import ImageDataGenerator, load_img
from keras.utils import to_categorical
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.regularizers import l2
from tensorflow.keras.optimizers import Adam

# %% [markdown]
# ## 2. Arquitectura de red del modelo

# %%
model = ks.Sequential()

model.add(ks.layers.Conv2D(64, (3, 3), strides=1, activation='relu', padding='same', input_shape=(32,32,3)))
model.add(ks.layers.Conv2D(64, (3, 3), strides=1, activation='relu', padding='same'))
model.add(ks.layers.Conv2D(64, (3, 3), strides=1, activation='relu', padding='same'))
model.add(ks.layers.MaxPooling2D((2, 2)))
model.add(ks.layers.Dropout(0.5)) 

model.add(ks.layers.Conv2D(128, (3, 3), strides=1, activation='relu', padding='same'))
model.add(ks.layers.Conv2D(128, (3, 3), strides=1, activation='relu', padding='same'))
model.add(ks.layers.Conv2D(128, (3, 3), strides=1, activation='relu', padding='same'))
model.add(ks.layers.MaxPooling2D((2, 2)))
model.add(ks.layers.Dropout(0.5))  

model.add(ks.layers.Conv2D(256, (3, 3), strides=1, activation='relu', padding='same'))
model.add(ks.layers.Conv2D(256, (3, 3), strides=1, activation='relu', padding='same'))
model.add(ks.layers.Conv2D(256, (3, 3), strides=1, activation='relu', padding='same'))
model.add(ks.layers.MaxPooling2D((2, 2)))
model.add(ks.layers.Dropout(0.5))  

model.add(ks.layers.Flatten())
model.add(ks.layers.Dense(512, activation='relu'))
model.add(ks.layers.Dropout(0.5))  

model.add(ks.layers.Dense(10, activation='softmax'))
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 32, 32, 64)        1792
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 32, 32, 64)        36928
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 32, 32, 64)        36928
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 16, 16, 64)        0
# _________________________________________________________________
# dropout (Dropout)            (None, 16, 16, 64)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 16, 16, 128)       73856
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 16, 16, 128)       147584
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 16, 16, 128)       147584
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 8, 8, 128)         0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 8, 8, 128)         0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 8, 8, 256)         295168
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 8, 8, 256)         590080
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 8, 8, 256)         590080
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 4, 4, 256)         0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 4, 4, 256)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 4096)              0
# _________________________________________________________________
# dense (Dense)                (None, 512)               2097664
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 10)                5130
# =================================================================
# Total params: 4,022,794
# Trainable params: 4,022,794
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# Para revisar un modelo, nos basta con llamar al método **.summary()** del modelo

# %% [markdown]
# ## 3. Optimizador, función error

# %%
model.compile(optimizer='Adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# %% [markdown]
# # 3.1 Definimos la tecnica de Early stopping mediante callbacks

# %%
callback_val_loss = EarlyStopping(monitor="val_loss", patience=20)
callback_val_accy = EarlyStopping(monitor="val_accuracy", patience=20)

# %% [markdown]
# ## 4. Preparamos los datos
#
# Cargamos los datos de CIFAR10 de los datasets directamente de las librerias de Keras. Estos ya estan dispuestos en train and test
#
# **Detalle importante:**
# > La red neuronal requiere que los inputs sean números reales, y lo haremos forzando la division de los valores de dentro de las matrices 28x28 (que tienen valoress del 0 al 255) por 255.0 (un real)

# %%
cifar10 = ks.datasets.cifar10

(x_train, y_train), (x_test, y_test) = cifar10.load_data()
x_train_scaled, x_test_scaled = x_train / 255.0, x_test / 255.0            # Descomentado por Isidre

# %%
print(y_train)
print(y_test)
# Out:
# [[6]
#  [9]
#  [9]
#  ...
#  [9]
#  [1]
#  [1]]
# [[3]
#  [8]
#  [8]
#  ...
#  [5]
#  [1]
#  [7]]

# %% [markdown]
# Obtenemos un array con todas las labels de CIFAR10

# %%
cifar10_labels = ['airplane','automobile','bird','cat','deer','dog','frog','horse','ship','truck']
print('labels: %s' % (cifar10_labels))
# Out:
# labels: ['airplane', 'automobile', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']

# %% [markdown]
# Pintemos una muestra de las imagenes del dataset CIFAR10, a ver si se parece en algo a lo que esperamos.
# Primero, vemos que tipos de datos tengo, después mapeamos esas matrices en una escala de grises utilizando el método **.get_cmap()** de PlotLy con los nueve primeros números del dataset.

# %%
# Pintemos una muestra de las las imagenes del dataset 

print('Train: X=%s, y=%s' % (x_train.shape, y_train.shape))
print('Test: X=%s, y=%s' % (x_test.shape, y_test.shape))

for i in range(9):

    plt.subplot(330 + 1 + i)
    plt.imshow(x_train[i], cmap=plt.get_cmap('gray'))
    plt.title(cifar10_labels[y_train[i,0]])

plt.subplots_adjust(hspace = 1)
plt.show()
# Out:
# Train: X=(50000, 32, 32, 3), y=(50000, 1)
# Test: X=(10000, 32, 32, 3), y=(10000, 1)

# %% [markdown]
# Como vamos a querer ir haciendo validación a la vez que entrenamos (muy practico)

# %%
x_val = x_train[-10000:]
y_val = y_train[-10000:]

x_train = x_train[:-10000]
y_train = y_train[:-10000]

# %% [markdown]
# # [Añadido por ISIDRE]

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()
le.fit(y_train)

y_train_encoded = le.transform(y_train)
y_val_encoded = le.transform(y_val)
y_test_encoded = le.transform(y_test)
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/preprocessing/_label.py:235: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.6/dist-packages/sklearn/preprocessing/_label.py:268: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
y_train_encoded
# Out:
# array([6, 9, 9, ..., 6, 2, 8])

# %% [markdown]
# # [Fin añadido por Isidre]

# %%
y_train
# Out:
# array([[6],
#        [9],
#        [9],
#        ...,
#        [6],
#        [2],
#        [8]], dtype=uint8)

# %% [markdown]
# Cuando añadimos convoluciones, necesitamos "pre-tratar los datos", porque **la convolución es pera una matriz de 4 campos** (más parecido a "imagenes"), no un array de 3 como son actualmente los data sets de train, test y validación. Así que toca darle al **.reshape()**
#
# Por eso, al salir de la Convolution, hay que hacer un Flatten, porque las capas FullDense esperan arrays, no matrices!!
#
# Luego lo imprimimos para ver que todo está correcto

# %%
# Validamos el resultado
print('Train: X=%s, y=%s' % (x_train.shape, y_train.shape))
print('Test: X=%s, y=%s' % (x_test.shape, y_test.shape))
# Out:
# Train: X=(40000, 32, 32, 3), y=(40000, 1)
# Test: X=(10000, 32, 32, 3), y=(10000, 1)

# %% [markdown]
# ## Transformador de imagenes a datos consumibles por la red neuronal

# %%
train_datagen = ImageDataGenerator( 
    rescale=1./255,
    # rotation_range = 20,
    # shear_range = 0.05,
    # zoom_range= 0.05,
    horizontal_flip=True,
    # width_shift_range=-0.01,
    # height_shift_range=-0.01,
    # brightness_range=(0.8,1.2),
    # fill_mode='nearest'
    )

train_generator = train_datagen.flow( 
    x_train, 
    y_train_encoded, 
    batch_size=512          
    )

# %% [markdown]
# ## vamos a pintarnos un ejemplo de lo que hace el train data generator

# %%
sample = random.choice(range(0,1450))
example_generator = train_datagen.flow(
    x_train[sample:sample+1],
    y_train[sample:sample+1],
    batch_size=512
    )

plt.imshow(x_train[sample])

# %%
plt.figure(figsize=(12,12))
for i in range(0,15):
    plt.subplot(5,3,i+1)
    for X, Y in example_generator:
        image = X[0]
        plt.imshow(image)
        break

plt.tight_layout()
plt.show()

# %% [markdown]
# **De validacion y de testeo**
#
# Fijaos que aquí la única modificación es un re-escalado, nada de modificaciones

# %%
validation_datagen = ImageDataGenerator(
    rescale=1./255
    )
validation_generator = validation_datagen.flow(
    x_val, 
    y_val_encoded, 
    batch_size=512
    )

test_datagen = ImageDataGenerator(
    rescale=1./255
    )
test_generator = test_datagen.flow(
    x_test, 
    y_test_encoded,
    batch_size=512
    )

# %% [markdown]
# ## 5. Entrenamiento
#
# Ya podemos ponernos a entrenar el modelo!! Ojo, que hemos de entrenar contra los datos convertidos al formato que espera la Convolution.
#
# Empezaremos con 30 epocs, es decir, 30 pasadas completas del dataset (que a su vez sera con mini-batches internamente), fijando un batch de 64
#
# El metodo .fit() nos permite, definir además si disponemos de varias CPUs, GPUs, y si queremos ir validando datos a cada fin de epoch.

# %%
t = time.perf_counter()

# %%
history = model.fit(train_generator,epochs=100,steps_per_epoch= 78,callbacks=[callback_val_loss,callback_val_accy],validation_data=validation_generator,validation_steps=20)

# history = model.fit(x_traain, y_train, epochs=200, callbacks=[callback_val_loss,callback_val_accy], batch_size= 512, validation_data=(x_val, y_val))
# Out:
# Epoch 1/100
# 78/78 [==============================] - 10s 95ms/step - loss: 2.2844 - accuracy: 0.1196 - val_loss: 2.0145 - val_accuracy: 0.2619
# Epoch 2/100
# 78/78 [==============================] - 7s 85ms/step - loss: 1.9093 - accuracy: 0.2888 - val_loss: 1.6817 - val_accuracy: 0.3731
# Epoch 3/100
# 78/78 [==============================] - 7s 86ms/step - loss: 1.6468 - accuracy: 0.3869 - val_loss: 1.5680 - val_accuracy: 0.4217
# Epoch 4/100
# 78/78 [==============================] - 7s 85ms/step - loss: 1.5192 - accuracy: 0.4338 - val_loss: 1.3834 - val_accuracy: 0.4870
# Epoch 5/100
# 78/78 [==============================] - 7s 85ms/step - loss: 1.3825 - accuracy: 0.4890 - val_loss: 1.2541 - val_accuracy: 0.5422
# Epoch 6/100
# 78/78 [==============================] - 7s 85ms/step - loss: 1.2770 - accuracy: 0.5345 - val_loss: 1.1463 - val_accuracy: 0.5898
# Epoch 7/100
# 78/78 [==============================] - 7s 85ms/step - loss: 1.1788 - accuracy: 0.5776 - val_loss: 1.2001 - val_accuracy: 0.5753
# Epoch 8/100
# 78/78 [==============================] - 7s 86ms/step - loss: 1.1194 - accuracy: 0.5958 - val_loss: 0.9899 - val_accuracy: 0.6461
# Epoch 9/100
# 78/78 [==============================] - 7s 85ms/step - loss: 1.0457 - accuracy: 0.6289 - val_loss: 0.9481 - val_accuracy: 0.6585
# Epoch 10/100
# 78/78 [==============================] - 7s 85ms/step - loss: 0.9920 - accuracy: 0.6481 - val_loss: 0.9195 - val_accuracy: 0.6768
# Epoch 11/100
# 78/78 [==============================] - 7s 85ms/step - loss: 0.9304 - accuracy: 0.6655 - val_loss: 0.8810 - val_accuracy: 0.6856
# Epoch 12/100
# 78/78 [==============================] - 7s 86ms/step - loss: 0.8794 - accuracy: 0.6880 - val_loss: 0.8487 - val_accuracy: 0.6965
# Epoch 13/100
# 78/78 [==============================] - 7s 86ms/step - loss: 0.8533 - accuracy: 0.6984 - val_loss: 0.7552 - val_accuracy: 0.7317
# Epoch 14/100
# 78/78 [==============================] - 7s 85ms/step - loss: 0.8087 - accuracy: 0.7173 - val_loss: 0.7465 - val_accuracy: 0.7361
# Epoch 15/100
# 78/78 [==============================] - 7s 85ms/step - loss: 0.7911 - accuracy: 0.7205 - val_loss: 0.7579 - val_accuracy: 0.7343
# Epoch 16/100
# 78/78 [==============================] - 7s 86ms/step - loss: 0.7483 - accuracy: 0.7382 - val_loss: 0.7246 - val_accuracy: 0.7458
# Epoch 17/100
# 78/78 [==============================] - 7s 85ms/step - loss: 0.7257 - accuracy: 0.7433 - val_loss: 0.6689 - val_accuracy: 0.7652
# Epoch 18/100
# 78/78 [==============================] - 7s 85ms/step - loss: 0.6912 - accuracy: 0.7544 - val_loss: 0.6599 - val_accuracy: 0.7674
# Epoch 19/100
# 78/78 [==============================] - 7s 86ms/step - loss: 0.6642 - accuracy: 0.7638 - val_loss: 0.6288 - val_accuracy: 0.7801
# Epoch 20/100
# 78/78 [==============================] - 7s 85ms/step - loss: 0.6538 - accuracy: 0.7725 - val_loss: 0.6573 - val_accuracy: 0.7763
# Epoch 21/100
# 78/78 [==============================] - 7s 86ms/step - loss: 0.6530 - accuracy: 0.7711 - val_loss: 0.6020 - val_accuracy: 0.7936
# Epoch 22/100
# 78/78 [==============================] - 7s 86ms/step - loss: 0.6254 - accuracy: 0.7822 - val_loss: 0.6668 - val_accuracy: 0.7725
# Epoch 23/100
# 78/78 [==============================] - 7s 86ms/step - loss: 0.5998 - accuracy: 0.7900 - val_loss: 0.6002 - val_accuracy: 0.7910
# Epoch 24/100
# 78/78 [==============================] - 7s 86ms/step - loss: 0.6023 - accuracy: 0.7921 - val_loss: 0.5536 - val_accuracy: 0.8110
# Epoch 25/100
# 78/78 [==============================] - 7s 86ms/step - loss: 0.5854 - accuracy: 0.7954 - val_loss: 0.5459 - val_accuracy: 0.8089
# Epoch 26/100
# 78/78 [==============================] - 7s 85ms/step - loss: 0.5525 - accuracy: 0.8059 - val_loss: 0.5874 - val_accuracy: 0.7995
# Epoch 27/100
# 78/78 [==============================] - 7s 85ms/step - loss: 0.5389 - accuracy: 0.8131 - val_loss: 0.5640 - val_accuracy: 0.8053
# Epoch 28/100
# 78/78 [==============================] - 7s 85ms/step - loss: 0.5487 - accuracy: 0.8100 - val_loss: 0.5313 - val_accuracy: 0.8190
# Epoch 29/100
# 78/78 [==============================] - 7s 85ms/step - loss: 0.5356 - accuracy: 0.8129 - val_loss: 0.5609 - val_accuracy: 0.8105
# Epoch 30/100
# 78/78 [==============================] - 7s 86ms/step - loss: 0.5163 - accuracy: 0.8209 - val_loss: 0.5682 - val_accuracy: 0.8132
# Epoch 31/100
# 78/78 [==============================] - 7s 86ms/step - loss: 0.5143 - accuracy: 0.8215 - val_loss: 0.5228 - val_accuracy: 0.8244
# Epoch 32/100
# 78/78 [==============================] - 7s 86ms/step - loss: 0.5163 - accuracy: 0.8222 - val_loss: 0.4935 - val_accuracy: 0.8332
# Epoch 33/100
# 78/78 [==============================] - 7s 87ms/step - loss: 0.4810 - accuracy: 0.8338 - val_loss: 0.5078 - val_accuracy: 0.8255
# Epoch 34/100
# 78/78 [==============================] - 7s 86ms/step - loss: 0.4571 - accuracy: 0.8392 - val_loss: 0.5354 - val_accuracy: 0.8178
# Epoch 35/100
# 78/78 [==============================] - 7s 86ms/step - loss: 0.4729 - accuracy: 0.8341 - val_loss: 0.5229 - val_accuracy: 0.8242
# Epoch 36/100
# 78/78 [==============================] - 7s 86ms/step - loss: 0.4882 - accuracy: 0.8283 - val_loss: 0.5056 - val_accuracy: 0.8238
# Epoch 37/100
# 78/78 [==============================] - 7s 86ms/step - loss: 0.4664 - accuracy: 0.8389 - val_loss: 0.4912 - val_accuracy: 0.8315
# Epoch 38/100
# 78/78 [==============================] - 7s 86ms/step - loss: 0.4503 - accuracy: 0.8419 - val_loss: 0.5007 - val_accuracy: 0.8320
# Epoch 39/100
# 78/78 [==============================] - 7s 86ms/step - loss: 0.4681 - accuracy: 0.8388 - val_loss: 0.5227 - val_accuracy: 0.8252
# Epoch 40/100
# 78/78 [==============================] - 7s 85ms/step - loss: 0.4430 - accuracy: 0.8460 - val_loss: 0.4785 - val_accuracy: 0.8380
# Epoch 41/100
# 78/78 [==============================] - 7s 86ms/step - loss: 0.4282 - accuracy: 0.8490 - val_loss: 0.4680 - val_accuracy: 0.8423
# Epoch 42/100
# 78/78 [==============================] - 7s 86ms/step - loss: 0.4130 - accuracy: 0.8580 - val_loss: 0.4658 - val_accuracy: 0.8387
# Epoch 43/100
# 78/78 [==============================] - 7s 86ms/step - loss: 0.4187 - accuracy: 0.8534 - val_loss: 0.4845 - val_accuracy: 0.8390
# Epoch 44/100
# 78/78 [==============================] - 7s 86ms/step - loss: 0.4157 - accuracy: 0.8564 - val_loss: 0.4865 - val_accuracy: 0.8367
# Epoch 45/100
# 78/78 [==============================] - 7s 86ms/step - loss: 0.4010 - accuracy: 0.8601 - val_loss: 0.4681 - val_accuracy: 0.8426
# Epoch 46/100
# 78/78 [==============================] - 7s 86ms/step - loss: 0.3998 - accuracy: 0.8598 - val_loss: 0.4875 - val_accuracy: 0.8358
# Epoch 47/100
# 78/78 [==============================] - 7s 85ms/step - loss: 0.4076 - accuracy: 0.8548 - val_loss: 0.4703 - val_accuracy: 0.8455
# Epoch 48/100
# 78/78 [==============================] - 7s 86ms/step - loss: 0.3907 - accuracy: 0.8637 - val_loss: 0.4585 - val_accuracy: 0.8468
# Epoch 49/100
# 78/78 [==============================] - 7s 86ms/step - loss: 0.3964 - accuracy: 0.8618 - val_loss: 0.4473 - val_accuracy: 0.8521
# Epoch 50/100
# 78/78 [==============================] - 7s 86ms/step - loss: 0.3749 - accuracy: 0.8692 - val_loss: 0.4618 - val_accuracy: 0.8476
# Epoch 51/100
# 78/78 [==============================] - 7s 86ms/step - loss: 0.3789 - accuracy: 0.8661 - val_loss: 0.4532 - val_accuracy: 0.8509
# Epoch 52/100
# 78/78 [==============================] - 7s 86ms/step - loss: 0.3675 - accuracy: 0.8689 - val_loss: 0.4869 - val_accuracy: 0.8377
# Epoch 53/100
# 78/78 [==============================] - 7s 86ms/step - loss: 0.3825 - accuracy: 0.8668 - val_loss: 0.4588 - val_accuracy: 0.8483
# Epoch 54/100
# 78/78 [==============================] - 7s 86ms/step - loss: 0.3840 - accuracy: 0.8656 - val_loss: 0.4575 - val_accuracy: 0.8549
# Epoch 55/100
# 78/78 [==============================] - 7s 86ms/step - loss: 0.3556 - accuracy: 0.8734 - val_loss: 0.4771 - val_accuracy: 0.8461
# Epoch 56/100
# 78/78 [==============================] - 7s 86ms/step - loss: 0.3550 - accuracy: 0.8776 - val_loss: 0.4608 - val_accuracy: 0.8532
# Epoch 57/100
# 78/78 [==============================] - 7s 86ms/step - loss: 0.3476 - accuracy: 0.8768 - val_loss: 0.4723 - val_accuracy: 0.8469
# Epoch 58/100
# 78/78 [==============================] - 7s 86ms/step - loss: 0.3719 - accuracy: 0.8715 - val_loss: 0.4740 - val_accuracy: 0.8441
# Epoch 59/100
# 78/78 [==============================] - 7s 87ms/step - loss: 0.3484 - accuracy: 0.8764 - val_loss: 0.4512 - val_accuracy: 0.8483
# Epoch 60/100
# 78/78 [==============================] - 7s 87ms/step - loss: 0.3491 - accuracy: 0.8763 - val_loss: 0.4499 - val_accuracy: 0.8519
# Epoch 61/100
# 78/78 [==============================] - 7s 86ms/step - loss: 0.3423 - accuracy: 0.8776 - val_loss: 0.4549 - val_accuracy: 0.8496
# Epoch 62/100
# 78/78 [==============================] - 7s 87ms/step - loss: 0.3348 - accuracy: 0.8862 - val_loss: 0.4890 - val_accuracy: 0.8463
# Epoch 63/100
# 78/78 [==============================] - 7s 85ms/step - loss: 0.3551 - accuracy: 0.8746 - val_loss: 0.4723 - val_accuracy: 0.8459
# Epoch 64/100
# 78/78 [==============================] - 7s 86ms/step - loss: 0.3337 - accuracy: 0.8813 - val_loss: 0.4524 - val_accuracy: 0.8535
# Epoch 65/100
# 78/78 [==============================] - 7s 87ms/step - loss: 0.3505 - accuracy: 0.8787 - val_loss: 0.4586 - val_accuracy: 0.8509
# Epoch 66/100
# 78/78 [==============================] - 7s 86ms/step - loss: 0.3245 - accuracy: 0.8843 - val_loss: 0.4646 - val_accuracy: 0.8534
# Epoch 67/100
# 78/78 [==============================] - 7s 86ms/step - loss: 0.3242 - accuracy: 0.8889 - val_loss: 0.4723 - val_accuracy: 0.8477
# Epoch 68/100
# 78/78 [==============================] - 7s 86ms/step - loss: 0.3378 - accuracy: 0.8820 - val_loss: 0.4400 - val_accuracy: 0.8562
# Epoch 69/100
# 78/78 [==============================] - 7s 86ms/step - loss: 0.3198 - accuracy: 0.8863 - val_loss: 0.4765 - val_accuracy: 0.8471
# Epoch 70/100
# 78/78 [==============================] - 7s 86ms/step - loss: 0.3453 - accuracy: 0.8803 - val_loss: 0.4422 - val_accuracy: 0.8551
# Epoch 71/100
# 78/78 [==============================] - 7s 86ms/step - loss: 0.3126 - accuracy: 0.8907 - val_loss: 0.4524 - val_accuracy: 0.8514
# Epoch 72/100
# 78/78 [==============================] - 7s 86ms/step - loss: 0.3291 - accuracy: 0.8843 - val_loss: 0.4532 - val_accuracy: 0.8556
# Epoch 73/100
# 78/78 [==============================] - 7s 86ms/step - loss: 0.3445 - accuracy: 0.8790 - val_loss: 0.4739 - val_accuracy: 0.8489
# Epoch 74/100
# 78/78 [==============================] - 7s 86ms/step - loss: 0.3226 - accuracy: 0.8886 - val_loss: 0.4701 - val_accuracy: 0.8543
# Epoch 75/100
# 78/78 [==============================] - 7s 87ms/step - loss: 0.3142 - accuracy: 0.8889 - val_loss: 0.4222 - val_accuracy: 0.8591
# Epoch 76/100
# 78/78 [==============================] - 7s 86ms/step - loss: 0.3080 - accuracy: 0.8896 - val_loss: 0.4505 - val_accuracy: 0.8536
# Epoch 77/100
# 78/78 [==============================] - 7s 86ms/step - loss: 0.3023 - accuracy: 0.8942 - val_loss: 0.4262 - val_accuracy: 0.8617
# Epoch 78/100
# 78/78 [==============================] - 7s 87ms/step - loss: 0.3080 - accuracy: 0.8912 - val_loss: 0.4312 - val_accuracy: 0.8605
# Epoch 79/100
# 78/78 [==============================] - 7s 87ms/step - loss: 0.3091 - accuracy: 0.8906 - val_loss: 0.4371 - val_accuracy: 0.8600
# Epoch 80/100
# 78/78 [==============================] - 7s 87ms/step - loss: 0.3090 - accuracy: 0.8931 - val_loss: 0.4600 - val_accuracy: 0.8573
# Epoch 81/100
# 78/78 [==============================] - 7s 86ms/step - loss: 0.3032 - accuracy: 0.8919 - val_loss: 0.4676 - val_accuracy: 0.8586
# Epoch 82/100
# 78/78 [==============================] - 7s 86ms/step - loss: 0.2843 - accuracy: 0.8994 - val_loss: 0.4615 - val_accuracy: 0.8565
# Epoch 83/100
# 78/78 [==============================] - 7s 87ms/step - loss: 0.2968 - accuracy: 0.8953 - val_loss: 0.4539 - val_accuracy: 0.8594
# Epoch 84/100
# 78/78 [==============================] - 7s 88ms/step - loss: 0.2960 - accuracy: 0.8956 - val_loss: 0.4316 - val_accuracy: 0.8618
# Epoch 85/100
# 78/78 [==============================] - 7s 87ms/step - loss: 0.2824 - accuracy: 0.9008 - val_loss: 0.4232 - val_accuracy: 0.8655
# Epoch 86/100
# 78/78 [==============================] - 7s 86ms/step - loss: 0.2960 - accuracy: 0.8962 - val_loss: 0.4338 - val_accuracy: 0.8581
# Epoch 87/100
# 78/78 [==============================] - 7s 87ms/step - loss: 0.2849 - accuracy: 0.8994 - val_loss: 0.4296 - val_accuracy: 0.8685
# Epoch 88/100
# 78/78 [==============================] - 7s 86ms/step - loss: 0.2824 - accuracy: 0.8997 - val_loss: 0.4376 - val_accuracy: 0.8644
# Epoch 89/100
# 78/78 [==============================] - 7s 86ms/step - loss: 0.2717 - accuracy: 0.9042 - val_loss: 0.4409 - val_accuracy: 0.8656
# Epoch 90/100
# 78/78 [==============================] - 7s 86ms/step - loss: 0.2818 - accuracy: 0.9000 - val_loss: 0.4426 - val_accuracy: 0.8662
# Epoch 91/100
# 78/78 [==============================] - 7s 87ms/step - loss: 0.2766 - accuracy: 0.9028 - val_loss: 0.4573 - val_accuracy: 0.8534
# Epoch 92/100
# 78/78 [==============================] - 7s 87ms/step - loss: 0.3053 - accuracy: 0.8933 - val_loss: 0.4190 - val_accuracy: 0.8655
# Epoch 93/100
# 78/78 [==============================] - 7s 87ms/step - loss: 0.2724 - accuracy: 0.9039 - val_loss: 0.4308 - val_accuracy: 0.8652
# Epoch 94/100
# 78/78 [==============================] - 7s 87ms/step - loss: 0.2878 - accuracy: 0.8996 - val_loss: 0.4407 - val_accuracy: 0.8608
# Epoch 95/100
# 78/78 [==============================] - 7s 86ms/step - loss: 0.2774 - accuracy: 0.9047 - val_loss: 0.4227 - val_accuracy: 0.8682
# Epoch 96/100
# 78/78 [==============================] - 7s 86ms/step - loss: 0.2656 - accuracy: 0.9068 - val_loss: 0.4517 - val_accuracy: 0.8620
# Epoch 97/100
# 78/78 [==============================] - 7s 87ms/step - loss: 0.2712 - accuracy: 0.9042 - val_loss: 0.4401 - val_accuracy: 0.8645
# Epoch 98/100
# 78/78 [==============================] - 7s 87ms/step - loss: 0.2749 - accuracy: 0.9015 - val_loss: 0.4480 - val_accuracy: 0.8630
# Epoch 99/100
# 78/78 [==============================] - 7s 87ms/step - loss: 0.2708 - accuracy: 0.9038 - val_loss: 0.4442 - val_accuracy: 0.8642
# Epoch 100/100
# 78/78 [==============================] - 7s 87ms/step - loss: 0.2733 - accuracy: 0.9041 - val_loss: 0.4457 - val_accuracy: 0.8650

# %%
elapsed_time = datetime.timedelta(seconds=(time.perf_counter() - t))

print('Tiempo de entrenamiento:', elapsed_time)
# Out:
# Tiempo de entrenamiento: 0:11:16.591488

# %% [markdown]
# ## 6. Evaluamos los resultados

# %%
_, acc = model.evaluate(x_test_scaled, y_test_encoded, verbose=0)
print('Accuracy:',' %.3f' % (acc))
# Out:
# Accuracy:  0.860

# %%
plt.title('Cross Entropy Loss')
plt.plot(history.history['loss'], color='blue', label='train')
plt.plot(history.history['val_loss'], color='orange', label='test')
plt.show()

plt.title('Classification Accuracy')
plt.plot(history.history['accuracy'], color='blue', label='train')
plt.plot(history.history['val_accuracy'], color='orange', label='test')
plt.show()

# %% [markdown]
# El coste podemos ver que es estable y es en el epoch 15 que se fija en un valor. Además la accuracy baila alrededor de 0.10. No se puede decir que sea un modelo muy bueno.
#
# Veamos que tipo de predicciones estoy obteniendo sobre el conjunto de test (vamos a pintar las imagenes y sus clasificaciones)

# %%
predictions = model.predict(x_test_scaled)

# %% [markdown]
# Una de las ventajas de Python es que hay montones de funciones y código realizado por terceras personas. Aquí me he fusilado unas bonitas funciones (que he adaptado un poco a mis necesidades) para poder pintar las imagenes, su label (ground truth) y las clasificaciones que hemos realizado.

# %%
def plot_image(i, predictions_array, true_label, img):
  predictions_array, true_label, img = predictions_array, true_label[i], img[i]
  plt.grid(False)
  plt.xticks([])
  plt.yticks([])

  plt.imshow(img, cmap=plt.cm.binary)

  predicted_label = np.argmax(predictions_array)
  if predicted_label == true_label:
    color = 'blue'
  else:
    color = 'red'

  plt.xlabel("{} {:2.0f}% ({})".format(predicted_label,
                                100*np.max(predictions_array),
                                true_label[0]),
                                color=color)

def plot_value_array(i, predictions_array, true_label):
  predictions_array, true_label = predictions_array, true_label[i]
  plt.grid(False)
  plt.xticks(range(10))
  plt.yticks([])
  thisplot = plt.bar(range(10), predictions_array, color="#777777")
  plt.ylim([0, 1])
  predicted_label = np.argmax(predictions_array)

  thisplot[predicted_label].set_color('red')
  thisplot[true_label[0]].set_color('blue')

# %% [markdown]
# Dibujamos las primeras imagenes, con las predicciones y sus valores reales (un total de 20 imagenes, para no abusar de vuestros laptops)
#
# Coloreamos las prediciones correctas en azul y los fallos en rojo. Aunque primero he impreso las etiquetas para que tengamos una referencia al grafico.

# %%
i = 0
for l in cifar10_labels:
    print(i, l)
    i += 1

num_rows = 5
num_cols = 4
start = 1000
num_images = num_rows*num_cols
plt.figure(figsize=(2*2*num_cols, 2*num_rows))
for i in range(num_images):
  plt.subplot(num_rows, 2*num_cols, 2*i+1)
  plot_image(i+start, predictions[i+start], y_test, x_test_scaled)
  plt.subplot(num_rows, 2*num_cols, 2*i+2)
  plot_value_array(i+start, predictions[i+start], y_test)
plt.tight_layout()
plt.show()
# Out:
# 0 airplane
# 1 automobile
# 2 bird
# 3 cat
# 4 deer
# 5 dog
# 6 frog
# 7 horse
# 8 ship
# 9 truck
