# %% [markdown]
# <a href="https://colab.research.google.com/github/IanPuig/SCHOOL/blob/main/da_cnn_cifar10_tf2_v0_corregido.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![Nuclio logo](https://nuclio.school/wp-content/uploads/2018/12/nucleoDS-newBlack.png)

# %% [markdown]
# ## 1. Librerias
#
# Para empezar carguemos esas librerias que nos hacen falta

# %%
import numpy as np
import time
import datetime
import random
import pandas as pd
import os

from matplotlib import pyplot as plt
from tensorflow import keras as ks
from tensorflow.keras.preprocessing.image import ImageDataGenerator, load_img
from keras.utils import to_categorical
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.regularizers import l2
from tensorflow.keras.optimizers import Adam

# %% [markdown]
# ## 2. Arquitectura de red del modelo

# %%
model = ks.Sequential()

model.add(ks.layers.Conv2D(128, (3, 3), strides=1, activation='relu', padding='same', input_shape=(32,32,3)))
model.add(ks.layers.Conv2D(128, (3, 3), strides=1, activation='relu', padding='same'))
model.add(ks.layers.MaxPooling2D((2, 2)))
model.add(ks.layers.Dropout(0.5))  

model.add(ks.layers.Conv2D(256, (3, 3), strides=1, activation='relu', padding='same', input_shape=(32,32,3)))
model.add(ks.layers.Conv2D(256, (3, 3), strides=1, activation='relu', padding='same'))
model.add(ks.layers.MaxPooling2D((2, 2)))
model.add(ks.layers.Dropout(0.5))  

model.add(ks.layers.Flatten())
model.add(ks.layers.Dense(256, activation='relu'))
model.add(ks.layers.Dropout(0.5))  

model.add(ks.layers.Dense(10, activation='softmax'))
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 32, 32, 128)       3584
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 32, 32, 128)       147584
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 16, 16, 128)       0
# _________________________________________________________________
# dropout (Dropout)            (None, 16, 16, 128)       0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 16, 16, 256)       295168
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 16, 16, 256)       590080
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 8, 8, 256)         0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 8, 8, 256)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 16384)             0
# _________________________________________________________________
# dense (Dense)                (None, 256)               4194560
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 10)                2570
# =================================================================
# Total params: 5,233,546
# Trainable params: 5,233,546
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# Para revisar un modelo, nos basta con llamar al método **.summary()** del modelo

# %% [markdown]
# ## 3. Optimizador, función error

# %%
model.compile(optimizer='Adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# %% [markdown]
# # 3.1 Definimos la tecnica de Early stopping mediante callbacks

# %%
callback_val_loss = EarlyStopping(monitor="val_loss", patience=20)
callback_val_accy = EarlyStopping(monitor="val_accuracy", patience=20)

# %% [markdown]
# ## 4. Preparamos los datos
#
# Cargamos los datos de CIFAR10 de los datasets directamente de las librerias de Keras. Estos ya estan dispuestos en train and test
#
# **Detalle importante:**
# > La red neuronal requiere que los inputs sean números reales, y lo haremos forzando la division de los valores de dentro de las matrices 28x28 (que tienen valoress del 0 al 255) por 255.0 (un real)

# %%
cifar10 = ks.datasets.cifar10

(x_train, y_train), (x_test, y_test) = cifar10.load_data()
x_train_scaled, x_test_scaled = x_train / 255.0, x_test / 255.0            # Descomentado por Isidre

# %%
print(y_train)
print(y_test)
# Out:
# [[6]
#  [9]
#  [9]
#  ...
#  [9]
#  [1]
#  [1]]
# [[3]
#  [8]
#  [8]
#  ...
#  [5]
#  [1]
#  [7]]

# %% [markdown]
# Obtenemos un array con todas las labels de CIFAR10

# %%
cifar10_labels = ['airplane','automobile','bird','cat','deer','dog','frog','horse','ship','truck']
print('labels: %s' % (cifar10_labels))
# Out:
# labels: ['airplane', 'automobile', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']

# %% [markdown]
# Pintemos una muestra de las imagenes del dataset CIFAR10, a ver si se parece en algo a lo que esperamos.
# Primero, vemos que tipos de datos tengo, después mapeamos esas matrices en una escala de grises utilizando el método **.get_cmap()** de PlotLy con los nueve primeros números del dataset.

# %%
# Pintemos una muestra de las las imagenes del dataset 

print('Train: X=%s, y=%s' % (x_train.shape, y_train.shape))
print('Test: X=%s, y=%s' % (x_test.shape, y_test.shape))

for i in range(9):

    plt.subplot(330 + 1 + i)
    plt.imshow(x_train[i], cmap=plt.get_cmap('gray'))
    plt.title(cifar10_labels[y_train[i,0]])

plt.subplots_adjust(hspace = 1)
plt.show()
# Out:
# Train: X=(50000, 32, 32, 3), y=(50000, 1)
# Test: X=(10000, 32, 32, 3), y=(10000, 1)

# %% [markdown]
# Como vamos a querer ir haciendo validación a la vez que entrenamos (muy practico)

# %%
x_val = x_train[-10000:]
y_val = y_train[-10000:]

x_train = x_train[:-10000]
y_train = y_train[:-10000]

# %% [markdown]
# # [Añadido por ISIDRE]

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()
le.fit(y_train)

y_train_encoded = le.transform(y_train)
y_val_encoded = le.transform(y_val)
y_test_encoded = le.transform(y_test)
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/preprocessing/_label.py:235: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.6/dist-packages/sklearn/preprocessing/_label.py:268: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
y_train_encoded
# Out:
# array([6, 9, 9, ..., 6, 2, 8])

# %% [markdown]
# # [Fin añadido por Isidre]

# %%
y_train
# Out:
# array([[6],
#        [9],
#        [9],
#        ...,
#        [6],
#        [2],
#        [8]], dtype=uint8)

# %% [markdown]
# Cuando añadimos convoluciones, necesitamos "pre-tratar los datos", porque **la convolución es pera una matriz de 4 campos** (más parecido a "imagenes"), no un array de 3 como son actualmente los data sets de train, test y validación. Así que toca darle al **.reshape()**
#
# Por eso, al salir de la Convolution, hay que hacer un Flatten, porque las capas FullDense esperan arrays, no matrices!!
#
# Luego lo imprimimos para ver que todo está correcto

# %%
# Validamos el resultado
print('Train: X=%s, y=%s' % (x_train.shape, y_train.shape))
print('Test: X=%s, y=%s' % (x_test.shape, y_test.shape))
# Out:
# Train: X=(40000, 32, 32, 3), y=(40000, 1)
# Test: X=(10000, 32, 32, 3), y=(10000, 1)

# %% [markdown]
# ## Transformador de imagenes a datos consumibles por la red neuronal

# %%
train_datagen = ImageDataGenerator( 
    rescale=1./255,
    # rotation_range = 20,
    # shear_range = 0.05,
    # zoom_range= 0.05,
    horizontal_flip=True,
    # width_shift_range=-0.01,
    # height_shift_range=-0.01,
    # brightness_range=(0.8,1.2),
    # fill_mode='nearest'
    )

# debemos coger las imagenes originales, le doy la x, le doy la y 
# y el batch size = cuantas imagenes voy a generar por cada paquete, data generation (no podemos pasarnos, misma cantidad que le pasamos en eel data set)

train_generator = train_datagen.flow( 
    x_train, 
    y_train_encoded, 
    batch_size=512          # hago esto para cada 30 imagenes
    )

# %% [markdown]
# ## vamos a pintarnos un ejemplo de lo que hace el train data generator

# %%
sample = random.choice(range(0,1450))
example_generator = train_datagen.flow(
    x_train[sample:sample+1],
    y_train[sample:sample+1],
    batch_size=512
    )

plt.imshow(x_train[sample])

# %%
plt.figure(figsize=(12,12))
for i in range(0,15):
    plt.subplot(5,3,i+1)
    for X, Y in example_generator:
        image = X[0]
        plt.imshow(image)
        break

plt.tight_layout()
plt.show()

# %% [markdown]
# **De validacion y de testeo**
#
# Fijaos que aquí la única modificación es un re-escalado, nada de modificaciones

# %%
validation_datagen = ImageDataGenerator(
    rescale=1./255
    )
validation_generator = validation_datagen.flow(
    x_val, 
    y_val_encoded, 
    batch_size=512
    )

test_datagen = ImageDataGenerator(
    rescale=1./255
    )
test_generator = test_datagen.flow(
    x_test, 
    y_test_encoded,
    batch_size=512
    )

# %% [markdown]
# ## 5. Entrenamiento
#
# Ya podemos ponernos a entrenar el modelo!! Ojo, que hemos de entrenar contra los datos convertidos al formato que espera la Convolution.
#
# Empezaremos con 30 epocs, es decir, 30 pasadas completas del dataset (que a su vez sera con mini-batches internamente), fijando un batch de 64
#
# El metodo .fit() nos permite, definir además si disponemos de varias CPUs, GPUs, y si queremos ir validando datos a cada fin de epoch.

# %%
t = time.perf_counter()

# %%
history = model.fit(train_generator,epochs=100,steps_per_epoch= 78,callbacks=[callback_val_loss,callback_val_accy],validation_data=validation_generator,validation_steps=20)

# history = model.fit(x_traain, y_train, epochs=200, callbacks=[callback_val_loss,callback_val_accy], batch_size= 512, validation_data=(x_val, y_val))
# Out:
# Epoch 1/100
# 78/78 [==============================] - 18s 181ms/step - loss: 2.1379 - accuracy: 0.1928 - val_loss: 1.6331 - val_accuracy: 0.4038
# Epoch 2/100
# 78/78 [==============================] - 13s 169ms/step - loss: 1.6288 - accuracy: 0.4053 - val_loss: 1.3516 - val_accuracy: 0.5100
# Epoch 3/100
# 78/78 [==============================] - 13s 169ms/step - loss: 1.3910 - accuracy: 0.4898 - val_loss: 1.1508 - val_accuracy: 0.5865
# Epoch 4/100
# 78/78 [==============================] - 13s 168ms/step - loss: 1.1954 - accuracy: 0.5724 - val_loss: 1.0326 - val_accuracy: 0.6301
# Epoch 5/100
# 78/78 [==============================] - 13s 165ms/step - loss: 1.1235 - accuracy: 0.6024 - val_loss: 0.9396 - val_accuracy: 0.6714
# Epoch 6/100
# 78/78 [==============================] - 13s 166ms/step - loss: 1.0458 - accuracy: 0.6261 - val_loss: 0.9306 - val_accuracy: 0.6777
# Epoch 7/100
# 78/78 [==============================] - 13s 166ms/step - loss: 0.9589 - accuracy: 0.6582 - val_loss: 0.8299 - val_accuracy: 0.7058
# Epoch 8/100
# 78/78 [==============================] - 13s 167ms/step - loss: 0.9113 - accuracy: 0.6773 - val_loss: 0.7617 - val_accuracy: 0.7327
# Epoch 9/100
# 78/78 [==============================] - 13s 167ms/step - loss: 0.8717 - accuracy: 0.6927 - val_loss: 0.7575 - val_accuracy: 0.7365
# Epoch 10/100
# 78/78 [==============================] - 13s 167ms/step - loss: 0.8216 - accuracy: 0.7113 - val_loss: 0.7199 - val_accuracy: 0.7457
# Epoch 11/100
# 78/78 [==============================] - 13s 166ms/step - loss: 0.7974 - accuracy: 0.7226 - val_loss: 0.6991 - val_accuracy: 0.7529
# Epoch 12/100
# 78/78 [==============================] - 13s 166ms/step - loss: 0.7599 - accuracy: 0.7354 - val_loss: 0.6625 - val_accuracy: 0.7634
# Epoch 13/100
# 78/78 [==============================] - 13s 166ms/step - loss: 0.7419 - accuracy: 0.7403 - val_loss: 0.6622 - val_accuracy: 0.7680
# Epoch 14/100
# 78/78 [==============================] - 13s 167ms/step - loss: 0.7176 - accuracy: 0.7466 - val_loss: 0.6315 - val_accuracy: 0.7805
# Epoch 15/100
# 78/78 [==============================] - 13s 167ms/step - loss: 0.7006 - accuracy: 0.7542 - val_loss: 0.6350 - val_accuracy: 0.7772
# Epoch 16/100
# 78/78 [==============================] - 13s 166ms/step - loss: 0.6820 - accuracy: 0.7606 - val_loss: 0.6132 - val_accuracy: 0.7846
# Epoch 17/100
# 78/78 [==============================] - 13s 167ms/step - loss: 0.6732 - accuracy: 0.7652 - val_loss: 0.6123 - val_accuracy: 0.7856
# Epoch 18/100
# 78/78 [==============================] - 13s 166ms/step - loss: 0.6570 - accuracy: 0.7693 - val_loss: 0.5851 - val_accuracy: 0.7957
# Epoch 19/100
# 78/78 [==============================] - 13s 167ms/step - loss: 0.6456 - accuracy: 0.7758 - val_loss: 0.5855 - val_accuracy: 0.7923
# Epoch 20/100
# 78/78 [==============================] - 13s 166ms/step - loss: 0.6299 - accuracy: 0.7785 - val_loss: 0.5598 - val_accuracy: 0.8021
# Epoch 21/100
# 78/78 [==============================] - 13s 167ms/step - loss: 0.6201 - accuracy: 0.7803 - val_loss: 0.5750 - val_accuracy: 0.7973
# Epoch 22/100
# 78/78 [==============================] - 13s 167ms/step - loss: 0.5997 - accuracy: 0.7894 - val_loss: 0.5632 - val_accuracy: 0.8042
# Epoch 23/100
# 78/78 [==============================] - 13s 168ms/step - loss: 0.5908 - accuracy: 0.7908 - val_loss: 0.5432 - val_accuracy: 0.8083
# Epoch 24/100
# 78/78 [==============================] - 13s 166ms/step - loss: 0.5606 - accuracy: 0.8009 - val_loss: 0.5431 - val_accuracy: 0.8127
# Epoch 25/100
# 78/78 [==============================] - 13s 166ms/step - loss: 0.5734 - accuracy: 0.7983 - val_loss: 0.5587 - val_accuracy: 0.8087
# Epoch 26/100
# 78/78 [==============================] - 13s 167ms/step - loss: 0.5655 - accuracy: 0.8019 - val_loss: 0.5303 - val_accuracy: 0.8171
# Epoch 27/100
# 78/78 [==============================] - 13s 166ms/step - loss: 0.5554 - accuracy: 0.8070 - val_loss: 0.5524 - val_accuracy: 0.8122
# Epoch 28/100
# 78/78 [==============================] - 13s 166ms/step - loss: 0.5502 - accuracy: 0.8062 - val_loss: 0.5125 - val_accuracy: 0.8221
# Epoch 29/100
# 78/78 [==============================] - 13s 166ms/step - loss: 0.5482 - accuracy: 0.8047 - val_loss: 0.5128 - val_accuracy: 0.8248
# Epoch 30/100
# 78/78 [==============================] - 13s 166ms/step - loss: 0.5332 - accuracy: 0.8106 - val_loss: 0.5021 - val_accuracy: 0.8294
# Epoch 31/100
# 78/78 [==============================] - 13s 167ms/step - loss: 0.5185 - accuracy: 0.8177 - val_loss: 0.4942 - val_accuracy: 0.8309
# Epoch 32/100
# 78/78 [==============================] - 13s 166ms/step - loss: 0.5209 - accuracy: 0.8178 - val_loss: 0.5229 - val_accuracy: 0.8207
# Epoch 33/100
# 78/78 [==============================] - 13s 166ms/step - loss: 0.4958 - accuracy: 0.8235 - val_loss: 0.5022 - val_accuracy: 0.8267
# Epoch 34/100
# 78/78 [==============================] - 13s 166ms/step - loss: 0.4965 - accuracy: 0.8263 - val_loss: 0.5083 - val_accuracy: 0.8247
# Epoch 35/100
# 78/78 [==============================] - 13s 166ms/step - loss: 0.5119 - accuracy: 0.8197 - val_loss: 0.4885 - val_accuracy: 0.8345
# Epoch 36/100
# 78/78 [==============================] - 13s 166ms/step - loss: 0.4965 - accuracy: 0.8242 - val_loss: 0.4852 - val_accuracy: 0.8356
# Epoch 37/100
# 78/78 [==============================] - 13s 166ms/step - loss: 0.4746 - accuracy: 0.8301 - val_loss: 0.4962 - val_accuracy: 0.8299
# Epoch 38/100
# 78/78 [==============================] - 13s 166ms/step - loss: 0.4834 - accuracy: 0.8295 - val_loss: 0.4824 - val_accuracy: 0.8386
# Epoch 39/100
# 78/78 [==============================] - 13s 166ms/step - loss: 0.4721 - accuracy: 0.8341 - val_loss: 0.4946 - val_accuracy: 0.8328
# Epoch 40/100
# 78/78 [==============================] - 13s 166ms/step - loss: 0.4679 - accuracy: 0.8354 - val_loss: 0.4841 - val_accuracy: 0.8391
# Epoch 41/100
# 78/78 [==============================] - 13s 166ms/step - loss: 0.4601 - accuracy: 0.8384 - val_loss: 0.4832 - val_accuracy: 0.8357
# Epoch 42/100
# 78/78 [==============================] - 13s 166ms/step - loss: 0.4574 - accuracy: 0.8391 - val_loss: 0.4801 - val_accuracy: 0.8388
# Epoch 43/100
# 78/78 [==============================] - 13s 166ms/step - loss: 0.4365 - accuracy: 0.8432 - val_loss: 0.4891 - val_accuracy: 0.8367
# Epoch 44/100
# 78/78 [==============================] - 13s 166ms/step - loss: 0.4553 - accuracy: 0.8414 - val_loss: 0.4671 - val_accuracy: 0.8439
# Epoch 45/100
# 78/78 [==============================] - 13s 166ms/step - loss: 0.4384 - accuracy: 0.8439 - val_loss: 0.4806 - val_accuracy: 0.8391
# Epoch 46/100
# 78/78 [==============================] - 13s 166ms/step - loss: 0.4425 - accuracy: 0.8460 - val_loss: 0.4835 - val_accuracy: 0.8359
# Epoch 47/100
# 78/78 [==============================] - 13s 167ms/step - loss: 0.4288 - accuracy: 0.8472 - val_loss: 0.4597 - val_accuracy: 0.8419
# Epoch 48/100
# 78/78 [==============================] - 13s 166ms/step - loss: 0.4240 - accuracy: 0.8499 - val_loss: 0.4686 - val_accuracy: 0.8446
# Epoch 49/100
# 78/78 [==============================] - 13s 166ms/step - loss: 0.4160 - accuracy: 0.8539 - val_loss: 0.4676 - val_accuracy: 0.8417
# Epoch 50/100
# 78/78 [==============================] - 13s 166ms/step - loss: 0.4172 - accuracy: 0.8504 - val_loss: 0.4586 - val_accuracy: 0.8457
# Epoch 51/100
# 78/78 [==============================] - 13s 166ms/step - loss: 0.4087 - accuracy: 0.8544 - val_loss: 0.4642 - val_accuracy: 0.8437
# Epoch 52/100
# 78/78 [==============================] - 13s 167ms/step - loss: 0.4122 - accuracy: 0.8536 - val_loss: 0.4696 - val_accuracy: 0.8436
# Epoch 53/100
# 78/78 [==============================] - 13s 166ms/step - loss: 0.4047 - accuracy: 0.8545 - val_loss: 0.4647 - val_accuracy: 0.8441
# Epoch 54/100
# 78/78 [==============================] - 13s 166ms/step - loss: 0.4097 - accuracy: 0.8553 - val_loss: 0.5236 - val_accuracy: 0.8275
# Epoch 55/100
# 78/78 [==============================] - 13s 167ms/step - loss: 0.4234 - accuracy: 0.8500 - val_loss: 0.4660 - val_accuracy: 0.8450
# Epoch 56/100
# 78/78 [==============================] - 13s 166ms/step - loss: 0.3943 - accuracy: 0.8609 - val_loss: 0.4673 - val_accuracy: 0.8423
# Epoch 57/100
# 78/78 [==============================] - 13s 166ms/step - loss: 0.3902 - accuracy: 0.8593 - val_loss: 0.4714 - val_accuracy: 0.8417
# Epoch 58/100
# 78/78 [==============================] - 13s 166ms/step - loss: 0.4031 - accuracy: 0.8553 - val_loss: 0.4646 - val_accuracy: 0.8440
# Epoch 59/100
# 78/78 [==============================] - 13s 166ms/step - loss: 0.3877 - accuracy: 0.8625 - val_loss: 0.4703 - val_accuracy: 0.8446
# Epoch 60/100
# 78/78 [==============================] - 13s 166ms/step - loss: 0.3789 - accuracy: 0.8662 - val_loss: 0.4687 - val_accuracy: 0.8462
# Epoch 61/100
# 78/78 [==============================] - 13s 166ms/step - loss: 0.3808 - accuracy: 0.8641 - val_loss: 0.4488 - val_accuracy: 0.8501
# Epoch 62/100
# 78/78 [==============================] - 13s 166ms/step - loss: 0.3759 - accuracy: 0.8673 - val_loss: 0.4524 - val_accuracy: 0.8506
# Epoch 63/100
# 78/78 [==============================] - 13s 166ms/step - loss: 0.3636 - accuracy: 0.8714 - val_loss: 0.4571 - val_accuracy: 0.8492
# Epoch 64/100
# 78/78 [==============================] - 13s 165ms/step - loss: 0.3803 - accuracy: 0.8658 - val_loss: 0.4593 - val_accuracy: 0.8513
# Epoch 65/100
# 78/78 [==============================] - 13s 166ms/step - loss: 0.3646 - accuracy: 0.8687 - val_loss: 0.4637 - val_accuracy: 0.8502
# Epoch 66/100
# 78/78 [==============================] - 13s 166ms/step - loss: 0.3674 - accuracy: 0.8678 - val_loss: 0.4685 - val_accuracy: 0.8451
# Epoch 67/100
# 78/78 [==============================] - 13s 167ms/step - loss: 0.3549 - accuracy: 0.8741 - val_loss: 0.4486 - val_accuracy: 0.8540
# Epoch 68/100
# 78/78 [==============================] - 13s 166ms/step - loss: 0.3703 - accuracy: 0.8673 - val_loss: 0.4601 - val_accuracy: 0.8480
# Epoch 69/100
# 78/78 [==============================] - 13s 166ms/step - loss: 0.3561 - accuracy: 0.8731 - val_loss: 0.4574 - val_accuracy: 0.8531
# Epoch 70/100
# 78/78 [==============================] - 13s 166ms/step - loss: 0.3415 - accuracy: 0.8785 - val_loss: 0.4537 - val_accuracy: 0.8542
# Epoch 71/100
# 78/78 [==============================] - 13s 166ms/step - loss: 0.3586 - accuracy: 0.8756 - val_loss: 0.4681 - val_accuracy: 0.8509
# Epoch 72/100
# 78/78 [==============================] - 13s 166ms/step - loss: 0.3447 - accuracy: 0.8781 - val_loss: 0.4564 - val_accuracy: 0.8531
# Epoch 73/100
# 78/78 [==============================] - 13s 166ms/step - loss: 0.3406 - accuracy: 0.8788 - val_loss: 0.4520 - val_accuracy: 0.8549
# Epoch 74/100
# 78/78 [==============================] - 13s 166ms/step - loss: 0.3373 - accuracy: 0.8776 - val_loss: 0.4610 - val_accuracy: 0.8514
# Epoch 75/100
# 78/78 [==============================] - 13s 166ms/step - loss: 0.3394 - accuracy: 0.8783 - val_loss: 0.4531 - val_accuracy: 0.8562
# Epoch 76/100
# 78/78 [==============================] - 13s 166ms/step - loss: 0.3333 - accuracy: 0.8801 - val_loss: 0.4421 - val_accuracy: 0.8573
# Epoch 77/100
# 78/78 [==============================] - 13s 166ms/step - loss: 0.3412 - accuracy: 0.8785 - val_loss: 0.4545 - val_accuracy: 0.8563
# Epoch 78/100
# 78/78 [==============================] - 13s 166ms/step - loss: 0.3331 - accuracy: 0.8822 - val_loss: 0.4729 - val_accuracy: 0.8495
# Epoch 79/100
# 78/78 [==============================] - 13s 166ms/step - loss: 0.3329 - accuracy: 0.8828 - val_loss: 0.4634 - val_accuracy: 0.8560
# Epoch 80/100
# 78/78 [==============================] - 13s 166ms/step - loss: 0.3349 - accuracy: 0.8823 - val_loss: 0.4547 - val_accuracy: 0.8577
# Epoch 81/100
# 78/78 [==============================] - 13s 166ms/step - loss: 0.3295 - accuracy: 0.8823 - val_loss: 0.4491 - val_accuracy: 0.8553
# Epoch 82/100
# 78/78 [==============================] - 13s 166ms/step - loss: 0.3244 - accuracy: 0.8846 - val_loss: 0.4756 - val_accuracy: 0.8525
# Epoch 83/100
# 78/78 [==============================] - 13s 166ms/step - loss: 0.3161 - accuracy: 0.8864 - val_loss: 0.4503 - val_accuracy: 0.8583
# Epoch 84/100
# 78/78 [==============================] - 13s 166ms/step - loss: 0.3199 - accuracy: 0.8885 - val_loss: 0.4584 - val_accuracy: 0.8574
# Epoch 85/100
# 78/78 [==============================] - 13s 166ms/step - loss: 0.3100 - accuracy: 0.8910 - val_loss: 0.4691 - val_accuracy: 0.8518
# Epoch 86/100
# 78/78 [==============================] - 13s 166ms/step - loss: 0.3257 - accuracy: 0.8844 - val_loss: 0.4761 - val_accuracy: 0.8494
# Epoch 87/100
# 78/78 [==============================] - 13s 166ms/step - loss: 0.3128 - accuracy: 0.8873 - val_loss: 0.4475 - val_accuracy: 0.8543
# Epoch 88/100
# 78/78 [==============================] - 13s 166ms/step - loss: 0.3028 - accuracy: 0.8931 - val_loss: 0.4525 - val_accuracy: 0.8548
# Epoch 89/100
# 78/78 [==============================] - 13s 166ms/step - loss: 0.3099 - accuracy: 0.8874 - val_loss: 0.4863 - val_accuracy: 0.8495
# Epoch 90/100
# 78/78 [==============================] - 13s 166ms/step - loss: 0.3208 - accuracy: 0.8852 - val_loss: 0.4757 - val_accuracy: 0.8563
# Epoch 91/100
# 78/78 [==============================] - 13s 167ms/step - loss: 0.3162 - accuracy: 0.8842 - val_loss: 0.4659 - val_accuracy: 0.8549
# Epoch 92/100
# 78/78 [==============================] - 13s 166ms/step - loss: 0.2969 - accuracy: 0.8950 - val_loss: 0.4678 - val_accuracy: 0.8560
# Epoch 93/100
# 78/78 [==============================] - 13s 166ms/step - loss: 0.3121 - accuracy: 0.8862 - val_loss: 0.4542 - val_accuracy: 0.8605
# Epoch 94/100
# 78/78 [==============================] - 13s 166ms/step - loss: 0.2921 - accuracy: 0.8949 - val_loss: 0.4905 - val_accuracy: 0.8490
# Epoch 95/100
# 78/78 [==============================] - 13s 166ms/step - loss: 0.3047 - accuracy: 0.8893 - val_loss: 0.4642 - val_accuracy: 0.8588
# Epoch 96/100
# 78/78 [==============================] - 13s 166ms/step - loss: 0.2944 - accuracy: 0.8937 - val_loss: 0.4769 - val_accuracy: 0.8563

# %%
elapsed_time = datetime.timedelta(seconds=(time.perf_counter() - t))

print('Tiempo de entrenamiento:', elapsed_time)
# Out:
# Tiempo de entrenamiento: 0:20:52.253593

# %% [markdown]
# ## 6. Evaluamos los resultados

# %%
_, acc = model.evaluate(x_test_scaled, y_test_encoded, verbose=0)
print('Accuracy:',' %.3f' % (acc))
# Out:
# Accuracy:  0.842

# %%
plt.title('Cross Entropy Loss')
plt.plot(history.history['loss'], color='blue', label='train')
plt.plot(history.history['val_loss'], color='orange', label='test')
plt.show()

plt.title('Classification Accuracy')
plt.plot(history.history['accuracy'], color='blue', label='train')
plt.plot(history.history['val_accuracy'], color='orange', label='test')
plt.show()

# %% [markdown]
# El coste podemos ver que es estable y es en el epoch 15 que se fija en un valor. Además la accuracy baila alrededor de 0.10. No se puede decir que sea un modelo muy bueno.
#
# Veamos que tipo de predicciones estoy obteniendo sobre el conjunto de test (vamos a pintar las imagenes y sus clasificaciones)

# %%
predictions = model.predict(x_test_scaled)

# %% [markdown]
# Una de las ventajas de Python es que hay montones de funciones y código realizado por terceras personas. Aquí me he fusilado unas bonitas funciones (que he adaptado un poco a mis necesidades) para poder pintar las imagenes, su label (ground truth) y las clasificaciones que hemos realizado.

# %%
def plot_image(i, predictions_array, true_label, img):
  predictions_array, true_label, img = predictions_array, true_label[i], img[i]
  plt.grid(False)
  plt.xticks([])
  plt.yticks([])

  plt.imshow(img, cmap=plt.cm.binary)

  predicted_label = np.argmax(predictions_array)
  if predicted_label == true_label:
    color = 'blue'
  else:
    color = 'red'

  plt.xlabel("{} {:2.0f}% ({})".format(predicted_label,
                                100*np.max(predictions_array),
                                true_label[0]),
                                color=color)

def plot_value_array(i, predictions_array, true_label):
  predictions_array, true_label = predictions_array, true_label[i]
  plt.grid(False)
  plt.xticks(range(10))
  plt.yticks([])
  thisplot = plt.bar(range(10), predictions_array, color="#777777")
  plt.ylim([0, 1])
  predicted_label = np.argmax(predictions_array)

  thisplot[predicted_label].set_color('red')
  thisplot[true_label[0]].set_color('blue')

# %% [markdown]
# Dibujamos las primeras imagenes, con las predicciones y sus valores reales (un total de 20 imagenes, para no abusar de vuestros laptops)
#
# Coloreamos las prediciones correctas en azul y los fallos en rojo. Aunque primero he impreso las etiquetas para que tengamos una referencia al grafico.

# %%
i = 0
for l in cifar10_labels:
    print(i, l)
    i += 1

num_rows = 5
num_cols = 4
start = 1000
num_images = num_rows*num_cols
plt.figure(figsize=(2*2*num_cols, 2*num_rows))
for i in range(num_images):
  plt.subplot(num_rows, 2*num_cols, 2*i+1)
  plot_image(i+start, predictions[i+start], y_test, x_test_scaled)
  plt.subplot(num_rows, 2*num_cols, 2*i+2)
  plot_value_array(i+start, predictions[i+start], y_test)
plt.tight_layout()
plt.show()
# Out:
# 0 airplane
# 1 automobile
# 2 bird
# 3 cat
# 4 deer
# 5 dog
# 6 frog
# 7 horse
# 8 ship
# 9 truck
