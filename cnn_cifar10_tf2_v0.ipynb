# %% [markdown]
# <a href="https://colab.research.google.com/github/IanPuig/SCHOOL/blob/main/cnn_cifar10_tf2_v0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![Nuclio logo](https://nuclio.school/wp-content/uploads/2018/12/nucleoDS-newBlack.png)

# %% [markdown]
# ## 1. Librerias
#
# Para empezar carguemos esas librerias que nos hacen falta

# %%
import numpy as np
import time
import datetime
import random
import pandas as pd
import os

from matplotlib import pyplot as plt
from tensorflow import keras as ks
from tensorflow.keras.preprocessing.image import ImageDataGenerator, load_img
from keras.utils import to_categorical
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.regularizers import l2
from tensorflow.keras.optimizers import Adam

# %% [markdown]
# ## 2. Arquitectura de red del modelo

# %%
model = ks.Sequential()

model.add(ks.layers.Conv2D(32, (3, 3), strides=1, activation='relu', padding='same', kernel_regularizer=l2(0.001), kernel_initializer='he_uniform', input_shape=(32,32,3)))
model.add(ks.layers.Conv2D(32, (3, 3), strides=1, activation='relu', padding='same', kernel_regularizer=l2(0.001), kernel_initializer='he_uniform'))
model.add(ks.layers.BatchNormalization())
model.add(ks.layers.MaxPooling2D((2, 2))) 


model.add(ks.layers.Conv2D(64, (3, 3), strides=1, activation='relu', padding='same', kernel_regularizer=l2(0.001), kernel_initializer='he_uniform'))
model.add(ks.layers.Conv2D(64, (3, 3), strides=1, activation='relu', padding='same', kernel_regularizer=l2(0.001), kernel_initializer='he_uniform'))
model.add(ks.layers.BatchNormalization())
model.add(ks.layers.MaxPooling2D((2, 2)))
 

model.add(ks.layers.Conv2D(128, (3, 3), strides=1, activation='relu', padding='same', kernel_regularizer=l2(0.001), kernel_initializer='he_uniform'))
model.add(ks.layers.Conv2D(128, (3, 3), strides=1, activation='relu', padding='same', kernel_regularizer=l2(0.001), kernel_initializer='he_uniform'))
model.add(ks.layers.BatchNormalization())
model.add(ks.layers.MaxPooling2D((2, 2)))


model.add(ks.layers.Conv2D(256, (3, 3), strides=1, activation='relu', padding='same', kernel_regularizer=l2(0.001), kernel_initializer='he_uniform'))
model.add(ks.layers.Conv2D(256, (3, 3), strides=1, activation='relu', padding='same', kernel_regularizer=l2(0.001), kernel_initializer='he_uniform'))
model.add(ks.layers.BatchNormalization())
model.add(ks.layers.MaxPooling2D((2, 2)))


model.add(ks.layers.Flatten())
model.add(ks.layers.Dense(128, activation='relu', kernel_regularizer=l2(0.001), kernel_initializer='he_uniform'))
model.add(ks.layers.BatchNormalization())
model.add(ks.layers.Dropout(0.6))  


model.add(ks.layers.Dense(128, activation='relu', kernel_regularizer=l2(0.001), kernel_initializer='he_uniform'))
model.add(ks.layers.BatchNormalization())
model.add(ks.layers.Dropout(0.6))  

model.add(ks.layers.Dense(10, activation='softmax'))
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 32, 32, 32)        896
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 32, 32, 32)        9248
# _________________________________________________________________
# batch_normalization (BatchNo (None, 32, 32, 32)        128
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 16, 16, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 16, 16, 64)        18496
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 16, 16, 64)        36928
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 16, 16, 64)        256
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 8, 8, 64)          0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 8, 8, 128)         73856
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 8, 8, 128)         147584
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 8, 8, 128)         512
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 4, 4, 128)         0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 4, 4, 256)         295168
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 4, 4, 256)         590080
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 4, 4, 256)         1024
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 2, 2, 256)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 1024)              0
# _________________________________________________________________
# dense (Dense)                (None, 128)               131200
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 128)               512
# _________________________________________________________________
# dropout (Dropout)            (None, 128)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 128)               16512
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 128)               512
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                1290
# =================================================================
# Total params: 1,324,202
# Trainable params: 1,322,730
# Non-trainable params: 1,472
# _________________________________________________________________

# %% [markdown]
# Para revisar un modelo, nos basta con llamar al método **.summary()** del modelo

# %% [markdown]
# ## 3. Optimizador, función error

# %%
model.compile(optimizer='Adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# %% [markdown]
# ## 4. Preparamos los datos
#
# Cargamos los datos de CIFAR10 de los datasets directamente de las librerias de Keras. Estos ya estan dispuestos en train and test
#
# **Detalle importante:**
# > La red neuronal requiere que los inputs sean números reales, y lo haremos forzando la division de los valores de dentro de las matrices 28x28 (que tienen valoress del 0 al 255) por 255.0 (un real)

# %%
cifar10 = ks.datasets.cifar10

(x_train, y_train), (x_test, y_test) = cifar10.load_data()

x_train, x_test = x_train / 255.0, x_test / 255.0

# %% [markdown]
# Obtenemos un array con todas las labels de CIFAR10

# %%
cifar10_labels = [
'airplane', # id 0
'automobile',
'bird',
'cat',
'deer',
'dog',
'frog',
'horse',
'ship',
'truck',
]

print('Number of labels: %s' % len(cifar10_labels))
# Out:
# Number of labels: 10

# %% [markdown]
# Pintemos una muestra de las imagenes del dataset CIFAR10, a ver si se parece en algo a lo que esperamos.
# Primero, vemos que tipos de datos tengo, después mapeamos esas matrices en una escala de grises utilizando el método **.get_cmap()** de PlotLy con los nueve primeros números del dataset.

# %%
# Pintemos una muestra de las las imagenes del dataset MNIST

print('Train: X=%s, y=%s' % (x_train.shape, y_train.shape))
print('Test: X=%s, y=%s' % (x_test.shape, y_test.shape))

for i in range(9):

    plt.subplot(330 + 1 + i)
    plt.imshow(x_train[i], cmap=plt.get_cmap('gray'))
    plt.title(cifar10_labels[y_train[i,0]])

plt.subplots_adjust(hspace = 1)
plt.show()
# Out:
# Train: X=(50000, 32, 32, 3), y=(50000, 1)
# Test: X=(10000, 32, 32, 3), y=(10000, 1)

# %% [markdown]
# Como vamos a querer ir haciendo validación a la vez que entrenamos (muy practico)

# %%
x_val = x_train[-10000:]
y_val = y_train[-10000:]

x_train = x_train[:-10000]
y_train = y_train[:-10000]

# %% [markdown]
# Cuando añadimos convoluciones, necesitamos "pre-tratar los datos", porque **la convolución es pera una matriz de 4 campos** (más parecido a "imagenes"), no un array de 3 como son actualmente los data sets de train, test y validación. Así que toca darle al **.reshape()**
#
# Por eso, al salir de la Convolution, hay que hacer un Flatten, porque las capas FullDense esperan arrays, no matrices!!
#
# Luego lo imprimimos para ver que todo está correcto

# %%
x_train_cnn = x_train.reshape((x_train.shape[0], 32, 32, 3))
x_test_cnn = x_test.reshape((x_test.shape[0], 32, 32, 3))
x_val_cnn = x_val.reshape((x_val.shape[0],32,32,3))

# Validamos el resultado
print('Train: X=%s, y=%s' % (x_train_cnn.shape, y_train.shape))
print('Test: X=%s, y=%s' % (x_test_cnn.shape, y_test.shape))
print('Validation: X=%s, y=%s' % (x_val_cnn.shape, y_val.shape))
# Out:
# Train: X=(40000, 32, 32, 3), y=(40000, 1)
# Test: X=(10000, 32, 32, 3), y=(10000, 1)
# Validation: X=(10000, 32, 32, 3), y=(10000, 1)

# %%
callback_val_loss = EarlyStopping(monitor="val_loss", patience=20)
callback_val_accy = EarlyStopping(monitor="val_accuracy", patience=20)

# %% [markdown]
# ## 5. Entrenamiento
#
# Ya podemos ponernos a entrenar el modelo!! Ojo, que hemos de entrenar contra los datos convertidos al formato que espera la Convolution.
#
# Empezaremos con 30 epocs, es decir, 30 pasadas completas del dataset (que a su vez sera con mini-batches internamente), fijando un batch de 64
#
# El metodo .fit() nos permite, definir además si disponemos de varias CPUs, GPUs, y si queremos ir validando datos a cada fin de epoch.

# %%
t = time.perf_counter()

# %%
history = model.fit(x_train_cnn, y_train, epochs=200, use_multiprocessing=False, batch_size= 512, validation_data=(x_val, y_val), callbacks=[callback_val_loss, callback_val_accy])
# Out:
# Epoch 1/200
# 79/79 [==============================] - 9s 66ms/step - loss: 5.4712 - accuracy: 0.1820 - val_loss: 5.2947 - val_accuracy: 0.1736
# Epoch 2/200
# 79/79 [==============================] - 4s 55ms/step - loss: 4.2425 - accuracy: 0.3390 - val_loss: 5.8452 - val_accuracy: 0.2006
# Epoch 3/200
# 79/79 [==============================] - 4s 55ms/step - loss: 3.7438 - accuracy: 0.4269 - val_loss: 4.7524 - val_accuracy: 0.2148
# Epoch 4/200
# 79/79 [==============================] - 4s 55ms/step - loss: 3.3195 - accuracy: 0.5161 - val_loss: 3.7089 - val_accuracy: 0.3622
# Epoch 5/200
# 79/79 [==============================] - 4s 55ms/step - loss: 2.9529 - accuracy: 0.5882 - val_loss: 3.5296 - val_accuracy: 0.3990
# Epoch 6/200
# 79/79 [==============================] - 4s 57ms/step - loss: 2.6445 - accuracy: 0.6417 - val_loss: 3.0692 - val_accuracy: 0.4765
# Epoch 7/200
# 79/79 [==============================] - 4s 56ms/step - loss: 2.3971 - accuracy: 0.6765 - val_loss: 2.7704 - val_accuracy: 0.5346
# Epoch 8/200
# 79/79 [==============================] - 4s 56ms/step - loss: 2.1843 - accuracy: 0.7128 - val_loss: 2.3911 - val_accuracy: 0.5890
# Epoch 9/200
# 79/79 [==============================] - 4s 56ms/step - loss: 1.9865 - accuracy: 0.7442 - val_loss: 2.3969 - val_accuracy: 0.5909
# Epoch 10/200
# 79/79 [==============================] - 4s 56ms/step - loss: 1.8150 - accuracy: 0.7775 - val_loss: 2.1457 - val_accuracy: 0.6403
# Epoch 11/200
# 79/79 [==============================] - 4s 56ms/step - loss: 1.6828 - accuracy: 0.7935 - val_loss: 2.0821 - val_accuracy: 0.6472
# Epoch 12/200
# 79/79 [==============================] - 4s 56ms/step - loss: 1.5619 - accuracy: 0.8145 - val_loss: 1.9976 - val_accuracy: 0.6636
# Epoch 13/200
# 79/79 [==============================] - 4s 56ms/step - loss: 1.4425 - accuracy: 0.8397 - val_loss: 1.9402 - val_accuracy: 0.6699
# Epoch 14/200
# 79/79 [==============================] - 4s 57ms/step - loss: 1.4176 - accuracy: 0.8361 - val_loss: 1.7715 - val_accuracy: 0.7083
# Epoch 15/200
# 79/79 [==============================] - 4s 56ms/step - loss: 1.2758 - accuracy: 0.8703 - val_loss: 2.0482 - val_accuracy: 0.6527
# Epoch 16/200
# 79/79 [==============================] - 4s 57ms/step - loss: 1.2366 - accuracy: 0.8728 - val_loss: 1.7526 - val_accuracy: 0.7129
# Epoch 17/200
# 79/79 [==============================] - 4s 57ms/step - loss: 1.1281 - accuracy: 0.9015 - val_loss: 1.8530 - val_accuracy: 0.7040
# Epoch 18/200
# 79/79 [==============================] - 4s 56ms/step - loss: 1.1549 - accuracy: 0.8868 - val_loss: 1.6218 - val_accuracy: 0.7503
# Epoch 19/200
# 79/79 [==============================] - 4s 57ms/step - loss: 1.0611 - accuracy: 0.9141 - val_loss: 1.6429 - val_accuracy: 0.7419
# Epoch 20/200
# 79/79 [==============================] - 4s 56ms/step - loss: 1.0645 - accuracy: 0.9064 - val_loss: 1.9554 - val_accuracy: 0.6939
# Epoch 21/200
# 79/79 [==============================] - 4s 56ms/step - loss: 1.0366 - accuracy: 0.9100 - val_loss: 1.6829 - val_accuracy: 0.7398
# Epoch 22/200
# 79/79 [==============================] - 4s 57ms/step - loss: 1.0310 - accuracy: 0.9136 - val_loss: 1.8968 - val_accuracy: 0.6977
# Epoch 23/200
# 79/79 [==============================] - 4s 56ms/step - loss: 0.9905 - accuracy: 0.9230 - val_loss: 1.7773 - val_accuracy: 0.7266
# Epoch 24/200
# 79/79 [==============================] - 4s 56ms/step - loss: 0.9873 - accuracy: 0.9221 - val_loss: 1.7363 - val_accuracy: 0.7349
# Epoch 25/200
# 79/79 [==============================] - 4s 56ms/step - loss: 0.9054 - accuracy: 0.9433 - val_loss: 1.7011 - val_accuracy: 0.7352
# Epoch 26/200
# 79/79 [==============================] - 4s 56ms/step - loss: 0.8993 - accuracy: 0.9414 - val_loss: 1.7880 - val_accuracy: 0.7280
# Epoch 27/200
# 79/79 [==============================] - 4s 57ms/step - loss: 0.8752 - accuracy: 0.9440 - val_loss: 1.7951 - val_accuracy: 0.7173
# Epoch 28/200
# 79/79 [==============================] - 4s 56ms/step - loss: 0.8909 - accuracy: 0.9394 - val_loss: 1.7602 - val_accuracy: 0.7470
# Epoch 29/200
# 79/79 [==============================] - 4s 56ms/step - loss: 0.8765 - accuracy: 0.9418 - val_loss: 1.7556 - val_accuracy: 0.7380
# Epoch 30/200
# 79/79 [==============================] - 4s 56ms/step - loss: 0.8900 - accuracy: 0.9388 - val_loss: 1.8073 - val_accuracy: 0.7258
# Epoch 31/200
# 79/79 [==============================] - 4s 56ms/step - loss: 0.8532 - accuracy: 0.9482 - val_loss: 1.6520 - val_accuracy: 0.7607
# Epoch 32/200
# 79/79 [==============================] - 4s 56ms/step - loss: 0.8502 - accuracy: 0.9466 - val_loss: 1.6680 - val_accuracy: 0.7467
# Epoch 33/200
# 79/79 [==============================] - 4s 56ms/step - loss: 0.8924 - accuracy: 0.9347 - val_loss: 1.6633 - val_accuracy: 0.7636
# Epoch 34/200
# 79/79 [==============================] - 4s 56ms/step - loss: 0.8059 - accuracy: 0.9606 - val_loss: 1.6409 - val_accuracy: 0.7559
# Epoch 35/200
# 79/79 [==============================] - 4s 56ms/step - loss: 0.8335 - accuracy: 0.9480 - val_loss: 1.7328 - val_accuracy: 0.7532
# Epoch 36/200
# 79/79 [==============================] - 4s 56ms/step - loss: 0.8351 - accuracy: 0.9483 - val_loss: 2.1090 - val_accuracy: 0.6844
# Epoch 37/200
# 79/79 [==============================] - 4s 56ms/step - loss: 0.8283 - accuracy: 0.9491 - val_loss: 1.6483 - val_accuracy: 0.7588
# Epoch 38/200
# 79/79 [==============================] - 4s 56ms/step - loss: 0.7801 - accuracy: 0.9599 - val_loss: 1.7005 - val_accuracy: 0.7506

# %%
elapsed_time = datetime.timedelta(seconds=(time.perf_counter() - t))

print('Tiempo de entrenamiento:', elapsed_time)
# Out:
# Tiempo de entrenamiento: 0:02:52.912334

# %% [markdown]
# ## 6. Evaluamos los resultados
#
# Obtengamos una grafica de como el error y la accuracy van evolucionando en cada epoch en los datos de entrenamiento y en la validación

# %%
_, acc = model.evaluate(x_test, y_test, verbose=0)
print('> %.3f' % (acc * 100.0))
# Out:
# > 74.480

# %%
plt.title('Cross Entropy Loss')
plt.plot(history.history['loss'], color='blue', label='train')
plt.plot(history.history['val_loss'], color='orange', label='test')
plt.show()

plt.title('Classification Accuracy')
plt.plot(history.history['accuracy'], color='blue', label='train')
plt.plot(history.history['val_accuracy'], color='orange', label='test')
plt.show()

# %% [markdown]
# El coste podemos ver que es estable y es en el epoch 15 que se fija en un valor. Además la accuracy baila alrededor de 0.10. No se puede decir que sea un modelo muy bueno.
#
# Veamos que tipo de predicciones estoy obteniendo sobre el conjunto de test (vamos a pintar las imagenes y sus clasificaciones)

# %%
predictions = model.predict(x_test_cnn)

# %% [markdown]
# Una de las ventajas de Python es que hay montones de funciones y código realizado por terceras personas. Aquí me he fusilado unas bonitas funciones (que he adaptado un poco a mis necesidades) para poder pintar las imagenes, su label (ground truth) y las clasificaciones que hemos realizado.

# %%
def plot_image(i, predictions_array, true_label, img):
  predictions_array, true_label, img = predictions_array, true_label[i], img[i]
  plt.grid(False)
  plt.xticks([])
  plt.yticks([])

  plt.imshow(img, cmap=plt.cm.binary)

  predicted_label = np.argmax(predictions_array)
  if predicted_label == true_label:
    color = 'blue'
  else:
    color = 'red'

  plt.xlabel("{} {:2.0f}% ({})".format(predicted_label,
                                100*np.max(predictions_array),
                                true_label[0]),
                                color=color)

def plot_value_array(i, predictions_array, true_label):
  predictions_array, true_label = predictions_array, true_label[i]
  plt.grid(False)
  plt.xticks(range(10))
  plt.yticks([])
  thisplot = plt.bar(range(10), predictions_array, color="#777777")
  plt.ylim([0, 1])
  predicted_label = np.argmax(predictions_array)

  thisplot[predicted_label].set_color('red')
  thisplot[true_label[0]].set_color('blue')

# %% [markdown]
# Dibujamos las primeras imagenes, con las predicciones y sus valores reales (un total de 20 imagenes, para no abusar de vuestros laptops)
#
# Coloreamos las prediciones correctas en azul y los fallos en rojo. Aunque primero he impreso las etiquetas para que tengamos una referencia al grafico.

# %%
i = 0
for l in cifar10_labels:
    print(i, l)
    i += 1

num_rows = 5
num_cols = 4
start = 650
num_images = num_rows*num_cols
plt.figure(figsize=(2*2*num_cols, 2*num_rows))
for i in range(num_images):
  plt.subplot(num_rows, 2*num_cols, 2*i+1)
  plot_image(i+start, predictions[i+start], y_test, x_test)
  plt.subplot(num_rows, 2*num_cols, 2*i+2)
  plot_value_array(i+start, predictions[i+start], y_test)
plt.tight_layout()
plt.show()
# Out:
# 0 airplane
# 1 automobile
# 2 bird
# 3 cat
# 4 deer
# 5 dog
# 6 frog
# 7 horse
# 8 ship
# 9 truck
