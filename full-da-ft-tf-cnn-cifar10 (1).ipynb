# %% [markdown]
# ![Nuclio logo](https://nuclio.school/wp-content/uploads/2018/12/nucleoDS-newBlack.png)

# %% [markdown]
# ## 1. Librerias
#
# Para empezar carguemos esas librerias que nos hacen falta

# %%
import numpy as np
import time
import datetime
import random
import pandas as pd
import os

from matplotlib import pyplot as plt
from tensorflow import keras as ks
from keras.utils import to_categorical
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.regularizers import l2
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.applications import vgg16
from tensorflow.keras.models import Model
from tensorflow.keras.preprocessing.image import ImageDataGenerator, load_img

# %% [markdown]
# ## 1.1. Preparamos los datos
#
# Cargamos los datos de CIFAR10 de los datasets directamente de las librerias de Keras. Estos ya estan dispuestos en train and test
#
# **Detalle importante:**
# > La red neuronal requiere que los inputs sean números reales, y lo haremos forzando la division de los valores de dentro de las matrices 28x28 (que tienen valoress del 0 al 255) por 255.0 (un real)

# %%
cifar10 = ks.datasets.cifar10

(x_train, y_train), (x_test, y_test) = cifar10.load_data()
x_train_scaled, x_test_scaled = x_train / 255.0, x_test / 255.0

# %%
print(y_train)
print(y_test)
# Out:
# [[6]
#  [9]
#  [9]
#  ...
#  [9]
#  [1]
#  [1]]
# [[3]
#  [8]
#  [8]
#  ...
#  [5]
#  [1]
#  [7]]

# %% [markdown]
# Obtenemos un array con todas las labels de CIFAR10

# %%
cifar10_labels = ['airplane','automobile','bird','cat','deer','dog','frog','horse','ship','truck']
print('labels: %s' % (cifar10_labels))
# Out:
# labels: ['airplane', 'automobile', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']

# %% [markdown]
# Pintemos una muestra de las imagenes del dataset CIFAR10, a ver si se parece en algo a lo que esperamos.
# Primero, vemos que tipos de datos tengo, después mapeamos esas matrices en una escala de grises utilizando el método **.get_cmap()** de PlotLy con los nueve primeros números del dataset.

# %%
print('Train: X=%s, y=%s' % (x_train_scaled.shape, y_train.shape))
print('Test: X=%s, y=%s' % (x_test_scaled.shape, y_test.shape))

for i in range(9):

    plt.subplot(330 + 1 + i)
    plt.imshow(x_train[i], cmap=plt.get_cmap('gray'))
    plt.title(cifar10_labels[y_train[i,0]])

plt.subplots_adjust(hspace = 1)
plt.show()
# Out:
# Train: X=(50000, 32, 32, 3), y=(50000, 1)
# Test: X=(10000, 32, 32, 3), y=(10000, 1)

# %% [markdown]
# Como vamos a querer ir haciendo validación a la vez que entrenamos (muy practico)

# %%
x_val = x_train[-10000:]
x_train = x_train[:-10000]

# %%
x_val_scaled= x_train_scaled[-10000:]
y_val = y_train[-10000:]
x_train_scaled= x_train_scaled[:-10000]
y_train = y_train[:-10000]

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()
le.fit(y_train)

y_train_encoded = le.transform(y_train)
y_val_encoded = le.transform(y_val)
y_test_encoded = le.transform(y_test)
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/preprocessing/_label.py:235: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.6/dist-packages/sklearn/preprocessing/_label.py:268: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
y_train.shape
y_train_reshape = np

# %%
print(y_train_encoded)
print(y_test_encoded)
print(y_val_encoded)
# Out:
# [6 9 9 ... 6 2 8]
# [3 8 8 ... 5 1 7]
# [1 8 5 ... 9 1 1]

# %%
y_train_encoded
# Out:
# array([6, 9, 9, ..., 6, 2, 8])

# %% [markdown]
# Cuando añadimos convoluciones, necesitamos "pre-tratar los datos", porque **la convolución es pera una matriz de 4 campos** (más parecido a "imagenes"), no un array de 3 como son actualmente los data sets de train, test y validación. Así que toca darle al **.reshape()**
#
# Por eso, al salir de la Convolution, hay que hacer un Flatten, porque las capas FullDense esperan arrays, no matrices!!
#
# Luego lo imprimimos para ver que todo está correcto

# %%
print('Train: X=%s, y=%s' % (x_train_scaled.shape, y_train_encoded.shape))
print('Test: X=%s, y=%s' % (x_test_scaled.shape, y_test_encoded.shape))
print('Val: X=%s, y=%s' % (x_val_scaled.shape, y_val_encoded.shape))
# Out:
# Train: X=(40000, 32, 32, 3), y=(40000,)
# Test: X=(10000, 32, 32, 3), y=(10000,)
# Val: X=(10000, 32, 32, 3), y=(10000,)

# %% [markdown]
# # 2. VGG16 Carga de la parte de extraccion de features
#
# Dos aproximaciones distintas...
#
#
# Basic se hace en dos pasos:
# Se cargar VGG16, sin classifcacion hasta el flatten, se procesan las imagenes hasta el bottleneck (donde se estrecha VGG16)
# Se monta la red de clasificacion con un input_shape fijado a partir de la salida de VGG16 (su flatten) y se entrena con los datos pasados por VGG16
# Fine Tuning, como requiere entrenar una red completa, se carga VGG16, se "descongelan capas" y se empalma con una red de clasificacion.
#
# en FT se entrena TODA la red... en Basic solo la classificacion tras pasar los datos por "preprocesado"

# %%
vgg = vgg16.VGG16(include_top=False, weights='imagenet', input_shape=(32,32,3))
vgg.summary()
# Out:
# Model: "vgg16"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 32, 32, 3)]       0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 32, 32, 64)        1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 32, 32, 64)        36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 16, 16, 64)        0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 16, 16, 128)       73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 16, 16, 128)       147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 8, 8, 128)         0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, 8, 8, 256)         295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, 8, 8, 256)         590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, 8, 8, 256)         590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, 4, 4, 256)         0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, 4, 4, 512)         1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, 4, 4, 512)         2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, 4, 4, 512)         2359808
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, 2, 2, 512)         0
# _________________________________________________________________
# block5_conv1 (Conv2D)        (None, 2, 2, 512)         2359808
# _________________________________________________________________
# block5_conv2 (Conv2D)        (None, 2, 2, 512)         2359808
# _________________________________________________________________
# block5_conv3 (Conv2D)        (None, 2, 2, 512)         2359808
# _________________________________________________________________
# block5_pool (MaxPooling2D)   (None, 1, 1, 512)         0
# =================================================================
# Total params: 14,714,688
# Trainable params: 14,714,688
# Non-trainable params: 0
# _________________________________________________________________

# %%
_
def_output = vgg.layers[-1].output
new_output_layer = ks.layers.Flatten()(def_output)
new_output_layer
# Out:
# <KerasTensor: shape=(None, 512) dtype=float32 (created by layer 'flatten')>

# %%
vgg_model = Model(vgg.input, new_output_layer)
vgg_model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 32, 32, 3)]       0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 32, 32, 64)        1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 32, 32, 64)        36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 16, 16, 64)        0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 16, 16, 128)       73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 16, 16, 128)       147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 8, 8, 128)         0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, 8, 8, 256)         295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, 8, 8, 256)         590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, 8, 8, 256)         590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, 4, 4, 256)         0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, 4, 4, 512)         1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, 4, 4, 512)         2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, 4, 4, 512)         2359808
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, 2, 2, 512)         0
# _________________________________________________________________
# block5_conv1 (Conv2D)        (None, 2, 2, 512)         2359808
# _________________________________________________________________
# block5_conv2 (Conv2D)        (None, 2, 2, 512)         2359808
# _________________________________________________________________
# block5_conv3 (Conv2D)        (None, 2, 2, 512)         2359808
# _________________________________________________________________
# block5_pool (MaxPooling2D)   (None, 1, 1, 512)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 512)               0
# =================================================================
# Total params: 14,714,688
# Trainable params: 14,714,688
# Non-trainable params: 0
# _________________________________________________________________

# %%
# mirem com estan els pesos de la xarxa vgg16

pd.set_option('max_colwidth', None)                                             
layers = [(layer, layer.name, layer.trainable) for layer in vgg_model.layers]
pd.DataFrame(layers, columns=['Layer Type', 'Layer Name', 'Trainable?'])
# Out:
#                                                                           Layer Type  ... Trainable?
# 0   <tensorflow.python.keras.engine.input_layer.InputLayer object at 0x7fd11ab76a58>  ...       True
# 1     <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fd0d8941550>  ...       True
# 2     <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fd0d811e2e8>  ...       True
# 3     <tensorflow.python.keras.layers.pooling.MaxPooling2D object at 0x7fd0d80c98d0>  ...       True
# 4     <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fd0d80c9c88>  ...       True
# 5     <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fd0d80d0eb8>  ...       True
# 6     <tensorflow.python.keras.layers.pooling.MaxPooling2D object at 0x7fd0d80d7f60>  ...       True
# 7     <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fd0d80e60b8>  ...       True
# 8     <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fd0d80db898>  ...       True
# 9     <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fd0d80e69b0>  ...       True
# 10    <tensorflow.python.keras.layers.pooling.MaxPooling2D object at 0x7fd0d0181cf8>  ...       True
# 11    <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fd0d0181240>  ...       True
# 12    <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fd0d80d7400>  ...       True
# 13    <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fd0d0188e48>  ...       True
# 14    <tensorflow.python.keras.layers.pooling.MaxPooling2D object at 0x7fd0d80e25f8>  ...       True
# 15    <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fd0d80d7390>  ...       True
# 16    <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fd0d0191f28>  ...       True
# 17    <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fd0d019cfd0>  ...       True
# 18    <tensorflow.python.keras.layers.pooling.MaxPooling2D object at 0x7fd0d01a3eb8>  ...       True
# 19            <tensorflow.python.keras.layers.core.Flatten object at 0x7fd0d01811d0>  ...       True
#
# [20 rows x 3 columns]

# %%
print(vgg_model.trainable)
# Out:
# True

# %%
# obrim la porta a poderlos modificar despres
vgg_model.trainable = True    
'''
# pero els posem en false de moment
for layer in vgg_model.layers:
  layer.trainable = False
'''
# Out:
# '\n# pero els posem en false de moment\nfor layer in vgg_model.layers:\n  layer.trainable = False\n'

# %%
# comprobem que estiguin en false
pd.set_option('max_colwidth', None)                                             
layers = [(layer, layer.name, layer.trainable) for layer in vgg_model.layers]
pd.DataFrame(layers, columns=['Layer Type', 'Layer Name', 'Trainable?'])
# Out:
#                                                                           Layer Type  ... Trainable?
# 0   <tensorflow.python.keras.engine.input_layer.InputLayer object at 0x7fd11ab76a58>  ...       True
# 1     <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fd0d8941550>  ...       True
# 2     <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fd0d811e2e8>  ...       True
# 3     <tensorflow.python.keras.layers.pooling.MaxPooling2D object at 0x7fd0d80c98d0>  ...       True
# 4     <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fd0d80c9c88>  ...       True
# 5     <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fd0d80d0eb8>  ...       True
# 6     <tensorflow.python.keras.layers.pooling.MaxPooling2D object at 0x7fd0d80d7f60>  ...       True
# 7     <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fd0d80e60b8>  ...       True
# 8     <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fd0d80db898>  ...       True
# 9     <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fd0d80e69b0>  ...       True
# 10    <tensorflow.python.keras.layers.pooling.MaxPooling2D object at 0x7fd0d0181cf8>  ...       True
# 11    <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fd0d0181240>  ...       True
# 12    <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fd0d80d7400>  ...       True
# 13    <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fd0d0188e48>  ...       True
# 14    <tensorflow.python.keras.layers.pooling.MaxPooling2D object at 0x7fd0d80e25f8>  ...       True
# 15    <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fd0d80d7390>  ...       True
# 16    <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fd0d0191f28>  ...       True
# 17    <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fd0d019cfd0>  ...       True
# 18    <tensorflow.python.keras.layers.pooling.MaxPooling2D object at 0x7fd0d01a3eb8>  ...       True
# 19            <tensorflow.python.keras.layers.core.Flatten object at 0x7fd0d01811d0>  ...       True
#
# [20 rows x 3 columns]

# %%
'''
trainable = False

for layer in vgg_model.layers:
  if layer.name in ['input_1']:
    trainable = True
  if trainable:
    layer.trainable = True
  else:
    layer.trainable = False
'''
# Out:
# "\ntrainable = False\n\nfor layer in vgg_model.layers:\n  if layer.name in ['input_1']:\n    trainable = True\n  if trainable:\n    layer.trainable = True\n  else:\n    layer.trainable = False\n"

# %%
# comprobem que estiguin en false
pd.set_option('max_colwidth', None)                                             
layers = [(layer, layer.name, layer.trainable) for layer in vgg_model.layers]
pd.DataFrame(layers, columns=['Layer Type', 'Layer Name', 'Trainable?'])
# Out:
#                                                                           Layer Type  ... Trainable?
# 0   <tensorflow.python.keras.engine.input_layer.InputLayer object at 0x7fd11ab76a58>  ...       True
# 1     <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fd0d8941550>  ...       True
# 2     <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fd0d811e2e8>  ...       True
# 3     <tensorflow.python.keras.layers.pooling.MaxPooling2D object at 0x7fd0d80c98d0>  ...       True
# 4     <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fd0d80c9c88>  ...       True
# 5     <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fd0d80d0eb8>  ...       True
# 6     <tensorflow.python.keras.layers.pooling.MaxPooling2D object at 0x7fd0d80d7f60>  ...       True
# 7     <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fd0d80e60b8>  ...       True
# 8     <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fd0d80db898>  ...       True
# 9     <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fd0d80e69b0>  ...       True
# 10    <tensorflow.python.keras.layers.pooling.MaxPooling2D object at 0x7fd0d0181cf8>  ...       True
# 11    <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fd0d0181240>  ...       True
# 12    <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fd0d80d7400>  ...       True
# 13    <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fd0d0188e48>  ...       True
# 14    <tensorflow.python.keras.layers.pooling.MaxPooling2D object at 0x7fd0d80e25f8>  ...       True
# 15    <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fd0d80d7390>  ...       True
# 16    <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fd0d0191f28>  ...       True
# 17    <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fd0d019cfd0>  ...       True
# 18    <tensorflow.python.keras.layers.pooling.MaxPooling2D object at 0x7fd0d01a3eb8>  ...       True
# 19            <tensorflow.python.keras.layers.core.Flatten object at 0x7fd0d01811d0>  ...       True
#
# [20 rows x 3 columns]

# %%
# MONTAMOS RED DE CLASIFICACION

input_shape = vgg_model.output_shape[1]
print(input_shape)
# Out:
# 512

# %%
# ARQUITECTURA CON  VGG16

model_ft_vgg = ks.Sequential()

model_ft_vgg.add(vgg_model)
model_ft_vgg.add(ks.layers.Dense(256, activation='relu', input_shape=(input_shape,)))
model_ft_vgg.add(ks.layers.Dropout(0.6))  

model_ft_vgg.add(ks.layers.Dense(256, activation='relu', input_shape=(input_shape,)))
model_ft_vgg.add(ks.layers.Dropout(0.6))

model_ft_vgg.add(ks.layers.Dense(10, activation='softmax'))
model_ft_vgg.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# model (Functional)           (None, 512)               14714688
# _________________________________________________________________
# dense (Dense)                (None, 256)               131328
# _________________________________________________________________
# dropout (Dropout)            (None, 256)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 256)               65792
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                2570
# =================================================================
# Total params: 14,914,378
# Trainable params: 14,914,378
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# Para revisar un modelo, nos basta con llamar al método **.summary()** del modelo

# %% [markdown]
# ## 3. Optimizador, función error

# %%
# OPTIMIZADOR DEL VGG
new_adam = Adam(learning_rate=0.000005)
model_ft_vgg.compile(optimizer=new_adam, loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# %% [markdown]
# # 3.1 Early stopping mediante callbacks

# %%
callback_val_loss = EarlyStopping(monitor="val_loss", patience=15)
callback_val_accy = EarlyStopping(monitor="val_accuracy", patience=20)

# %% [markdown]
# # 4. Data Augmentation

# %%
train_datagen = ImageDataGenerator( 
    rescale=1./255,
    horizontal_flip=True,
    # rotation_range = 10,
    # shear_range = 0.1,
    # zoom_range= 0.1,
    # width_shift_range=0.1,
    # height_shift_range=0.1,
    # brightness_range=(0.8,1.2),
    # fill_mode='nearest'
    )

train_generator = train_datagen.flow( 
    x_train, 
    y_train_encoded, 
    batch_size=32         
    )

# %%
sample = random.choice(range(0,1450))
example_generator = train_datagen.flow(
    x_train[sample:sample+1],
    y_train[sample:sample+1],
    batch_size=32
    )

plt.imshow(x_train[sample])

# %%
plt.figure(figsize=(12,12))
for i in range(0,15):
    plt.subplot(5,3,i+1)
    for X, Y in example_generator:
        image = X[0]
        plt.imshow(image)
        break

plt.tight_layout()
plt.show()

# %%
validation_datagen = ImageDataGenerator(
    rescale=1./255
    )
validation_generator = validation_datagen.flow(
    x_val, 
    y_val_encoded, 
    batch_size=32
    )

test_datagen = ImageDataGenerator(
    rescale=1./255
    )
test_generator = test_datagen.flow(
    x_test, 
    y_test_encoded,
    batch_size=32
    )

# %% [markdown]
# ## 5. Entrenamiento
#
# Ya podemos ponernos a entrenar el modelo!! Ojo, que hemos de entrenar contra los datos convertidos al formato que espera la Convolution.
#
# Empezaremos con 30 epocs, es decir, 30 pasadas completas del dataset (que a su vez sera con mini-batches internamente), fijando un batch de 64
#
# El metodo .fit() nos permite, definir además si disponemos de varias CPUs, GPUs, y si queremos ir validando datos a cada fin de epoch.

# %%
t = time.perf_counter()

# %%
# VGG16 + DA
history = model_ft_vgg.fit(train_generator, epochs=200, steps_per_epoch=512, callbacks=[callback_val_loss,callback_val_accy], validation_data=validation_generator, validation_steps=128)


# VGG16
# history = model_ft_vgg.fit(x_train_scaled, y_train_encoded, epochs=100, callbacks=[callback_val_loss,callback_val_accy], batch_size= 128, validation_data=(x_val_scaled, y_val_encoded))
# Out:
# Epoch 1/200
# 78/78 [==============================] - 21s 203ms/step - loss: 2.3898 - accuracy: 0.1268 - val_loss: 1.8049 - val_accuracy: 0.4608
# Epoch 2/200
# 78/78 [==============================] - 14s 185ms/step - loss: 1.7580 - accuracy: 0.3824 - val_loss: 1.1492 - val_accuracy: 0.6115
# Epoch 3/200
# 78/78 [==============================] - 14s 181ms/step - loss: 1.2695 - accuracy: 0.5613 - val_loss: 0.9834 - val_accuracy: 0.6673
# Epoch 4/200
# 78/78 [==============================] - 14s 179ms/step - loss: 1.0924 - accuracy: 0.6215 - val_loss: 0.8859 - val_accuracy: 0.6967
# Epoch 5/200
# 78/78 [==============================] - 14s 178ms/step - loss: 0.9931 - accuracy: 0.6600 - val_loss: 0.8281 - val_accuracy: 0.7194
# Epoch 6/200
# 78/78 [==============================] - 14s 180ms/step - loss: 0.9312 - accuracy: 0.6841 - val_loss: 0.7939 - val_accuracy: 0.7285
# Epoch 7/200
# 78/78 [==============================] - 14s 181ms/step - loss: 0.8821 - accuracy: 0.6996 - val_loss: 0.7603 - val_accuracy: 0.7370
# Epoch 8/200
# 78/78 [==============================] - 14s 181ms/step - loss: 0.8310 - accuracy: 0.7189 - val_loss: 0.7317 - val_accuracy: 0.7469
# Epoch 9/200
# 78/78 [==============================] - 14s 181ms/step - loss: 0.7975 - accuracy: 0.7290 - val_loss: 0.7140 - val_accuracy: 0.7540
# Epoch 10/200
# 78/78 [==============================] - 14s 181ms/step - loss: 0.7701 - accuracy: 0.7393 - val_loss: 0.6928 - val_accuracy: 0.7626
# Epoch 11/200
# 78/78 [==============================] - 14s 180ms/step - loss: 0.7412 - accuracy: 0.7482 - val_loss: 0.6773 - val_accuracy: 0.7665
# Epoch 12/200
# 78/78 [==============================] - 14s 180ms/step - loss: 0.7095 - accuracy: 0.7553 - val_loss: 0.6682 - val_accuracy: 0.7677
# Epoch 13/200
# 78/78 [==============================] - 14s 181ms/step - loss: 0.6941 - accuracy: 0.7640 - val_loss: 0.6499 - val_accuracy: 0.7755
# Epoch 14/200
# 78/78 [==============================] - 14s 181ms/step - loss: 0.6701 - accuracy: 0.7697 - val_loss: 0.6342 - val_accuracy: 0.7803
# Epoch 15/200
# 78/78 [==============================] - 14s 181ms/step - loss: 0.6607 - accuracy: 0.7759 - val_loss: 0.6300 - val_accuracy: 0.7807
# Epoch 16/200
# 78/78 [==============================] - 14s 181ms/step - loss: 0.6282 - accuracy: 0.7873 - val_loss: 0.6200 - val_accuracy: 0.7817
# Epoch 17/200
# 78/78 [==============================] - 14s 181ms/step - loss: 0.6199 - accuracy: 0.7905 - val_loss: 0.6078 - val_accuracy: 0.7884
# Epoch 18/200
# 78/78 [==============================] - 14s 181ms/step - loss: 0.6007 - accuracy: 0.7957 - val_loss: 0.6012 - val_accuracy: 0.7892
# Epoch 19/200
# 78/78 [==============================] - 14s 181ms/step - loss: 0.5884 - accuracy: 0.7984 - val_loss: 0.5928 - val_accuracy: 0.7940
# Epoch 20/200
# 78/78 [==============================] - 14s 181ms/step - loss: 0.5688 - accuracy: 0.8067 - val_loss: 0.5890 - val_accuracy: 0.7941
# Epoch 21/200
# 78/78 [==============================] - 14s 181ms/step - loss: 0.5613 - accuracy: 0.8093 - val_loss: 0.5878 - val_accuracy: 0.7944
# Epoch 22/200
# 78/78 [==============================] - 14s 180ms/step - loss: 0.5500 - accuracy: 0.8129 - val_loss: 0.5746 - val_accuracy: 0.7968
# Epoch 23/200
# 78/78 [==============================] - 14s 180ms/step - loss: 0.5325 - accuracy: 0.8191 - val_loss: 0.5640 - val_accuracy: 0.8028
# Epoch 24/200
# 78/78 [==============================] - 14s 180ms/step - loss: 0.5207 - accuracy: 0.8199 - val_loss: 0.5615 - val_accuracy: 0.8068
# Epoch 25/200
# 78/78 [==============================] - 14s 180ms/step - loss: 0.5105 - accuracy: 0.8272 - val_loss: 0.5568 - val_accuracy: 0.8043
# Epoch 26/200
# 78/78 [==============================] - 14s 180ms/step - loss: 0.5036 - accuracy: 0.8286 - val_loss: 0.5595 - val_accuracy: 0.8050
# Epoch 27/200
# 78/78 [==============================] - 14s 180ms/step - loss: 0.4921 - accuracy: 0.8323 - val_loss: 0.5502 - val_accuracy: 0.8092
# Epoch 28/200
# 78/78 [==============================] - 14s 180ms/step - loss: 0.4841 - accuracy: 0.8373 - val_loss: 0.5539 - val_accuracy: 0.8066
# Epoch 29/200
# 78/78 [==============================] - 14s 181ms/step - loss: 0.4835 - accuracy: 0.8344 - val_loss: 0.5381 - val_accuracy: 0.8125
# Epoch 30/200
# 78/78 [==============================] - 14s 180ms/step - loss: 0.4735 - accuracy: 0.8402 - val_loss: 0.5426 - val_accuracy: 0.8122
# Epoch 31/200
# 78/78 [==============================] - 14s 181ms/step - loss: 0.4645 - accuracy: 0.8427 - val_loss: 0.5466 - val_accuracy: 0.8082
# Epoch 32/200
# 78/78 [==============================] - 14s 181ms/step - loss: 0.4626 - accuracy: 0.8426 - val_loss: 0.5316 - val_accuracy: 0.8163
# Epoch 33/200
# 78/78 [==============================] - 14s 181ms/step - loss: 0.4512 - accuracy: 0.8456 - val_loss: 0.5211 - val_accuracy: 0.8170
# Epoch 34/200
# 78/78 [==============================] - 14s 181ms/step - loss: 0.4360 - accuracy: 0.8509 - val_loss: 0.5160 - val_accuracy: 0.8225
# Epoch 35/200
# 78/78 [==============================] - 14s 182ms/step - loss: 0.4260 - accuracy: 0.8556 - val_loss: 0.5244 - val_accuracy: 0.8189
# Epoch 36/200
# 78/78 [==============================] - 14s 180ms/step - loss: 0.4126 - accuracy: 0.8587 - val_loss: 0.5227 - val_accuracy: 0.8184
# Epoch 37/200
# 78/78 [==============================] - 14s 181ms/step - loss: 0.4145 - accuracy: 0.8610 - val_loss: 0.5113 - val_accuracy: 0.8237
# Epoch 38/200
# 78/78 [==============================] - 14s 181ms/step - loss: 0.3985 - accuracy: 0.8632 - val_loss: 0.5114 - val_accuracy: 0.8223
# Epoch 39/200
# 78/78 [==============================] - 14s 182ms/step - loss: 0.3975 - accuracy: 0.8659 - val_loss: 0.5031 - val_accuracy: 0.8267
# Epoch 40/200
# 78/78 [==============================] - 14s 181ms/step - loss: 0.3865 - accuracy: 0.8668 - val_loss: 0.5026 - val_accuracy: 0.8273
# Epoch 41/200
# 78/78 [==============================] - 14s 180ms/step - loss: 0.3781 - accuracy: 0.8709 - val_loss: 0.5215 - val_accuracy: 0.8210
# Epoch 42/200
# 78/78 [==============================] - 14s 180ms/step - loss: 0.3726 - accuracy: 0.8753 - val_loss: 0.5021 - val_accuracy: 0.8299
# Epoch 43/200
# 78/78 [==============================] - 14s 180ms/step - loss: 0.3689 - accuracy: 0.8747 - val_loss: 0.5046 - val_accuracy: 0.8262
# Epoch 44/200
# 78/78 [==============================] - 14s 180ms/step - loss: 0.3594 - accuracy: 0.8784 - val_loss: 0.4953 - val_accuracy: 0.8327
# Epoch 45/200
# 78/78 [==============================] - 14s 180ms/step - loss: 0.3480 - accuracy: 0.8810 - val_loss: 0.5048 - val_accuracy: 0.8300
# Epoch 46/200
# 78/78 [==============================] - 14s 180ms/step - loss: 0.3452 - accuracy: 0.8834 - val_loss: 0.5041 - val_accuracy: 0.8315
# Epoch 47/200
# 78/78 [==============================] - 14s 180ms/step - loss: 0.3416 - accuracy: 0.8843 - val_loss: 0.5058 - val_accuracy: 0.8298
# Epoch 48/200
# 78/78 [==============================] - 14s 181ms/step - loss: 0.3373 - accuracy: 0.8860 - val_loss: 0.4911 - val_accuracy: 0.8372
# Epoch 49/200
# 78/78 [==============================] - 14s 180ms/step - loss: 0.3274 - accuracy: 0.8885 - val_loss: 0.5046 - val_accuracy: 0.8321
# Epoch 50/200
# 78/78 [==============================] - 14s 180ms/step - loss: 0.3247 - accuracy: 0.8898 - val_loss: 0.4912 - val_accuracy: 0.8368
# Epoch 51/200
# 78/78 [==============================] - 14s 180ms/step - loss: 0.3202 - accuracy: 0.8927 - val_loss: 0.5028 - val_accuracy: 0.8332
# Epoch 52/200
# 78/78 [==============================] - 14s 180ms/step - loss: 0.3189 - accuracy: 0.8910 - val_loss: 0.4913 - val_accuracy: 0.8352
# Epoch 53/200
# 78/78 [==============================] - 14s 181ms/step - loss: 0.2956 - accuracy: 0.9000 - val_loss: 0.4951 - val_accuracy: 0.8371
# Epoch 54/200
# 78/78 [==============================] - 14s 180ms/step - loss: 0.3065 - accuracy: 0.8976 - val_loss: 0.4934 - val_accuracy: 0.8372
# Epoch 55/200
# 78/78 [==============================] - 14s 180ms/step - loss: 0.2922 - accuracy: 0.9009 - val_loss: 0.5008 - val_accuracy: 0.8338
# Epoch 56/200
# 78/78 [==============================] - 14s 181ms/step - loss: 0.2916 - accuracy: 0.9015 - val_loss: 0.4946 - val_accuracy: 0.8376
# Epoch 57/200
# 78/78 [==============================] - 14s 181ms/step - loss: 0.2747 - accuracy: 0.9056 - val_loss: 0.4958 - val_accuracy: 0.8380
# Epoch 58/200
# 78/78 [==============================] - 14s 181ms/step - loss: 0.2745 - accuracy: 0.9087 - val_loss: 0.4889 - val_accuracy: 0.8408
# Epoch 59/200
# 78/78 [==============================] - 14s 182ms/step - loss: 0.2637 - accuracy: 0.9095 - val_loss: 0.4952 - val_accuracy: 0.8394
# Epoch 60/200
# 78/78 [==============================] - 14s 180ms/step - loss: 0.2660 - accuracy: 0.9107 - val_loss: 0.4903 - val_accuracy: 0.8420
# Epoch 61/200
# 78/78 [==============================] - 14s 180ms/step - loss: 0.2613 - accuracy: 0.9113 - val_loss: 0.5016 - val_accuracy: 0.8381
# Epoch 62/200
# 78/78 [==============================] - 14s 181ms/step - loss: 0.2525 - accuracy: 0.9153 - val_loss: 0.4948 - val_accuracy: 0.8416
# Epoch 63/200
# 78/78 [==============================] - 14s 181ms/step - loss: 0.2406 - accuracy: 0.9170 - val_loss: 0.5050 - val_accuracy: 0.8388
# Epoch 64/200
# 78/78 [==============================] - 14s 181ms/step - loss: 0.2415 - accuracy: 0.9212 - val_loss: 0.5073 - val_accuracy: 0.8382
# Epoch 65/200
# 78/78 [==============================] - 14s 181ms/step - loss: 0.2449 - accuracy: 0.9176 - val_loss: 0.5015 - val_accuracy: 0.8429
# Epoch 66/200
# 78/78 [==============================] - 14s 181ms/step - loss: 0.2271 - accuracy: 0.9237 - val_loss: 0.5031 - val_accuracy: 0.8431
# Epoch 67/200
# 78/78 [==============================] - 14s 180ms/step - loss: 0.2234 - accuracy: 0.9262 - val_loss: 0.5053 - val_accuracy: 0.8406
# Epoch 68/200
# 78/78 [==============================] - 14s 181ms/step - loss: 0.2204 - accuracy: 0.9263 - val_loss: 0.5062 - val_accuracy: 0.8411
# Epoch 69/200
# 78/78 [==============================] - 14s 181ms/step - loss: 0.2182 - accuracy: 0.9285 - val_loss: 0.5043 - val_accuracy: 0.8413
# Epoch 70/200
# 78/78 [==============================] - 14s 181ms/step - loss: 0.2171 - accuracy: 0.9267 - val_loss: 0.5134 - val_accuracy: 0.8427
# Epoch 71/200
# 78/78 [==============================] - 14s 180ms/step - loss: 0.2024 - accuracy: 0.9312 - val_loss: 0.5035 - val_accuracy: 0.8424
# Epoch 72/200
# 78/78 [==============================] - 14s 181ms/step - loss: 0.1953 - accuracy: 0.9368 - val_loss: 0.5172 - val_accuracy: 0.8391
# Epoch 73/200
# 78/78 [==============================] - 14s 181ms/step - loss: 0.1961 - accuracy: 0.9352 - val_loss: 0.5102 - val_accuracy: 0.8448

# %% [markdown]
# ## 6. Evaluamos el Modelo

# %%
# VGG16
_, acc = model_ft_vgg.evaluate(x_test_scaled, y_test_encoded, verbose=0)
print('Accuracy:',' %.3f' % (acc))
# Out:
# Accuracy:  0.839

# %%
elapsed_time = datetime.timedelta(seconds=(time.perf_counter() - t))

print('Tiempo de entrenamiento:', elapsed_time)
# Out:
# Tiempo de entrenamiento: 0:17:18.868533

# %%
# for VGG16
_, acc = model_ft_vgg.evaluate(x_test_scaled, y_test_encoded, verbose=0)
print('Accuracy:',' %.3f' % (acc))
# Out:
# Accuracy:  0.839

# %%
plt.title('Cross Entropy Loss')
plt.plot(history.history['loss'], color='blue', label='train')
plt.plot(history.history['val_loss'], color='orange', label='test')
plt.show()

plt.title('Classification Accuracy')
plt.plot(history.history['accuracy'], color='blue', label='train')
plt.plot(history.history['val_accuracy'], color='orange', label='test')
plt.show()

# %% [markdown]
# El coste podemos ver que es estable y es en el epoch 15 que se fija en un valor. Además la accuracy baila alrededor de 0.10. No se puede decir que sea un modelo muy bueno.
#
# Veamos que tipo de predicciones estoy obteniendo sobre el conjunto de test (vamos a pintar las imagenes y sus clasificaciones)

# %%
predictions = model_ft_vgg.predict(x_test_scaled)

# %% [markdown]
# Una de las ventajas de Python es que hay montones de funciones y código realizado por terceras personas. Aquí me he fusilado unas bonitas funciones (que he adaptado un poco a mis necesidades) para poder pintar las imagenes, su label (ground truth) y las clasificaciones que hemos realizado.

# %%
def plot_image(i, predictions_array, true_label, img):
  predictions_array, true_label, img = predictions_array, true_label[i], img[i]
  plt.grid(False)
  plt.xticks([])
  plt.yticks([])

  plt.imshow(img, cmap=plt.cm.binary)

  predicted_label = np.argmax(predictions_array)
  if predicted_label == true_label:
    color = 'blue'
  else:
    color = 'red'

  plt.xlabel("{} {:2.0f}% ({})".format(predicted_label,
                                100*np.max(predictions_array),
                                true_label[0]),
                                color=color)

def plot_value_array(i, predictions_array, true_label):
  predictions_array, true_label = predictions_array, true_label[i]
  plt.grid(False)
  plt.xticks(range(10))
  plt.yticks([])
  thisplot = plt.bar(range(10), predictions_array, color="#777777")
  plt.ylim([0, 1])
  predicted_label = np.argmax(predictions_array)

  thisplot[predicted_label].set_color('red')
  thisplot[true_label[0]].set_color('blue')

# %% [markdown]
# Dibujamos las primeras imagenes, con las predicciones y sus valores reales (un total de 20 imagenes, para no abusar de vuestros laptops)
#
# Coloreamos las prediciones correctas en azul y los fallos en rojo. Aunque primero he impreso las etiquetas para que tengamos una referencia al grafico.

# %%
i = 0
for l in cifar10_labels:
    print(i, l)
    i += 1

num_rows = 5
num_cols = 4
start = 1000
num_images = num_rows*num_cols
plt.figure(figsize=(2*2*num_cols, 2*num_rows))
for i in range(num_images):
  plt.subplot(num_rows, 2*num_cols, 2*i+1)
  plot_image(i+start, predictions[i+start], y_test, x_test_scaled)
  plt.subplot(num_rows, 2*num_cols, 2*i+2)
  plot_value_array(i+start, predictions[i+start], y_test)
plt.tight_layout()
plt.show()
# Out:
# 0 airplane
# 1 automobile
# 2 bird
# 3 cat
# 4 deer
# 5 dog
# 6 frog
# 7 horse
# 8 ship
# 9 truck
