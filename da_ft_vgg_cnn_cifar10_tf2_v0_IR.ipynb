# %% [markdown]
# <a href="https://colab.research.google.com/github/IanPuig/SCHOOL/blob/main/da_ft_vgg_cnn_cifar10_tf2_v0_IR.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![Nuclio logo](https://nuclio.school/wp-content/uploads/2018/12/nucleoDS-newBlack.png)

# %% [markdown]
# ## 1. Librerias
#
# Para empezar carguemos esas librerias que nos hacen falta

# %%
import numpy as np
import time
import datetime
import random
import pandas as pd
import os

from matplotlib import pyplot as plt
from tensorflow import keras as ks
from keras.utils import to_categorical
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.regularizers import l2
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.applications import vgg16
from tensorflow.keras.models import Model
from tensorflow.keras.preprocessing.image import ImageDataGenerator, load_img

# %% [markdown]
# ## 1.1. Preparamos los datos
#
# Cargamos los datos de CIFAR10 de los datasets directamente de las librerias de Keras. Estos ya estan dispuestos en train and test
#
# **Detalle importante:**
# > La red neuronal requiere que los inputs sean números reales, y lo haremos forzando la division de los valores de dentro de las matrices 28x28 (que tienen valoress del 0 al 255) por 255.0 (un real)

# %%
cifar10 = ks.datasets.cifar10

(x_train, y_train), (x_test, y_test) = cifar10.load_data()
x_train_scaled, x_test_scaled = x_train / 255.0, x_test / 255.0

# %%
print(y_train)
print(y_test)
# Out:
# [[6]
#  [9]
#  [9]
#  ...
#  [9]
#  [1]
#  [1]]
# [[3]
#  [8]
#  [8]
#  ...
#  [5]
#  [1]
#  [7]]

# %% [markdown]
# Obtenemos un array con todas las labels de CIFAR10

# %%
cifar10_labels = ['airplane','automobile','bird','cat','deer','dog','frog','horse','ship','truck']
print('labels: %s' % (cifar10_labels))
# Out:
# labels: ['airplane', 'automobile', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']

# %% [markdown]
# Pintemos una muestra de las imagenes del dataset CIFAR10, a ver si se parece en algo a lo que esperamos.
# Primero, vemos que tipos de datos tengo, después mapeamos esas matrices en una escala de grises utilizando el método **.get_cmap()** de PlotLy con los nueve primeros números del dataset.

# %%
print('Train: X=%s, y=%s' % (x_train_scaled.shape, y_train.shape))
print('Test: X=%s, y=%s' % (x_test_scaled.shape, y_test.shape))

for i in range(9):

    plt.subplot(330 + 1 + i)
    plt.imshow(x_train[i], cmap=plt.get_cmap('gray'))
    plt.title(cifar10_labels[y_train[i,0]])

plt.subplots_adjust(hspace = 1)
plt.show()
# Out:
# Train: X=(50000, 32, 32, 3), y=(50000, 1)
# Test: X=(10000, 32, 32, 3), y=(10000, 1)

# %% [markdown]
# Como vamos a querer ir haciendo validación a la vez que entrenamos (muy practico)

# %%
x_val = x_train[-10000:]
x_train = x_train[:-10000]

# %%
x_val_scaled= x_train_scaled[-10000:]
y_val = y_train[-10000:]

x_train_scaled= x_train_scaled[:-10000]
y_train = y_train[:-10000]

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()
le.fit(y_train)

y_train_encoded = le.transform(y_train)
y_val_encoded = le.transform(y_val)
y_test_encoded = le.transform(y_test)
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/preprocessing/_label.py:235: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.6/dist-packages/sklearn/preprocessing/_label.py:268: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
y_train_encoded
# Out:
# array([6, 9, 9, ..., 6, 2, 8])

# %% [markdown]
# Cuando añadimos convoluciones, necesitamos "pre-tratar los datos", porque **la convolución es pera una matriz de 4 campos** (más parecido a "imagenes"), no un array de 3 como son actualmente los data sets de train, test y validación. Así que toca darle al **.reshape()**
#
# Por eso, al salir de la Convolution, hay que hacer un Flatten, porque las capas FullDense esperan arrays, no matrices!!
#
# Luego lo imprimimos para ver que todo está correcto

# %%
print('Train: X=%s, y=%s' % (x_train_scaled.shape, y_train_encoded.shape))
print('Test: X=%s, y=%s' % (x_test_scaled.shape, y_test_encoded.shape))
print('Val: X=%s, y=%s' % (x_val_scaled.shape, y_val_encoded.shape))
# Out:
# Train: X=(40000, 32, 32, 3), y=(40000,)
# Test: X=(10000, 32, 32, 3), y=(10000,)
# Val: X=(10000, 32, 32, 3), y=(10000,)

# %% [markdown]
# # 2. VGG16 Carga de la parte de extraccion de features
#
# Dos aproximaciones distintas...
#
#
# Basic se hace en dos pasos:
# Se cargar VGG16, sin classifcacion hasta el flatten, se procesan las imagenes hasta el bottleneck (donde se estrecha VGG16)
# Se monta la red de clasificacion con un input_shape fijado a partir de la salida de VGG16 (su flatten) y se entrena con los datos pasados por VGG16
# Fine Tuning, como requiere entrenar una red completa, se carga VGG16, se "descongelan capas" y se empalma con una red de clasificacion.
#
# en FT se entrena TODA la red... en Basic solo la classificacion tras pasar los datos por "preprocesado"

# %%
vgg = vgg16.VGG16(include_top=False, weights='imagenet', input_shape=(32,32,3))
vgg.summary()
# Out:
# Model: "vgg16"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 32, 32, 3)]       0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 32, 32, 64)        1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 32, 32, 64)        36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 16, 16, 64)        0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 16, 16, 128)       73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 16, 16, 128)       147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 8, 8, 128)         0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, 8, 8, 256)         295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, 8, 8, 256)         590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, 8, 8, 256)         590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, 4, 4, 256)         0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, 4, 4, 512)         1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, 4, 4, 512)         2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, 4, 4, 512)         2359808
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, 2, 2, 512)         0
# _________________________________________________________________
# block5_conv1 (Conv2D)        (None, 2, 2, 512)         2359808
# _________________________________________________________________
# block5_conv2 (Conv2D)        (None, 2, 2, 512)         2359808
# _________________________________________________________________
# block5_conv3 (Conv2D)        (None, 2, 2, 512)         2359808
# _________________________________________________________________
# block5_pool (MaxPooling2D)   (None, 1, 1, 512)         0
# =================================================================
# Total params: 14,714,688
# Trainable params: 14,714,688
# Non-trainable params: 0
# _________________________________________________________________

# %%
_
def_output = vgg.layers[-1].output
new_output_layer = ks.layers.Flatten()(def_output)
new_output_layer
# Out:
# <KerasTensor: shape=(None, 512) dtype=float32 (created by layer 'flatten')>

# %%
vgg_model = Model(vgg.input, new_output_layer)
vgg_model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 32, 32, 3)]       0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 32, 32, 64)        1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 32, 32, 64)        36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 16, 16, 64)        0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 16, 16, 128)       73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 16, 16, 128)       147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 8, 8, 128)         0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, 8, 8, 256)         295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, 8, 8, 256)         590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, 8, 8, 256)         590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, 4, 4, 256)         0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, 4, 4, 512)         1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, 4, 4, 512)         2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, 4, 4, 512)         2359808
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, 2, 2, 512)         0
# _________________________________________________________________
# block5_conv1 (Conv2D)        (None, 2, 2, 512)         2359808
# _________________________________________________________________
# block5_conv2 (Conv2D)        (None, 2, 2, 512)         2359808
# _________________________________________________________________
# block5_conv3 (Conv2D)        (None, 2, 2, 512)         2359808
# _________________________________________________________________
# block5_pool (MaxPooling2D)   (None, 1, 1, 512)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 512)               0
# =================================================================
# Total params: 14,714,688
# Trainable params: 14,714,688
# Non-trainable params: 0
# _________________________________________________________________

# %%
# mirem com estan els pesos de la xarxa vgg16

pd.set_option('max_colwidth', None)                                             
layers = [(layer, layer.name, layer.trainable) for layer in vgg_model.layers]
pd.DataFrame(layers, columns=['Layer Type', 'Layer Name', 'Trainable?'])
# Out:
#                                                                           Layer Type  ... Trainable?
# 0   <tensorflow.python.keras.engine.input_layer.InputLayer object at 0x7f3bea7638d0>  ...       True
# 1     <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f3ba85ef320>  ...       True
# 2     <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f3ba85efeb8>  ...       True
# 3     <tensorflow.python.keras.layers.pooling.MaxPooling2D object at 0x7f3bea763ef0>  ...       True
# 4     <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f3ba7d70f28>  ...       True
# 5     <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f3ba7d77978>  ...       True
# 6     <tensorflow.python.keras.layers.pooling.MaxPooling2D object at 0x7f3ba7d80cf8>  ...       True
# 7     <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f3ba7d84e10>  ...       True
# 8     <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f3ba7d848d0>  ...       True
# 9     <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f3ba7d70438>  ...       True
# 10    <tensorflow.python.keras.layers.pooling.MaxPooling2D object at 0x7f3ba042def0>  ...       True
# 11    <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f3ba042d9e8>  ...       True
# 12    <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f3ba7d77f60>  ...       True
# 13    <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f3ba0429940>  ...       True
# 14    <tensorflow.python.keras.layers.pooling.MaxPooling2D object at 0x7f3ba04411d0>  ...       True
# 15    <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f3ba0432dd8>  ...       True
# 16    <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f3ba0445630>  ...       True
# 17    <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f3ba044edd8>  ...       True
# 18    <tensorflow.python.keras.layers.pooling.MaxPooling2D object at 0x7f3ba044eac8>  ...       True
# 19            <tensorflow.python.keras.layers.core.Flatten object at 0x7f3ba7d80208>  ...       True
#
# [20 rows x 3 columns]

# %%
print(vgg_model.trainable)
# Out:
# True

# %%
# obrim la porta a poderlos modificar despres
vgg_model.trainable = True    

# pero els posem en false de moment
for layer in vgg_model.layers:
  layer.trainable = False

# %%
# comprobem que estiguin en false
pd.set_option('max_colwidth', None)                                             
layers = [(layer, layer.name, layer.trainable) for layer in vgg_model.layers]
pd.DataFrame(layers, columns=['Layer Type', 'Layer Name', 'Trainable?'])
# Out:
#                                                                           Layer Type  ... Trainable?
# 0   <tensorflow.python.keras.engine.input_layer.InputLayer object at 0x7f3bea7638d0>  ...      False
# 1     <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f3ba85ef320>  ...      False
# 2     <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f3ba85efeb8>  ...      False
# 3     <tensorflow.python.keras.layers.pooling.MaxPooling2D object at 0x7f3bea763ef0>  ...      False
# 4     <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f3ba7d70f28>  ...      False
# 5     <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f3ba7d77978>  ...      False
# 6     <tensorflow.python.keras.layers.pooling.MaxPooling2D object at 0x7f3ba7d80cf8>  ...      False
# 7     <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f3ba7d84e10>  ...      False
# 8     <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f3ba7d848d0>  ...      False
# 9     <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f3ba7d70438>  ...      False
# 10    <tensorflow.python.keras.layers.pooling.MaxPooling2D object at 0x7f3ba042def0>  ...      False
# 11    <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f3ba042d9e8>  ...      False
# 12    <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f3ba7d77f60>  ...      False
# 13    <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f3ba0429940>  ...      False
# 14    <tensorflow.python.keras.layers.pooling.MaxPooling2D object at 0x7f3ba04411d0>  ...      False
# 15    <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f3ba0432dd8>  ...      False
# 16    <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f3ba0445630>  ...      False
# 17    <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f3ba044edd8>  ...      False
# 18    <tensorflow.python.keras.layers.pooling.MaxPooling2D object at 0x7f3ba044eac8>  ...      False
# 19            <tensorflow.python.keras.layers.core.Flatten object at 0x7f3ba7d80208>  ...      False
#
# [20 rows x 3 columns]

# %%
trainable = False

for layer in vgg_model.layers:
  if layer.name in ['input_1']:
    trainable = True
  if trainable:
    layer.trainable = True
  else:
    layer.trainable = False

# %%
# comprobem que estiguin en false
pd.set_option('max_colwidth', None)                                             
layers = [(layer, layer.name, layer.trainable) for layer in vgg_model.layers]
pd.DataFrame(layers, columns=['Layer Type', 'Layer Name', 'Trainable?'])
# Out:
#                                                                           Layer Type  ... Trainable?
# 0   <tensorflow.python.keras.engine.input_layer.InputLayer object at 0x7f3bea7638d0>  ...       True
# 1     <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f3ba85ef320>  ...       True
# 2     <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f3ba85efeb8>  ...       True
# 3     <tensorflow.python.keras.layers.pooling.MaxPooling2D object at 0x7f3bea763ef0>  ...       True
# 4     <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f3ba7d70f28>  ...       True
# 5     <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f3ba7d77978>  ...       True
# 6     <tensorflow.python.keras.layers.pooling.MaxPooling2D object at 0x7f3ba7d80cf8>  ...       True
# 7     <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f3ba7d84e10>  ...       True
# 8     <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f3ba7d848d0>  ...       True
# 9     <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f3ba7d70438>  ...       True
# 10    <tensorflow.python.keras.layers.pooling.MaxPooling2D object at 0x7f3ba042def0>  ...       True
# 11    <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f3ba042d9e8>  ...       True
# 12    <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f3ba7d77f60>  ...       True
# 13    <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f3ba0429940>  ...       True
# 14    <tensorflow.python.keras.layers.pooling.MaxPooling2D object at 0x7f3ba04411d0>  ...       True
# 15    <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f3ba0432dd8>  ...       True
# 16    <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f3ba0445630>  ...       True
# 17    <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f3ba044edd8>  ...       True
# 18    <tensorflow.python.keras.layers.pooling.MaxPooling2D object at 0x7f3ba044eac8>  ...       True
# 19            <tensorflow.python.keras.layers.core.Flatten object at 0x7f3ba7d80208>  ...       True
#
# [20 rows x 3 columns]

# %%
# MONTAMOS RED DE CLASIFICACION

input_shape = vgg_model.output_shape[1]
print(input_shape)
# Out:
# 512

# %%
# ARQUITECTURA CON  VGG16

model_ft_vgg = ks.Sequential()

model_ft_vgg.add(vgg_model)
model_ft_vgg.add(ks.layers.Dense(512, activation='relu', input_shape=(input_shape,)))
model_ft_vgg.add(ks.layers.Dropout(0.6))  

model_ft_vgg.add(ks.layers.Dense(512, activation='relu', input_shape=(input_shape,)))
model_ft_vgg.add(ks.layers.Dropout(0.6)) 

model_ft_vgg.add(ks.layers.Dense(10, activation='softmax'))
model_ft_vgg.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# model (Functional)           (None, 512)               14714688
# _________________________________________________________________
# dense (Dense)                (None, 256)               131328
# _________________________________________________________________
# dropout (Dropout)            (None, 256)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 256)               65792
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                2570
# =================================================================
# Total params: 14,914,378
# Trainable params: 14,914,378
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# Para revisar un modelo, nos basta con llamar al método **.summary()** del modelo

# %% [markdown]
# ## 3. Optimizador, función error

# %%
# OPTIMIZADOR DEL VGG
new_adam = Adam(learning_rate=0.0001)
model_ft_vgg.compile(optimizer=new_adam, loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# %% [markdown]
# # 3.1 Definimos la tecnica de Early stopping mediante callbacks

# %%
callback_val_loss = EarlyStopping(monitor="val_loss", patience=20)
callback_val_accy = EarlyStopping(monitor="val_accuracy", patience=20)

# %% [markdown]
# # 4. Data Augmentation

# %%
train_datagen = ImageDataGenerator( 
    rescale=1./255,
    horizontal_flip=True,
    # rotation_range = 10,
    # shear_range = 0.1,
    # zoom_range= 0.1,
    # width_shift_range=0.1,
    # height_shift_range=0.1,
    # brightness_range=(0.8,1.2),
    # fill_mode='nearest'
    )



train_generator = train_datagen.flow( 
    x_train, 
    y_train_encoded, 
    batch_size=512          
    )

# %%
sample = random.choice(range(0,1450))
example_generator = train_datagen.flow(
    x_train[sample:sample+1],
    y_train[sample:sample+1],
    batch_size=512
    )

plt.imshow(x_train[sample])

# %%
plt.figure(figsize=(12,12))
for i in range(0,15):
    plt.subplot(5,3,i+1)
    for X, Y in example_generator:
        image = X[0]
        plt.imshow(image)
        break

plt.tight_layout()
plt.show()

# %%
validation_datagen = ImageDataGenerator(
    rescale=1./255
    )
validation_generator = validation_datagen.flow(
    x_val, 
    y_val_encoded, 
    batch_size=512
    )

test_datagen = ImageDataGenerator(
    rescale=1./255
    )
test_generator = test_datagen.flow(
    x_test, 
    y_test_encoded,
    batch_size=512
    )

# %% [markdown]
# ## 5. Entrenamiento
#
# Ya podemos ponernos a entrenar el modelo!! Ojo, que hemos de entrenar contra los datos convertidos al formato que espera la Convolution.
#
# Empezaremos con 30 epocs, es decir, 30 pasadas completas del dataset (que a su vez sera con mini-batches internamente), fijando un batch de 64
#
# El metodo .fit() nos permite, definir además si disponemos de varias CPUs, GPUs, y si queremos ir validando datos a cada fin de epoch.

# %%
t = time.perf_counter()

# %%
# VGG16 + DA
history = model_ft_vgg.fit(train_generator, epochs=200, steps_per_epoch=78, callbacks=[callback_val_loss,callback_val_accy], validation_data=validation_generator, validation_steps=20)

# VGG16
# history = model_ft_vgg.fit(x_train_scaled, y_train_encoded, epochs=300, callbacks=[callback_val_loss,callback_val_accy], batch_size= 512, validation_data=(x_val_scaled, y_val_encoded))
# Out:
# Epoch 1/200
# 78/78 [==============================] - 21s 202ms/step - loss: 2.4651 - accuracy: 0.1197 - val_loss: 2.0824 - val_accuracy: 0.3126
# Epoch 2/200
# 78/78 [==============================] - 15s 186ms/step - loss: 2.1300 - accuracy: 0.2314 - val_loss: 1.6994 - val_accuracy: 0.5310
# Epoch 3/200
# 78/78 [==============================] - 14s 181ms/step - loss: 1.8585 - accuracy: 0.3444 - val_loss: 1.3364 - val_accuracy: 0.6100
# Epoch 4/200
# 78/78 [==============================] - 14s 178ms/step - loss: 1.6189 - accuracy: 0.4405 - val_loss: 1.1232 - val_accuracy: 0.6620
# Epoch 5/200
# 78/78 [==============================] - 14s 177ms/step - loss: 1.4518 - accuracy: 0.5084 - val_loss: 1.0092 - val_accuracy: 0.6822
# Epoch 6/200
# 78/78 [==============================] - 14s 178ms/step - loss: 1.3299 - accuracy: 0.5591 - val_loss: 0.9043 - val_accuracy: 0.7126
# Epoch 7/200
# 78/78 [==============================] - 14s 180ms/step - loss: 1.2256 - accuracy: 0.6041 - val_loss: 0.8741 - val_accuracy: 0.7218
# Epoch 8/200
# 78/78 [==============================] - 14s 181ms/step - loss: 1.1496 - accuracy: 0.6317 - val_loss: 0.8116 - val_accuracy: 0.7373
# Epoch 9/200
# 78/78 [==============================] - 14s 180ms/step - loss: 1.0743 - accuracy: 0.6535 - val_loss: 0.7890 - val_accuracy: 0.7436
# Epoch 10/200
# 78/78 [==============================] - 14s 179ms/step - loss: 1.0163 - accuracy: 0.6808 - val_loss: 0.7479 - val_accuracy: 0.7561
# Epoch 11/200
# 78/78 [==============================] - 14s 179ms/step - loss: 0.9739 - accuracy: 0.6914 - val_loss: 0.7198 - val_accuracy: 0.7654
# Epoch 12/200
# 78/78 [==============================] - 14s 179ms/step - loss: 0.9407 - accuracy: 0.7062 - val_loss: 0.7201 - val_accuracy: 0.7597
# Epoch 13/200
# 78/78 [==============================] - 14s 179ms/step - loss: 0.8992 - accuracy: 0.7233 - val_loss: 0.6853 - val_accuracy: 0.7739
# Epoch 14/200
# 78/78 [==============================] - 14s 179ms/step - loss: 0.8599 - accuracy: 0.7362 - val_loss: 0.6718 - val_accuracy: 0.7819
# Epoch 15/200
# 78/78 [==============================] - 14s 180ms/step - loss: 0.8332 - accuracy: 0.7400 - val_loss: 0.6435 - val_accuracy: 0.7908
# Epoch 16/200
# 78/78 [==============================] - 14s 180ms/step - loss: 0.7945 - accuracy: 0.7560 - val_loss: 0.6385 - val_accuracy: 0.7888
# Epoch 17/200
# 78/78 [==============================] - 14s 181ms/step - loss: 0.7694 - accuracy: 0.7625 - val_loss: 0.6225 - val_accuracy: 0.7945
# Epoch 18/200
# 78/78 [==============================] - 14s 180ms/step - loss: 0.7521 - accuracy: 0.7734 - val_loss: 0.6186 - val_accuracy: 0.7983
# Epoch 19/200
# 78/78 [==============================] - 14s 180ms/step - loss: 0.7326 - accuracy: 0.7763 - val_loss: 0.6001 - val_accuracy: 0.8012
# Epoch 20/200
# 78/78 [==============================] - 14s 180ms/step - loss: 0.6959 - accuracy: 0.7907 - val_loss: 0.6004 - val_accuracy: 0.8041
# Epoch 21/200
# 78/78 [==============================] - 14s 180ms/step - loss: 0.6865 - accuracy: 0.7949 - val_loss: 0.5970 - val_accuracy: 0.8039
# Epoch 22/200
# 78/78 [==============================] - 14s 180ms/step - loss: 0.6682 - accuracy: 0.7961 - val_loss: 0.5891 - val_accuracy: 0.8069
# Epoch 23/200
# 78/78 [==============================] - 14s 180ms/step - loss: 0.6544 - accuracy: 0.8065 - val_loss: 0.5812 - val_accuracy: 0.8104
# Epoch 24/200
# 78/78 [==============================] - 14s 180ms/step - loss: 0.6355 - accuracy: 0.8082 - val_loss: 0.5708 - val_accuracy: 0.8139
# Epoch 25/200
# 78/78 [==============================] - 14s 180ms/step - loss: 0.6288 - accuracy: 0.8115 - val_loss: 0.5577 - val_accuracy: 0.8172
# Epoch 26/200
# 78/78 [==============================] - 14s 180ms/step - loss: 0.5974 - accuracy: 0.8202 - val_loss: 0.5541 - val_accuracy: 0.8185
# Epoch 27/200
# 78/78 [==============================] - 14s 181ms/step - loss: 0.5832 - accuracy: 0.8247 - val_loss: 0.5636 - val_accuracy: 0.8148
# Epoch 28/200
# 78/78 [==============================] - 14s 180ms/step - loss: 0.5601 - accuracy: 0.8308 - val_loss: 0.5553 - val_accuracy: 0.8219
# Epoch 29/200
# 78/78 [==============================] - 14s 179ms/step - loss: 0.5556 - accuracy: 0.8340 - val_loss: 0.5558 - val_accuracy: 0.8203
# Epoch 30/200
# 78/78 [==============================] - 14s 179ms/step - loss: 0.5347 - accuracy: 0.8392 - val_loss: 0.5634 - val_accuracy: 0.8203
# Epoch 31/200
# 78/78 [==============================] - 14s 179ms/step - loss: 0.5262 - accuracy: 0.8443 - val_loss: 0.5440 - val_accuracy: 0.8257
# Epoch 32/200
# 78/78 [==============================] - 14s 180ms/step - loss: 0.5218 - accuracy: 0.8439 - val_loss: 0.5424 - val_accuracy: 0.8267
# Epoch 33/200
# 78/78 [==============================] - 14s 180ms/step - loss: 0.5005 - accuracy: 0.8495 - val_loss: 0.5723 - val_accuracy: 0.8181
# Epoch 34/200
# 78/78 [==============================] - 14s 180ms/step - loss: 0.4897 - accuracy: 0.8555 - val_loss: 0.5486 - val_accuracy: 0.8287
# Epoch 35/200
# 78/78 [==============================] - 14s 179ms/step - loss: 0.4695 - accuracy: 0.8612 - val_loss: 0.5484 - val_accuracy: 0.8264
# Epoch 36/200
# 78/78 [==============================] - 14s 180ms/step - loss: 0.4691 - accuracy: 0.8609 - val_loss: 0.5281 - val_accuracy: 0.8341
# Epoch 37/200
# 78/78 [==============================] - 14s 180ms/step - loss: 0.4393 - accuracy: 0.8677 - val_loss: 0.5333 - val_accuracy: 0.8308
# Epoch 38/200
# 78/78 [==============================] - 14s 180ms/step - loss: 0.4402 - accuracy: 0.8698 - val_loss: 0.5545 - val_accuracy: 0.8266
# Epoch 39/200
# 78/78 [==============================] - 14s 180ms/step - loss: 0.4182 - accuracy: 0.8790 - val_loss: 0.5279 - val_accuracy: 0.8375
# Epoch 40/200
# 78/78 [==============================] - 14s 180ms/step - loss: 0.4141 - accuracy: 0.8776 - val_loss: 0.5367 - val_accuracy: 0.8347
# Epoch 41/200
# 78/78 [==============================] - 14s 180ms/step - loss: 0.3986 - accuracy: 0.8813 - val_loss: 0.5309 - val_accuracy: 0.8379
# Epoch 42/200
# 78/78 [==============================] - 14s 180ms/step - loss: 0.3899 - accuracy: 0.8847 - val_loss: 0.5278 - val_accuracy: 0.8407
# Epoch 43/200
# 78/78 [==============================] - 14s 180ms/step - loss: 0.3819 - accuracy: 0.8882 - val_loss: 0.5278 - val_accuracy: 0.8416
# Epoch 44/200
# 78/78 [==============================] - 14s 180ms/step - loss: 0.3640 - accuracy: 0.8912 - val_loss: 0.5370 - val_accuracy: 0.8395
# Epoch 45/200
# 78/78 [==============================] - 14s 180ms/step - loss: 0.3539 - accuracy: 0.8961 - val_loss: 0.5653 - val_accuracy: 0.8328
# Epoch 46/200
# 78/78 [==============================] - 14s 180ms/step - loss: 0.3602 - accuracy: 0.8939 - val_loss: 0.5365 - val_accuracy: 0.8377
# Epoch 47/200
# 78/78 [==============================] - 14s 180ms/step - loss: 0.3334 - accuracy: 0.9040 - val_loss: 0.5559 - val_accuracy: 0.8397
# Epoch 48/200
# 78/78 [==============================] - 14s 180ms/step - loss: 0.3342 - accuracy: 0.9014 - val_loss: 0.5477 - val_accuracy: 0.8419
# Epoch 49/200
# 78/78 [==============================] - 14s 181ms/step - loss: 0.3129 - accuracy: 0.9086 - val_loss: 0.5587 - val_accuracy: 0.8412
# Epoch 50/200
# 78/78 [==============================] - 14s 180ms/step - loss: 0.3018 - accuracy: 0.9117 - val_loss: 0.5448 - val_accuracy: 0.8436
# Epoch 51/200
# 78/78 [==============================] - 14s 180ms/step - loss: 0.2959 - accuracy: 0.9134 - val_loss: 0.5435 - val_accuracy: 0.8453
# Epoch 52/200
# 78/78 [==============================] - 14s 180ms/step - loss: 0.2940 - accuracy: 0.9156 - val_loss: 0.5490 - val_accuracy: 0.8460
# Epoch 53/200
# 78/78 [==============================] - 14s 180ms/step - loss: 0.2699 - accuracy: 0.9215 - val_loss: 0.5808 - val_accuracy: 0.8354
# Epoch 54/200
# 78/78 [==============================] - 14s 181ms/step - loss: 0.3000 - accuracy: 0.9124 - val_loss: 0.5623 - val_accuracy: 0.8429
# Epoch 55/200
# 78/78 [==============================] - 14s 180ms/step - loss: 0.2653 - accuracy: 0.9231 - val_loss: 0.5565 - val_accuracy: 0.8464
# Epoch 56/200
# 78/78 [==============================] - 14s 180ms/step - loss: 0.2536 - accuracy: 0.9252 - val_loss: 0.5612 - val_accuracy: 0.8439
# Epoch 57/200
# 78/78 [==============================] - 14s 180ms/step - loss: 0.2352 - accuracy: 0.9304 - val_loss: 0.5870 - val_accuracy: 0.8453
# Epoch 58/200
# 78/78 [==============================] - 14s 180ms/step - loss: 0.2356 - accuracy: 0.9334 - val_loss: 0.5992 - val_accuracy: 0.8434
# Epoch 59/200
# 78/78 [==============================] - 14s 180ms/step - loss: 0.2312 - accuracy: 0.9352 - val_loss: 0.5860 - val_accuracy: 0.8440
# Epoch 60/200
# 78/78 [==============================] - 14s 180ms/step - loss: 0.2240 - accuracy: 0.9365 - val_loss: 0.5855 - val_accuracy: 0.8489
# Epoch 61/200
# 78/78 [==============================] - 14s 180ms/step - loss: 0.2106 - accuracy: 0.9405 - val_loss: 0.6060 - val_accuracy: 0.8451
# Epoch 62/200
# 78/78 [==============================] - 14s 180ms/step - loss: 0.2036 - accuracy: 0.9428 - val_loss: 0.6152 - val_accuracy: 0.8416

# %% [markdown]
# ## 6. Evaluamos el Modelo

# %%
# VGG16 + DA
_, acc = model_ft_vgg.evaluate(x_test_scaled, y_test_encoded, verbose=0)
print('Accuracy:',' %.3f' % (acc))
# Out:
# Accuracy:  0.840

# %%
elapsed_time = datetime.timedelta(seconds=(time.perf_counter() - t))

print('Tiempo de entrenamiento:', elapsed_time)
# Out:
# Tiempo de entrenamiento: 0:14:40.599208

# %%
plt.title('Cross Entropy Loss')
plt.plot(history.history['loss'], color='blue', label='train')
plt.plot(history.history['val_loss'], color='orange', label='test')
plt.show()

plt.title('Classification Accuracy')
plt.plot(history.history['accuracy'], color='blue', label='train')
plt.plot(history.history['val_accuracy'], color='orange', label='test')
plt.show()

# %% [markdown]
# El coste podemos ver que es estable y es en el epoch 15 que se fija en un valor. Además la accuracy baila alrededor de 0.10. No se puede decir que sea un modelo muy bueno.
#
# Veamos que tipo de predicciones estoy obteniendo sobre el conjunto de test (vamos a pintar las imagenes y sus clasificaciones)

# %%
predictions = model_ft_vgg.predict(x_test_scaled)

# %% [markdown]
# Una de las ventajas de Python es que hay montones de funciones y código realizado por terceras personas. Aquí me he fusilado unas bonitas funciones (que he adaptado un poco a mis necesidades) para poder pintar las imagenes, su label (ground truth) y las clasificaciones que hemos realizado.

# %%
def plot_image(i, predictions_array, true_label, img):
  predictions_array, true_label, img = predictions_array, true_label[i], img[i]
  plt.grid(False)
  plt.xticks([])
  plt.yticks([])

  plt.imshow(img, cmap=plt.cm.binary)

  predicted_label = np.argmax(predictions_array)
  if predicted_label == true_label:
    color = 'blue'
  else:
    color = 'red'

  plt.xlabel("{} {:2.0f}% ({})".format(predicted_label,
                                100*np.max(predictions_array),
                                true_label[0]),
                                color=color)

def plot_value_array(i, predictions_array, true_label):
  predictions_array, true_label = predictions_array, true_label[i]
  plt.grid(False)
  plt.xticks(range(10))
  plt.yticks([])
  thisplot = plt.bar(range(10), predictions_array, color="#777777")
  plt.ylim([0, 1])
  predicted_label = np.argmax(predictions_array)

  thisplot[predicted_label].set_color('red')
  thisplot[true_label[0]].set_color('blue')

# %% [markdown]
# Dibujamos las primeras imagenes, con las predicciones y sus valores reales (un total de 20 imagenes, para no abusar de vuestros laptops)
#
# Coloreamos las prediciones correctas en azul y los fallos en rojo. Aunque primero he impreso las etiquetas para que tengamos una referencia al grafico.

# %%
i = 0
for l in cifar10_labels:
    print(i, l)
    i += 1

num_rows = 5
num_cols = 4
start = 1000
num_images = num_rows*num_cols
plt.figure(figsize=(2*2*num_cols, 2*num_rows))
for i in range(num_images):
  plt.subplot(num_rows, 2*num_cols, 2*i+1)
  plot_image(i+start, predictions[i+start], y_test, x_test_scaled)
  plt.subplot(num_rows, 2*num_cols, 2*i+2)
  plot_value_array(i+start, predictions[i+start], y_test)
plt.tight_layout()
plt.show()
# Out:
# 0 airplane
# 1 automobile
# 2 bird
# 3 cat
# 4 deer
# 5 dog
# 6 frog
# 7 horse
# 8 ship
# 9 truck
