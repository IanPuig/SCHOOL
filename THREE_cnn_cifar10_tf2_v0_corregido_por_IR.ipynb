# %% [markdown]
# ![Nuclio logo](https://nuclio.school/wp-content/uploads/2018/12/nucleoDS-newBlack.png)

# %% [markdown]
# ## 1. Librerias
#
# Para empezar carguemos esas librerias que nos hacen falta

# %%
import numpy as np
import time
import datetime
import random
import pandas as pd
import os

from matplotlib import pyplot as plt
from tensorflow import keras as ks
from tensorflow.keras.preprocessing.image import ImageDataGenerator, load_img
from keras.utils import to_categorical
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.regularizers import l2
from tensorflow.keras.optimizers import Adam

# %% [markdown]
# ## 2. Arquitectura de red del modelo

# %%
model = ks.Sequential()

model.add(ks.layers.Conv2D(32, (3, 3), strides=1, activation='relu', padding='same', input_shape=(32,32,3)))
model.add(ks.layers.Conv2D(32, (3, 3), strides=1, activation='relu', padding='same'))
model.add(ks.layers.MaxPooling2D((2, 2)))
model.add(ks.layers.Dropout(0.6))  

model.add(ks.layers.Conv2D(64, (3, 3), strides=1, activation='relu', padding='same', input_shape=(32,32,3)))
model.add(ks.layers.Conv2D(64, (3, 3), strides=1, activation='relu', padding='same'))
model.add(ks.layers.MaxPooling2D((2, 2)))
model.add(ks.layers.Dropout(0.5))  

model.add(ks.layers.Flatten())
model.add(ks.layers.Dense(128, activation='relu'))
model.add(ks.layers.Dropout(0.4))  

model.add(ks.layers.Dense(10, activation='softmax'))
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 32, 32, 32)        896
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 32, 32, 32)        9248
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 16, 16, 32)        0
# _________________________________________________________________
# dropout (Dropout)            (None, 16, 16, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 16, 16, 64)        18496
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 16, 16, 64)        36928
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 8, 8, 64)          0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 8, 8, 64)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 4096)              0
# _________________________________________________________________
# dense (Dense)                (None, 128)               524416
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 10)                1290
# =================================================================
# Total params: 591,274
# Trainable params: 591,274
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# Para revisar un modelo, nos basta con llamar al método **.summary()** del modelo

# %% [markdown]
# ## 3. Optimizador, función error

# %%
model.compile(optimizer='Adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# %% [markdown]
# # 3.1 Definimos la tecnica de Early stopping mediante callbacks

# %%
callback_val_loss = EarlyStopping(monitor="val_loss", patience=20)
callback_val_accy = EarlyStopping(monitor="val_accuracy", patience=20)

# %% [markdown]
# ## 4. Preparamos los datos
#
# Cargamos los datos de CIFAR10 de los datasets directamente de las librerias de Keras. Estos ya estan dispuestos en train and test
#
# **Detalle importante:**
# > La red neuronal requiere que los inputs sean números reales, y lo haremos forzando la division de los valores de dentro de las matrices 28x28 (que tienen valoress del 0 al 255) por 255.0 (un real)

# %%
cifar10 = ks.datasets.cifar10

(x_train, y_train), (x_test, y_test) = cifar10.load_data()
x_train_scaled, x_test_scaled = x_train / 255.0, x_test / 255.0            # Descomentado por Isidre

# %%
print(y_train)
print(y_test)
# Out:
# [[6]
#  [9]
#  [9]
#  ...
#  [9]
#  [1]
#  [1]]
# [[3]
#  [8]
#  [8]
#  ...
#  [5]
#  [1]
#  [7]]

# %% [markdown]
# Obtenemos un array con todas las labels de CIFAR10

# %%
cifar10_labels = ['airplane','automobile','bird','cat','deer','dog','frog','horse','ship','truck']
print('labels: %s' % (cifar10_labels))
# Out:
# labels: ['airplane', 'automobile', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']

# %% [markdown]
# Pintemos una muestra de las imagenes del dataset CIFAR10, a ver si se parece en algo a lo que esperamos.
# Primero, vemos que tipos de datos tengo, después mapeamos esas matrices en una escala de grises utilizando el método **.get_cmap()** de PlotLy con los nueve primeros números del dataset.

# %%
# Pintemos una muestra de las las imagenes del dataset 

print('Train: X=%s, y=%s' % (x_train.shape, y_train.shape))
print('Test: X=%s, y=%s' % (x_test.shape, y_test.shape))

for i in range(9):

    plt.subplot(330 + 1 + i)
    plt.imshow(x_train[i], cmap=plt.get_cmap('gray'))
    plt.title(cifar10_labels[y_train[i,0]])

plt.subplots_adjust(hspace = 1)
plt.show()
# Out:
# Train: X=(50000, 32, 32, 3), y=(50000, 1)
# Test: X=(10000, 32, 32, 3), y=(10000, 1)

# %% [markdown]
# Como vamos a querer ir haciendo validación a la vez que entrenamos (muy practico)

# %%
x_val = x_train[-10000:]
y_val = y_train[-10000:]

x_train = x_train[:-10000]
y_train = y_train[:-10000]

# %% [markdown]
# # [Añadido por ISIDRE]

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()
le.fit(y_train)

y_train_encoded = le.transform(y_train)
y_val_encoded = le.transform(y_val)
y_test_encoded = le.transform(y_test)
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/preprocessing/_label.py:235: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.6/dist-packages/sklearn/preprocessing/_label.py:268: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
y_train_encoded
# Out:
# array([6, 9, 9, ..., 6, 2, 8])

# %% [markdown]
# # [Fin añadido por Isidre]

# %%
y_train
# Out:
# array([[6],
#        [9],
#        [9],
#        ...,
#        [6],
#        [2],
#        [8]], dtype=uint8)

# %% [markdown]
# Cuando añadimos convoluciones, necesitamos "pre-tratar los datos", porque **la convolución es pera una matriz de 4 campos** (más parecido a "imagenes"), no un array de 3 como son actualmente los data sets de train, test y validación. Así que toca darle al **.reshape()**
#
# Por eso, al salir de la Convolution, hay que hacer un Flatten, porque las capas FullDense esperan arrays, no matrices!!
#
# Luego lo imprimimos para ver que todo está correcto

# %%
# Validamos el resultado
print('Train: X=%s, y=%s' % (x_train.shape, y_train.shape))
print('Test: X=%s, y=%s' % (x_test.shape, y_test.shape))
# Out:
# Train: X=(40000, 32, 32, 3), y=(40000, 1)
# Test: X=(10000, 32, 32, 3), y=(10000, 1)

# %% [markdown]
# ## Transformador de imagenes a datos consumibles por la red neuronal

# %%
train_datagen = ImageDataGenerator( 
    rescale=1./255,
    # rotation_range = 20,
    # shear_range = 0.05,
    # zoom_range= 0.05,
    horizontal_flip=True,
    # width_shift_range=-0.01,
    # height_shift_range=-0.01,
    # brightness_range=(0.8,1.2),
    # fill_mode='nearest'
    )

# debemos coger las imagenes originales, le doy la x, le doy la y 
# y el batch size = cuantas imagenes voy a generar por cada paquete, data generation (no podemos pasarnos, misma cantidad que le pasamos en eel data set)

train_generator = train_datagen.flow( 
    x_train, 
    y_train_encoded, 
    batch_size=256          # hago esto para cada 30 imagenes
    )

# %% [markdown]
# ## vamos a pintarnos un ejemplo de lo que hace el train data generator

# %%
sample = random.choice(range(0,1450))
example_generator = train_datagen.flow(
    x_train[sample:sample+1],
    y_train[sample:sample+1],
    batch_size=20
    )

plt.imshow(x_train[sample])

# %%
plt.figure(figsize=(12,12))
for i in range(0,15):
    plt.subplot(5,3,i+1)
    for X, Y in example_generator:
        image = X[0]
        plt.imshow(image)
        break

plt.tight_layout()
plt.show()

# %% [markdown]
# **De validacion y de testeo**
#
# Fijaos que aquí la única modificación es un re-escalado, nada de modificaciones

# %%
validation_datagen = ImageDataGenerator(
    rescale=1./255
    )
validation_generator = validation_datagen.flow(
    x_val, 
    y_val_encoded, 
    batch_size=32
    )

test_datagen = ImageDataGenerator(
    rescale=1./255
    )
test_generator = test_datagen.flow(
    x_test, 
    y_test_encoded,
    batch_size=32
    )

# %% [markdown]
# ## 5. Entrenamiento
#
# Ya podemos ponernos a entrenar el modelo!! Ojo, que hemos de entrenar contra los datos convertidos al formato que espera la Convolution.
#
# Empezaremos con 30 epocs, es decir, 30 pasadas completas del dataset (que a su vez sera con mini-batches internamente), fijando un batch de 64
#
# El metodo .fit() nos permite, definir además si disponemos de varias CPUs, GPUs, y si queremos ir validando datos a cada fin de epoch.

# %%
t = time.perf_counter()

# %%
history = model.fit(train_generator,epochs=100,steps_per_epoch= 128,callbacks=[callback_val_loss,callback_val_accy],validation_data=validation_generator,validation_steps=32)

# history = model.fit(x_traain, y_train, epochs=200, callbacks=[callback_val_loss,callback_val_accy], batch_size= 512, validation_data=(x_val, y_val))
# Out:
# Epoch 1/100
# 128/128 [==============================] - 10s 20ms/step - loss: 2.1168 - accuracy: 0.1987 - val_loss: 1.6892 - val_accuracy: 0.3818
# Epoch 2/100
# 128/128 [==============================] - 2s 18ms/step - loss: 1.6765 - accuracy: 0.3859 - val_loss: 1.4399 - val_accuracy: 0.4971
# Epoch 3/100
# 128/128 [==============================] - 2s 18ms/step - loss: 1.5314 - accuracy: 0.4399 - val_loss: 1.3339 - val_accuracy: 0.5293
# Epoch 4/100
# 128/128 [==============================] - 2s 18ms/step - loss: 1.4361 - accuracy: 0.4769 - val_loss: 1.2088 - val_accuracy: 0.5684
# Epoch 5/100
# 128/128 [==============================] - 2s 18ms/step - loss: 1.3457 - accuracy: 0.5160 - val_loss: 1.1809 - val_accuracy: 0.5713
# Epoch 6/100
# 128/128 [==============================] - 2s 18ms/step - loss: 1.2918 - accuracy: 0.5355 - val_loss: 1.1274 - val_accuracy: 0.6074
# Epoch 7/100
# 128/128 [==============================] - 2s 18ms/step - loss: 1.2261 - accuracy: 0.5577 - val_loss: 1.0551 - val_accuracy: 0.6270
# Epoch 8/100
# 128/128 [==============================] - 2s 18ms/step - loss: 1.1825 - accuracy: 0.5785 - val_loss: 1.0507 - val_accuracy: 0.6211
# Epoch 9/100
# 128/128 [==============================] - 2s 18ms/step - loss: 1.1507 - accuracy: 0.5894 - val_loss: 0.9945 - val_accuracy: 0.6299
# Epoch 10/100
# 128/128 [==============================] - 2s 18ms/step - loss: 1.1144 - accuracy: 0.6002 - val_loss: 0.8909 - val_accuracy: 0.7051
# Epoch 11/100
# 128/128 [==============================] - 2s 18ms/step - loss: 1.0803 - accuracy: 0.6140 - val_loss: 0.9554 - val_accuracy: 0.6504
# Epoch 12/100
# 128/128 [==============================] - 2s 18ms/step - loss: 1.0490 - accuracy: 0.6292 - val_loss: 0.8665 - val_accuracy: 0.6875
# Epoch 13/100
# 128/128 [==============================] - 2s 18ms/step - loss: 1.0140 - accuracy: 0.6456 - val_loss: 0.8396 - val_accuracy: 0.7080
# Epoch 14/100
# 128/128 [==============================] - 2s 18ms/step - loss: 1.0179 - accuracy: 0.6394 - val_loss: 0.8545 - val_accuracy: 0.6895
# Epoch 15/100
# 128/128 [==============================] - 2s 18ms/step - loss: 0.9980 - accuracy: 0.6519 - val_loss: 0.8642 - val_accuracy: 0.6885
# Epoch 16/100
# 128/128 [==============================] - 2s 18ms/step - loss: 0.9651 - accuracy: 0.6578 - val_loss: 0.8337 - val_accuracy: 0.7051
# Epoch 17/100
# 128/128 [==============================] - 2s 18ms/step - loss: 0.9410 - accuracy: 0.6686 - val_loss: 0.8056 - val_accuracy: 0.7207
# Epoch 18/100
# 128/128 [==============================] - 2s 18ms/step - loss: 0.9312 - accuracy: 0.6697 - val_loss: 0.7866 - val_accuracy: 0.7285
# Epoch 19/100
# 128/128 [==============================] - 2s 18ms/step - loss: 0.9116 - accuracy: 0.6809 - val_loss: 0.7836 - val_accuracy: 0.7324
# Epoch 20/100
# 128/128 [==============================] - 2s 18ms/step - loss: 0.9081 - accuracy: 0.6808 - val_loss: 0.7887 - val_accuracy: 0.7324
# Epoch 21/100
# 128/128 [==============================] - 2s 18ms/step - loss: 0.8883 - accuracy: 0.6864 - val_loss: 0.7469 - val_accuracy: 0.7520
# Epoch 22/100
# 128/128 [==============================] - 2s 18ms/step - loss: 0.8879 - accuracy: 0.6896 - val_loss: 0.7230 - val_accuracy: 0.7539
# Epoch 23/100
# 128/128 [==============================] - 2s 18ms/step - loss: 0.8683 - accuracy: 0.6945 - val_loss: 0.6782 - val_accuracy: 0.7607
# Epoch 24/100
# 128/128 [==============================] - 2s 18ms/step - loss: 0.8658 - accuracy: 0.6943 - val_loss: 0.7921 - val_accuracy: 0.7324
# Epoch 25/100
# 128/128 [==============================] - 2s 18ms/step - loss: 0.8495 - accuracy: 0.7047 - val_loss: 0.7116 - val_accuracy: 0.7412
# Epoch 26/100
# 128/128 [==============================] - 2s 18ms/step - loss: 0.8420 - accuracy: 0.7075 - val_loss: 0.7513 - val_accuracy: 0.7334
# Epoch 27/100
# 128/128 [==============================] - 2s 18ms/step - loss: 0.8332 - accuracy: 0.7099 - val_loss: 0.7347 - val_accuracy: 0.7461
# Epoch 28/100
# 128/128 [==============================] - 2s 18ms/step - loss: 0.8391 - accuracy: 0.7043 - val_loss: 0.7526 - val_accuracy: 0.7324
# Epoch 29/100
# 128/128 [==============================] - 2s 18ms/step - loss: 0.8328 - accuracy: 0.7101 - val_loss: 0.6838 - val_accuracy: 0.7500
# Epoch 30/100
# 128/128 [==============================] - 2s 18ms/step - loss: 0.7977 - accuracy: 0.7204 - val_loss: 0.6633 - val_accuracy: 0.7598
# Epoch 31/100
# 128/128 [==============================] - 2s 18ms/step - loss: 0.8053 - accuracy: 0.7169 - val_loss: 0.6885 - val_accuracy: 0.7705
# Epoch 32/100
# 128/128 [==============================] - 2s 18ms/step - loss: 0.8035 - accuracy: 0.7169 - val_loss: 0.7344 - val_accuracy: 0.7588
# Epoch 33/100
# 128/128 [==============================] - 2s 18ms/step - loss: 0.7804 - accuracy: 0.7262 - val_loss: 0.6712 - val_accuracy: 0.7695
# Epoch 34/100
# 128/128 [==============================] - 2s 19ms/step - loss: 0.7862 - accuracy: 0.7248 - val_loss: 0.6659 - val_accuracy: 0.7568
# Epoch 35/100
# 128/128 [==============================] - 2s 18ms/step - loss: 0.7829 - accuracy: 0.7215 - val_loss: 0.6474 - val_accuracy: 0.7646
# Epoch 36/100
# 128/128 [==============================] - 2s 18ms/step - loss: 0.7677 - accuracy: 0.7297 - val_loss: 0.6488 - val_accuracy: 0.7676
# Epoch 37/100
# 128/128 [==============================] - 2s 18ms/step - loss: 0.7758 - accuracy: 0.7294 - val_loss: 0.6392 - val_accuracy: 0.7861
# Epoch 38/100
# 128/128 [==============================] - 2s 18ms/step - loss: 0.7523 - accuracy: 0.7351 - val_loss: 0.6930 - val_accuracy: 0.7559
# Epoch 39/100
# 128/128 [==============================] - 2s 18ms/step - loss: 0.7588 - accuracy: 0.7305 - val_loss: 0.6997 - val_accuracy: 0.7666
# Epoch 40/100
# 128/128 [==============================] - 2s 18ms/step - loss: 0.7574 - accuracy: 0.7336 - val_loss: 0.6466 - val_accuracy: 0.7666
# Epoch 41/100
# 128/128 [==============================] - 2s 18ms/step - loss: 0.7595 - accuracy: 0.7352 - val_loss: 0.6234 - val_accuracy: 0.7842
# Epoch 42/100
# 128/128 [==============================] - 2s 18ms/step - loss: 0.7580 - accuracy: 0.7330 - val_loss: 0.6341 - val_accuracy: 0.7803
# Epoch 43/100
# 128/128 [==============================] - 2s 18ms/step - loss: 0.7519 - accuracy: 0.7351 - val_loss: 0.6571 - val_accuracy: 0.7686
# Epoch 44/100
# 128/128 [==============================] - 2s 18ms/step - loss: 0.7410 - accuracy: 0.7423 - val_loss: 0.6415 - val_accuracy: 0.7930
# Epoch 45/100
# 128/128 [==============================] - 2s 18ms/step - loss: 0.7339 - accuracy: 0.7466 - val_loss: 0.6654 - val_accuracy: 0.7764
# Epoch 46/100
# 128/128 [==============================] - 2s 18ms/step - loss: 0.7238 - accuracy: 0.7474 - val_loss: 0.6516 - val_accuracy: 0.7656
# Epoch 47/100
# 128/128 [==============================] - 2s 18ms/step - loss: 0.7343 - accuracy: 0.7440 - val_loss: 0.6935 - val_accuracy: 0.7559
# Epoch 48/100
# 128/128 [==============================] - 2s 18ms/step - loss: 0.7198 - accuracy: 0.7473 - val_loss: 0.6269 - val_accuracy: 0.7842
# Epoch 49/100
# 128/128 [==============================] - 2s 19ms/step - loss: 0.7069 - accuracy: 0.7502 - val_loss: 0.6382 - val_accuracy: 0.7812
# Epoch 50/100
# 128/128 [==============================] - 2s 18ms/step - loss: 0.7087 - accuracy: 0.7473 - val_loss: 0.6732 - val_accuracy: 0.7676
# Epoch 51/100
# 128/128 [==============================] - 2s 19ms/step - loss: 0.7195 - accuracy: 0.7473 - val_loss: 0.5982 - val_accuracy: 0.7979
# Epoch 52/100
# 128/128 [==============================] - 2s 19ms/step - loss: 0.7126 - accuracy: 0.7483 - val_loss: 0.6407 - val_accuracy: 0.7793
# Epoch 53/100
# 128/128 [==============================] - 2s 19ms/step - loss: 0.7410 - accuracy: 0.7393 - val_loss: 0.6306 - val_accuracy: 0.7764
# Epoch 54/100
# 128/128 [==============================] - 2s 19ms/step - loss: 0.7087 - accuracy: 0.7507 - val_loss: 0.5791 - val_accuracy: 0.8018
# Epoch 55/100
# 128/128 [==============================] - 2s 18ms/step - loss: 0.7123 - accuracy: 0.7487 - val_loss: 0.6846 - val_accuracy: 0.7578
# Epoch 56/100
# 128/128 [==============================] - 2s 19ms/step - loss: 0.6992 - accuracy: 0.7517 - val_loss: 0.6175 - val_accuracy: 0.7900
# Epoch 57/100
# 128/128 [==============================] - 2s 19ms/step - loss: 0.7082 - accuracy: 0.7519 - val_loss: 0.6074 - val_accuracy: 0.7930
# Epoch 58/100
# 128/128 [==============================] - 2s 19ms/step - loss: 0.6873 - accuracy: 0.7581 - val_loss: 0.6268 - val_accuracy: 0.7754
# Epoch 59/100
# 128/128 [==============================] - 2s 19ms/step - loss: 0.6929 - accuracy: 0.7547 - val_loss: 0.5940 - val_accuracy: 0.7979
# Epoch 60/100
# 128/128 [==============================] - 2s 19ms/step - loss: 0.6938 - accuracy: 0.7558 - val_loss: 0.6132 - val_accuracy: 0.7930
# Epoch 61/100
# 128/128 [==============================] - 2s 19ms/step - loss: 0.7048 - accuracy: 0.7518 - val_loss: 0.6000 - val_accuracy: 0.7900
# Epoch 62/100
# 128/128 [==============================] - 2s 19ms/step - loss: 0.6831 - accuracy: 0.7585 - val_loss: 0.5946 - val_accuracy: 0.7910
# Epoch 63/100
# 128/128 [==============================] - 2s 19ms/step - loss: 0.6800 - accuracy: 0.7596 - val_loss: 0.6482 - val_accuracy: 0.7939
# Epoch 64/100
# 128/128 [==============================] - 2s 19ms/step - loss: 0.6715 - accuracy: 0.7634 - val_loss: 0.5878 - val_accuracy: 0.7900
# Epoch 65/100
# 128/128 [==============================] - 2s 19ms/step - loss: 0.6639 - accuracy: 0.7662 - val_loss: 0.6087 - val_accuracy: 0.7793
# Epoch 66/100
# 128/128 [==============================] - 2s 19ms/step - loss: 0.6656 - accuracy: 0.7668 - val_loss: 0.5908 - val_accuracy: 0.7949
# Epoch 67/100
# 128/128 [==============================] - 2s 19ms/step - loss: 0.6697 - accuracy: 0.7671 - val_loss: 0.5773 - val_accuracy: 0.8145
# Epoch 68/100
# 128/128 [==============================] - 2s 19ms/step - loss: 0.6798 - accuracy: 0.7616 - val_loss: 0.6117 - val_accuracy: 0.7939
# Epoch 69/100
# 128/128 [==============================] - 2s 19ms/step - loss: 0.6662 - accuracy: 0.7654 - val_loss: 0.5791 - val_accuracy: 0.7910
# Epoch 70/100
# 128/128 [==============================] - 2s 19ms/step - loss: 0.6793 - accuracy: 0.7628 - val_loss: 0.6704 - val_accuracy: 0.7773
# Epoch 71/100
# 128/128 [==============================] - 2s 19ms/step - loss: 0.6736 - accuracy: 0.7599 - val_loss: 0.6181 - val_accuracy: 0.7979
# Epoch 72/100
# 128/128 [==============================] - 2s 18ms/step - loss: 0.6660 - accuracy: 0.7667 - val_loss: 0.5262 - val_accuracy: 0.8125
# Epoch 73/100
# 128/128 [==============================] - 2s 18ms/step - loss: 0.6607 - accuracy: 0.7677 - val_loss: 0.5146 - val_accuracy: 0.8232
# Epoch 74/100
# 128/128 [==============================] - 2s 18ms/step - loss: 0.6570 - accuracy: 0.7675 - val_loss: 0.5609 - val_accuracy: 0.8008
# Epoch 75/100
# 128/128 [==============================] - 2s 18ms/step - loss: 0.6550 - accuracy: 0.7689 - val_loss: 0.5750 - val_accuracy: 0.8008
# Epoch 76/100
# 128/128 [==============================] - 2s 19ms/step - loss: 0.6554 - accuracy: 0.7713 - val_loss: 0.5577 - val_accuracy: 0.8076
# Epoch 77/100
# 128/128 [==============================] - 2s 19ms/step - loss: 0.6486 - accuracy: 0.7707 - val_loss: 0.5913 - val_accuracy: 0.7979
# Epoch 78/100
# 128/128 [==============================] - 2s 19ms/step - loss: 0.6535 - accuracy: 0.7701 - val_loss: 0.5249 - val_accuracy: 0.8174
# Epoch 79/100
# 128/128 [==============================] - 2s 18ms/step - loss: 0.6538 - accuracy: 0.7656 - val_loss: 0.5987 - val_accuracy: 0.7949
# Epoch 80/100
# 128/128 [==============================] - 2s 19ms/step - loss: 0.6502 - accuracy: 0.7711 - val_loss: 0.4985 - val_accuracy: 0.8203
# Epoch 81/100
# 128/128 [==============================] - 2s 18ms/step - loss: 0.6550 - accuracy: 0.7705 - val_loss: 0.5965 - val_accuracy: 0.7852
# Epoch 82/100
# 128/128 [==============================] - 2s 19ms/step - loss: 0.6543 - accuracy: 0.7716 - val_loss: 0.6042 - val_accuracy: 0.7998
# Epoch 83/100
# 128/128 [==============================] - 2s 19ms/step - loss: 0.6364 - accuracy: 0.7750 - val_loss: 0.5539 - val_accuracy: 0.8271
# Epoch 84/100
# 128/128 [==============================] - 2s 19ms/step - loss: 0.6378 - accuracy: 0.7749 - val_loss: 0.6101 - val_accuracy: 0.7910
# Epoch 85/100
# 128/128 [==============================] - 2s 18ms/step - loss: 0.6444 - accuracy: 0.7717 - val_loss: 0.6614 - val_accuracy: 0.7676
# Epoch 86/100
# 128/128 [==============================] - 2s 19ms/step - loss: 0.6517 - accuracy: 0.7651 - val_loss: 0.5514 - val_accuracy: 0.8076
# Epoch 87/100
# 128/128 [==============================] - 2s 19ms/step - loss: 0.6285 - accuracy: 0.7779 - val_loss: 0.5895 - val_accuracy: 0.7988
# Epoch 88/100
# 128/128 [==============================] - 2s 19ms/step - loss: 0.6301 - accuracy: 0.7737 - val_loss: 0.6215 - val_accuracy: 0.7646
# Epoch 89/100
# 128/128 [==============================] - 2s 19ms/step - loss: 0.6361 - accuracy: 0.7752 - val_loss: 0.5764 - val_accuracy: 0.7988
# Epoch 90/100
# 128/128 [==============================] - 2s 19ms/step - loss: 0.6288 - accuracy: 0.7773 - val_loss: 0.5599 - val_accuracy: 0.8008
# Epoch 91/100
# 128/128 [==============================] - 2s 19ms/step - loss: 0.6246 - accuracy: 0.7777 - val_loss: 0.5596 - val_accuracy: 0.8047
# Epoch 92/100
# 128/128 [==============================] - 2s 19ms/step - loss: 0.6367 - accuracy: 0.7769 - val_loss: 0.5682 - val_accuracy: 0.8027
# Epoch 93/100
# 128/128 [==============================] - 2s 19ms/step - loss: 0.6303 - accuracy: 0.7754 - val_loss: 0.6648 - val_accuracy: 0.7695
# Epoch 94/100
# 128/128 [==============================] - 2s 19ms/step - loss: 0.6119 - accuracy: 0.7835 - val_loss: 0.6261 - val_accuracy: 0.7783
# Epoch 95/100
# 128/128 [==============================] - 2s 19ms/step - loss: 0.6125 - accuracy: 0.7853 - val_loss: 0.5222 - val_accuracy: 0.8389
# Epoch 96/100
# 128/128 [==============================] - 2s 19ms/step - loss: 0.6162 - accuracy: 0.7831 - val_loss: 0.5748 - val_accuracy: 0.8115
# Epoch 97/100
# 128/128 [==============================] - 2s 19ms/step - loss: 0.6133 - accuracy: 0.7868 - val_loss: 0.5796 - val_accuracy: 0.7988
# Epoch 98/100
# 128/128 [==============================] - 2s 19ms/step - loss: 0.6105 - accuracy: 0.7840 - val_loss: 0.5907 - val_accuracy: 0.7891
# Epoch 99/100
# 128/128 [==============================] - 2s 19ms/step - loss: 0.6169 - accuracy: 0.7840 - val_loss: 0.5608 - val_accuracy: 0.8066
# Epoch 100/100
# 128/128 [==============================] - 2s 19ms/step - loss: 0.6222 - accuracy: 0.7809 - val_loss: 0.5304 - val_accuracy: 0.8145

# %%
elapsed_time = datetime.timedelta(seconds=(time.perf_counter() - t))

print('Tiempo de entrenamiento:', elapsed_time)
# Out:
# Tiempo de entrenamiento: 0:04:06.581509

# %% [markdown]
# ## 6. Evaluamos los resultados
#
# # [Isidre ha cambiado los test_generated, por x_test_scaled, y y_test_encoded]

# %%
_, acc = model.evaluate(x_test_scaled, y_test_encoded, verbose=0)
print('Accuracy:',' %.3f' % (acc))
# Out:
# Accuracy:  0.805

# %%
plt.title('Cross Entropy Loss')
plt.plot(history.history['loss'], color='blue', label='train')
plt.plot(history.history['val_loss'], color='orange', label='test')
plt.show()

plt.title('Classification Accuracy')
plt.plot(history.history['accuracy'], color='blue', label='train')
plt.plot(history.history['val_accuracy'], color='orange', label='test')
plt.show()

# %% [markdown]
# El coste podemos ver que es estable y es en el epoch 15 que se fija en un valor. Además la accuracy baila alrededor de 0.10. No se puede decir que sea un modelo muy bueno.
#
# Veamos que tipo de predicciones estoy obteniendo sobre el conjunto de test (vamos a pintar las imagenes y sus clasificaciones)

# %%
predictions = model.predict(x_test_scaled)

# %% [markdown]
# Una de las ventajas de Python es que hay montones de funciones y código realizado por terceras personas. Aquí me he fusilado unas bonitas funciones (que he adaptado un poco a mis necesidades) para poder pintar las imagenes, su label (ground truth) y las clasificaciones que hemos realizado.

# %%
def plot_image(i, predictions_array, true_label, img):
  predictions_array, true_label, img = predictions_array, true_label[i], img[i]
  plt.grid(False)
  plt.xticks([])
  plt.yticks([])

  plt.imshow(img, cmap=plt.cm.binary)

  predicted_label = np.argmax(predictions_array)
  if predicted_label == true_label:
    color = 'blue'
  else:
    color = 'red'

  plt.xlabel("{} {:2.0f}% ({})".format(predicted_label,
                                100*np.max(predictions_array),
                                true_label[0]),
                                color=color)

def plot_value_array(i, predictions_array, true_label):
  predictions_array, true_label = predictions_array, true_label[i]
  plt.grid(False)
  plt.xticks(range(10))
  plt.yticks([])
  thisplot = plt.bar(range(10), predictions_array, color="#777777")
  plt.ylim([0, 1])
  predicted_label = np.argmax(predictions_array)

  thisplot[predicted_label].set_color('red')
  thisplot[true_label[0]].set_color('blue')

# %% [markdown]
# Dibujamos las primeras imagenes, con las predicciones y sus valores reales (un total de 20 imagenes, para no abusar de vuestros laptops)
#
# Coloreamos las prediciones correctas en azul y los fallos en rojo. Aunque primero he impreso las etiquetas para que tengamos una referencia al grafico.

# %%
i = 0
for l in cifar10_labels:
    print(i, l)
    i += 1

num_rows = 5
num_cols = 4
start = 1000
num_images = num_rows*num_cols
plt.figure(figsize=(2*2*num_cols, 2*num_rows))
for i in range(num_images):
  plt.subplot(num_rows, 2*num_cols, 2*i+1)
  plot_image(i+start, predictions[i+start], y_test, x_test_scaled)
  plt.subplot(num_rows, 2*num_cols, 2*i+2)
  plot_value_array(i+start, predictions[i+start], y_test)
plt.tight_layout()
plt.show()
# Out:
# 0 airplane
# 1 automobile
# 2 bird
# 3 cat
# 4 deer
# 5 dog
# 6 frog
# 7 horse
# 8 ship
# 9 truck
